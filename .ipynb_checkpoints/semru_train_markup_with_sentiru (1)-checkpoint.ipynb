# %%
import xml.etree.ElementTree as ET
from razdel import tokenize
import ipymarkup
from collections import defaultdict
from pymorphy2 import MorphAnalyzer
from razdel import tokenize
import pandas as pd

# %%
#Функции для получения разметки из xml файлов SentiRuEval

def parse_texts(path):
    root_node = ET.parse(path).getroot()
    texts = dict()
    for rev in root_node.findall('review'):
        texts[rev.get('id')] = rev.find('text').text
    return texts

def parse_aspects(path):
    root_node = ET.parse(path).getroot()
    global_aspects = dict()
    tag_list = ['type', 'to','term','sentiment','mark','from','category']
    for rev in root_node.findall('review'):
        id_ = rev.get('id')
        aspects = dict()
        for i, a in enumerate(rev.findall('aspects/aspect')):
            aspects[i] = dict()
            for tag in tag_list:
                aspects[i][f'{tag}'] = a.get(tag)
        global_aspects[f'{id_}'] = aspects
    return global_aspects

def mark_text(path, aspect_type = 'explicit', binary = True):
    global_aspects = parse_aspects(path)
    texts = parse_texts(path)
    
    categories = set()
    for id_ in global_aspects.values():
        for aspect in id_.values():
            categories.add(aspect['category'])
    
    markup = dict()
    for id_, aspects in global_aspects.items():
        labels = []
        tokens = list(tokenize(texts[id_]))
        for token in tokens:
            label = 0
            for aspect in aspects.values():
                if aspect['type'] == aspect_type and aspect['mark'] == 'Rel':
                    if token.start == int(aspect['from']):
                        label = 1
                    elif token.start > int(aspect['from']) and token.stop <= int(aspect['to']):
                        if binary:
                            label = 1
                        else:
                            label = 2
            labels.append(label)
        markup[id_] = labels
        
    return markup, texts

def markup_text_senti(path):
    global_aspects = parse_aspects(path)
    texts = parse_texts(path)
    markup = defaultdict(dict)
    for id_, aspects in global_aspects.items():
        spans = []
        markup[id_]['text'] = texts[id_]
        for entity in aspects.values():
            spans.append((int(entity['from']), int(entity['to']), entity['polarity']))
            spans.append((int(entity['from']), int(entity['to']), entity['category']))
        markup[id_]['aspects'] = spans
    return markup

# %%
#Функции для получения разметки из xml файлов SemEval

def parse_texts_sem(path):
    root_node = ET.parse(path).getroot()
    texts = dict()
    for rev in root_node.findall('Review/sentences/sentence'):
        texts[rev.get('id')] = rev.find('text').text
    return texts

def parse_aspects_sem(path):
    root_node = ET.parse(path).getroot()
    global_aspects = dict()
    tag_list = ['to','from','polarity','category','target']
    for rev in root_node.findall('Review/sentences/sentence'):
        id_ = rev.get('id')
        aspects = dict()
        for i, a in enumerate(rev.findall('Opinions/Opinion')):
            aspects[i] = dict()
            for tag in tag_list:
                aspects[i][f'{tag}'] = a.get(tag)
        global_aspects[f'{id_}'] = aspects
    return global_aspects

def markup_text_sem(path):
    global_aspects = parse_aspects_sem(path)
    texts = parse_texts_sem(path)
    markup = defaultdict(dict)
    for id_, aspects in global_aspects.items():
        spans = []
        markup[id_]['text'] = texts[id_]
        for entity in aspects.values():
            spans.append((int(entity['from']), int(entity['to']), entity['polarity']))
            spans.append((int(entity['from']), int(entity['to']), entity['category']))
        markup[id_]['aspects'] = spans
    return markup

# %%
senti_texts_train = parse_texts('data/SentiRuEval_car_markup_train.xml')
senti_texts_test = parse_texts('data/SentiRuEval_car_markup_test.xml')

# %%
senti_texts = {**senti_texts_train,**senti_texts_test}

# %%
senti_aspects_train = parse_aspects('data/SentiRuEval_car_markup_train.xml')
senti_aspects_test = parse_aspects('data/SentiRuEval_car_markup_test.xml')
senti_aspects = {**senti_aspects_train,**senti_aspects_test}

# %%
spans_senti_train = dict()
for id_ in senti_aspects_train.keys():
    entities = []
    for entity in senti_aspects_train[id_].values():
        if entity['type'] == 'explicit':
            entities.append((int(entity['from']), int(entity['to']), entity['term'], entity['sentiment'], entity['category']))
    spans_senti_train[id_] = entities

# %%
spans_senti_test = dict()
for id_ in senti_aspects_test.keys():
    entities = []
    for entity in senti_aspects_test[id_].values():
        if entity['type'] == 'explicit':
            entities.append((int(entity['from']), int(entity['to']), entity['term'], entity['sentiment'], entity['category']))
    spans_senti_test[id_] = entities

# %%
united_aspects = dict()
for k in senti_texts.keys():
    try:
        united_aspects[k] = spans_senti[k] + spans[k]
    except KeyError:
        continue

# %%
# first, filter by indexes
left_in_sentiru = dict()
left_in_sem = dict()

for text_id in senti_texts.keys():
    try:
        sentiru_aspects = spans_senti[text_id]
        semru_aspects = spans[text_id]
    except KeyError:
        continue
    sim_i = []
    sim_j = []
    j_start = 0
    for i, semru_aspect in enumerate(semru_aspects):
        for j, sentiru_aspect in enumerate(sentiru_aspects[j_start:]):
            if semru_aspect[0] == sentiru_aspect[0] and semru_aspect[1] == sentiru_aspect[1]:
                sim_i.append(i)
                sim_j.append(j+j_start)
                j_start = j
                break
            elif semru_aspect[0] < sentiru_aspect[0]:
                break
    if len(sim_j) - len(sentiru_aspects) < 0:
        left_in_sentiru[text_id] = [a for j, a in enumerate(sentiru_aspects) if j not in sim_j]
    if len(sim_i) - len(semru_aspects) < 0:
        left_in_sem[text_id] = [a for i, a in enumerate(semru_aspects) if i not in sim_i]

# %%
# second, consider sem inclusions

left_in_sentiru_2 = dict()
left_in_sem_2 = dict()

for text_id in left_in_sem.keys():
    try:
        sentiru_aspects = left_in_sentiru[text_id]
        semru_aspects = left_in_sem[text_id]
    except KeyError:
        continue
    sim_i = []
    sim_j = []
    for i, semru_aspect in enumerate(semru_aspects):
        for j, sentiru_aspect in enumerate(sentiru_aspects):
            if semru_aspect[0] >= sentiru_aspect[0] and semru_aspect[1] <= sentiru_aspect[1]:
                sim_i.append(i)
                sim_j.append(j)
                break
            elif semru_aspect[0] < sentiru_aspect[0]:
                break
    if len(sim_j) - len(sentiru_aspects) < 0:
        left_in_sentiru_2[text_id] = [a for j, a in enumerate(sentiru_aspects) if j not in set(sim_j)]
    if len(sim_i) - len(semru_aspects) < 0:
        left_in_sem_2[text_id] = [a for i, a in enumerate(semru_aspects) if i not in set(sim_i)]

# %%
# third, consider senti inclusions

left_in_sentiru_3 = dict()
left_in_sem_3 = dict()

for text_id in left_in_sem_2.keys():
    try:
        sentiru_aspects = left_in_sentiru_2[text_id]
        semru_aspects = left_in_sem_2[text_id]
    except KeyError:
        continue
    sim_i = []
    sim_j = []
    for i, semru_aspect in enumerate(semru_aspects):
        for j, sentiru_aspect in enumerate(sentiru_aspects):
            if semru_aspect[0] <= sentiru_aspect[0] and semru_aspect[1] >= sentiru_aspect[1]:
                sim_i.append(i)
                sim_j.append(j)
                break
            elif semru_aspect[0] < sentiru_aspect[0]:
                break
    if len(sim_j) - len(sentiru_aspects) < 0:
        left_in_sentiru_3[text_id] = [a for j, a in enumerate(sentiru_aspects) if j not in set(sim_j)]
    if len(sim_i) - len(semru_aspects) < 0:
        left_in_sem_3[text_id] = [a for i, a in enumerate(semru_aspects) if i not in set(sim_i)]

# %%
# Аспекты из sentiru, не попоавшие в semru
morph = MorphAnalyzer()
abandoned = []
for text_id in left_in_sentiru_3.keys():
    for aspect in left_in_sentiru_3[text_id]:
        tokens = list(tokenize(aspect[2].lower()))
        if len(tokens)>1:
            for t in tokens:
                lemma = morph.parse(t.text)[0].normal_form
                abandoned.append((aspect[0]+t.start, aspect[0]+t.stop, lemma, aspect[3], aspect[4], text_id))
            abandoned.append((aspect[0], aspect[1], aspect[2].lower().strip('"'), aspect[3], aspect[4], text_id))
        else:
            abandoned.append((aspect[0], aspect[1], morph.parse(aspect[2])[0].normal_form.strip('"'), aspect[3], aspect[4], text_id))

# %%
abandoned_df = pd.DataFrame(abandoned, columns = ['from', 'to', 'text', 'sentiment', 'category', 'review_id'])

# %%
#убираем нейтральные
abandoned_df['polar'] = ((abandoned_df.sentiment != 'neutral') & (abandoned_df.sentiment != 'both'))*1

# %%
abandoned_df
# Out:
#       from   to               text sentiment category review_id  polar
# 0       43   52          заведение   neutral    Whole     16137      0
# 1      446  455           ресторан   neutral    Whole     16137      0
# 2      642  650           посадить   neutral  Service     16137      0
# 3      651  654                 мы   neutral  Service     16137      0
# 4      655  657                 за   neutral  Service     16137      0
# ...    ...  ...                ...       ...      ...       ...    ...
# 1269   791  808  салат с говядиной  positive     Food     28258      1
# 1270   811  819           карпаччо  positive     Food     28258      1
# 1271   822  826               цена   neutral    Price     28258      0
# 1272   870  876              визит  positive    Whole     28258      1
# 1273   931  936             поесть  positive     Food     28258      1
#
# [1274 rows x 7 columns]

# %%
abandoned_df.category.unique()
# Out:
# array(['Whole', 'Service', 'Food', 'Price', 'Interior'], dtype=object)

# %%
abandoned_df[abandoned_df.category=='Whole'].groupby('text').agg({'review_id':'count',
                                                                 'polar':'sum'}).sort_values('review_id', ascending=False).iloc[:30]
# Out:
#                     review_id  polar
# text
# ресторан                   82     31
# заведение                  23      9
# "                          22      6
# место                      21     15
# вечер                      12     12
# провести                    6      6
# впечатление                 6      6
# время                       6      6
# посещение                   4      4
# кафе                        4      2
# город                       4      2
# небо                        3      0
# ресторанчик                 3      1
# паб                         3      2
# провели время               3      3
# праздник                    2      2
# '                           2      0
# провести время              2      2
# палкин                      2      1
# общий                       2      2
# визит                       2      2
# аппетит                     2      0
# ресторане "фаворит          1      0
# провести там время          1      1
# отзыв                       1      1
# чувствуешь себя             1      1
# чувствовать                 1      1
# хутор                       1      0
# фаворит                     1      0
# там                         1      1

# %%
abandoned_df[abandoned_df.category=='Interior'].groupby('text').agg({'review_id':'count',
                                                                 'polar':'sum'}).sort_values('review_id', ascending=False).iloc[:30]
# Out:
#                     review_id  polar
# text
# зал                        12      9
# столик                      6      4
# интерьер                    3      2
# потанцевать                 2      2
# в                           2      2
# атмосфера                   2      2
# оформить                    2      2
# стена                       2      2
# музыка                      2      1
# концерт                     2      0
# свободный                   2      1
# дискотека                   2      2
# для                         2      2
# стол                        1      1
# спокойный                   1      1
# свободный столик            1      1
# /                           1      0
# свободные столики           1      0
# светильник                  1      0
# саксофонист                 1      1
# рояль                       1      1
# пыль на полках              1      1
# пыль                        1      1
# светильники/люстры          1      0
# танец                       1      1
# стул                        1      1
# украшение                   1      1
# штора                       1      1
# человек                     1      1
# фотан                       1      1

# %%
abandoned_df[abandoned_df.category=='Food'].groupby('text').agg({'review_id':'count',
                                                                 'polar':'sum'}).sort_values('review_id', ascending=False).iloc[:30]
# Out:
#            review_id  polar
# text
# блюдо             21      9
# кухня             18     11
# с                 14      6
# салат             12      2
# пиво              11      0
# напиток           10      1
# готовить           9      9
# еда                8      2
# выпить             7      2
# горячий            7      1
# десерт             6      4
# закуска            6      1
# чай                6      2
# поесть             6      6
# сушить             5      1
# паста              5      0
# из                 5      3
# меню               5      3
# мясо               5      1
# вкус               5      5
# гриб               4      4
# "                  4      0
# соус               4      3
# порция             4      4
# съесть             4      1
# рыба               4      2
# говядина           4      3
# пообедать          4      0
# поужинать          3      0
# креветка           3      0

# %%
abandoned_df[abandoned_df.category=='Service'].groupby('text').agg({'review_id':'count',
                                                                 'polar':'sum'}).sort_values('review_id', ascending=False).iloc[:30]
# Out:
#                  review_id  polar
# text
# встретить               19     16
# заказать                15      5
# столик                  13      4
# принести                12     11
# обслуживать             12     12
# заказ                   11     11
# проводить               11      9
# обслуживание             9      5
# стол                     9      7
# официант                 8      4
# помочь                   6      6
# обслужить                6      6
# заказывать               5      1
# предложить               4      3
# ждать                    4      4
# меню                     4      4
# сервис                   4      2
# девушка                  4      2
# молодой                  3      2
# приносить                3      3
# за                       3      2
# молодой человек          3      2
# к                        3      2
# подходить                3      3
# готовить                 3      2
# встречать                3      3
# человек                  3      2
# убирать                  3      3
# принять                  2      2
# персонал                 2      2

# %%
abandoned_df[abandoned_df.category=='Price'].groupby('text').agg({'review_id':'count',
                                                                 'polar':'sum'}).sort_values('review_id', ascending=False).iloc[:30]
# Out:
#                              review_id  polar
# text
# цена                                34     31
# счёт                                 8      5
# соотношение                          4      4
# качество                             4      4
# скидка                               3      3
# ценник                               3      3
# чек                                  2      1
# и                                    2      2
# плата                                1      1
# предоплата                           1      1
# качество цене соответствует          1      1
# соответствовать                      1      1
# бесплатно                            1      1
# соотношение цена-качество            1      1
# соотношение цена/качество            1      1
# соотношение цены и качества          1      1
# соотношении цены и качества          1      1
# категория                            1      0
# цена-качество                        1      1
# бесплатный                           1      1
# ценовой                              1      0
# ценовой категории                    1      0
# /                                    1      1

# %%
#оставляем следующие аспекты
interesting_words = ["цена", "счет", "столик", "заказ", 
                    "стол", "официант", "сервис", "встретить",
                    "обслуживать", "обслужить", "помочь", 
                    "меню", "блюдо", "кухня", "салат", 
                    "еда", "поесть", "готовить", "вкус", 
                    "зал", "интерьер", "атмосфера", "ресторан", 
                    "заведение", "место"]

# %%
interesting_df = abandoned_df[abandoned_df['text'].isin(interesting_words)]
interesting_df = interesting_df[interesting_df['polar'] == 1]

# %%
interesting_df.sentiment.value_counts()
# Out:
# positive    197
# negative     31
# Name: sentiment, dtype: int64

# %%
interesting_df.category.value_counts()
# Out:
# Service     76
# Whole       55
# Food        48
# Price       31
# Interior    18
# Name: category, dtype: int64

# %% [markdown]
# ## Добавляем в разметку

# %%
additional_spans = []
for id_ in interesting_df.review_id.unique():
    new_df = interesting_df[interesting_df.review_id == id_]
    a_new_df = abandoned_df[abandoned_df.review_id == id_][abandoned_df[abandoned_df.review_id == id_].polar==1]
    for val in new_df.values:
        start, stop, token, sentiment, cat, rev_id, pol = val
        inter_df = a_new_df[a_new_df['from']<=start]
        inter_df = inter_df[inter_df['to']>=stop]
        if len(inter_df) == 1:
            additional_spans.append((start, stop, token, sentiment, cat, rev_id))
        else:
            additional_spans.append(tuple(inter_df[inter_df.text != token].values[0][:-1]))

# %%
additional_spans_list = list(set(additional_spans))
for i in additional_spans_list:
    id_ = i[-1]
    key_indicator = 0
    for sp in spans.keys():
        if sp == id_:
            spans[sp].append((i[0], i[1], i[3]))
            key_indicator += 1
    if key_indicator == 0:
        print(i)

# %%
spans
# Out:
# {'15758': [(60, 69, 'neutral'),
#   (131, 136, 'positive'),
#   (153, 165, 'positive'),
#   (177, 180, 'positive'),
#   (320, 328, 'neutral'),
#   (389, 397, 'positive'),
#   (475, 479, 'neutral')],
#  '2073': [(97, 106, 'negative'),
#   (223, 231, 'neutral'),
#   (242, 247, 'neutral'),
#   (314, 326, 'negative'),
#   (377, 387, 'negative'),
#   (899, 911, 'negative'),
#   (974, 983, 'negative'),
#   (1179, 1187, 'negative')],
#  '24713': [(52, 55, 'positive'),
#   (116, 120, 'neutral'),
#   (166, 173, 'negative'),
#   (213, 227, 'negative'),
#   (246, 251, 'negative'),
#   (253, 259, 'negative'),
#   (307, 313, 'negative'),
#   (448, 451, 'positive'),
#   (525, 532, 'negative'),
#   (620, 623, 'negative'),
#   (833, 842, 'negative'),
#   (502, 509, 'negative')],
#  '16630': [(25, 35, 'positive'),
#   (56, 64, 'positive'),
#   (85, 97, 'positive'),
#   (99, 102, 'positive'),
#   (244, 253, 'positive'),
#   (294, 302, 'positive'),
#   (315, 320, 'positive')],
#  '27841': [(71, 95, 'positive'),
#   (161, 165, 'positive'),
#   (175, 182, 'positive'),
#   (264, 268, 'neutral'),
#   (352, 359, 'positive'),
#   (377, 387, 'positive'),
#   (390, 397, 'positive'),
#   (417, 426, 'positive'),
#   (430, 447, 'positive'),
#   (460, 468, 'positive'),
#   (515, 520, 'negative'),
#   (573, 591, 'positive'),
#   (654, 662, 'neutral'),
#   (750, 762, 'positive'),
#   (839, 847, 'positive')],
#  '12880': [(347, 356, 'positive'),
#   (443, 448, 'positive'),
#   (470, 478, 'positive'),
#   (489, 496, 'positive'),
#   (508, 512, 'negative'),
#   (532, 541, 'positive'),
#   (563, 567, 'neutral'),
#   (590, 595, 'negative'),
#   (599, 607, 'negative'),
#   (689, 695, 'negative'),
#   (936, 945, 'negative'),
#   (1083, 1091, 'negative'),
#   (1098, 1107, 'negative')],
#  '32040': [(8, 16, 'positive'),
#   (28, 41, 'neutral'),
#   (99, 107, 'positive'),
#   (153, 170, 'positive'),
#   (181, 187, 'positive'),
#   (203, 208, 'neutral'),
#   (238, 243, 'negative'),
#   (403, 411, 'positive')],
#  '19111': [(65, 73, 'positive'),
#   (90, 100, 'positive'),
#   (287, 294, 'positive'),
#   (346, 355, 'positive'),
#   (495, 498, 'positive'),
#   (508, 514, 'neutral'),
#   (534, 543, 'positive'),
#   (622, 646, 'negative'),
#   (733, 738, 'positive'),
#   (835, 848, 'neutral'),
#   (896, 904, 'positive')],
#  '10847': [(95, 105, 'positive'),
#   (233, 243, 'positive'),
#   (276, 285, 'positive'),
#   (330, 343, 'positive'),
#   (346, 355, 'positive'),
#   (394, 403, 'positive'),
#   (670, 676, 'positive'),
#   (684, 690, 'positive'),
#   (727, 761, 'positive'),
#   (848, 853, 'positive'),
#   (877, 881, 'positive'),
#   (960, 964, 'positive'),
#   (1056, 1070, 'positive'),
#   (1075, 1087, 'positive'),
#   (1091, 1101, 'positive')],
#  '10354': [(113, 122, 'positive'),
#   (113, 122, 'positive'),
#   (133, 139, 'positive'),
#   (229, 242, 'positive'),
#   (378, 383, 'positive'),
#   (410, 422, 'positive'),
#   (429, 447, 'positive'),
#   (501, 514, 'positive'),
#   (614, 623, 'positive'),
#   (857, 861, 'negative'),
#   (990, 1025, 'positive'),
#   (1040, 1058, 'positive'),
#   (1060, 1070, 'positive'),
#   (1084, 1091, 'positive'),
#   (1109, 1122, 'positive')],
#  '21059': [(374, 379, 'positive'),
#   (398, 404, 'positive'),
#   (458, 467, 'positive'),
#   (468, 480, 'positive'),
#   (511, 544, 'positive'),
#   (559, 562, 'positive'),
#   (726, 742, 'positive'),
#   (157, 162, 'negative')],
#  '25960': [(75, 83, 'positive'),
#   (144, 156, 'positive'),
#   (182, 186, 'positive'),
#   (291, 297, 'negative'),
#   (416, 420, 'negative'),
#   (464, 467, 'positive'),
#   (562, 567, 'negative')],
#  '2965': [(351, 359, 'positive'),
#   (472, 482, 'positive'),
#   (504, 517, 'positive'),
#   (557, 569, 'positive'),
#   (623, 632, 'positive'),
#   (706, 718, 'positive'),
#   (742, 747, 'positive'),
#   (795, 799, 'positive'),
#   (913, 919, 'positive'),
#   (928, 934, 'positive'),
#   (1111, 1119, 'positive'),
#   (1147, 1154, 'positive'),
#   (1157, 1163, 'positive'),
#   (837, 842, 'positive'),
#   (434, 442, 'positive'),
#   (943, 947, 'positive')],
#  '37036': [(108, 129, 'positive'),
#   (131, 155, 'positive'),
#   (173, 180, 'positive'),
#   (226, 233, 'positive'),
#   (234, 239, 'positive'),
#   (290, 298, 'positive'),
#   (317, 321, 'positive'),
#   (439, 448, 'positive')],
#  '10985': [(264, 284, 'negative'),
#   (288, 297, 'negative'),
#   (312, 330, 'negative'),
#   (402, 411, 'negative'),
#   (443, 452, 'negative'),
#   (543, 547, 'negative'),
#   (602, 613, 'negative'),
#   (701, 709, 'positive'),
#   (711, 718, 'positive'),
#   (720, 723, 'positive'),
#   (730, 737, 'positive'),
#   (739, 745, 'positive'),
#   (766, 769, 'positive'),
#   (811, 817, 'negative'),
#   (820, 830, 'negative'),
#   (882, 892, 'negative')],
#  '11267': [(30, 35, 'negative'),
#   (37, 49, 'negative'),
#   (84, 93, 'negative'),
#   (290, 293, 'neutral'),
#   (304, 309, 'neutral'),
#   (367, 379, 'negative'),
#   (475, 479, 'negative'),
#   (562, 570, 'negative'),
#   (652, 657, 'negative')],
#  '27569': [(123, 128, 'positive'),
#   (132, 144, 'positive'),
#   (148, 158, 'positive'),
#   (165, 173, 'positive'),
#   (446, 449, 'positive'),
#   (481, 497, 'positive'),
#   (547, 553, 'neutral'),
#   (631, 639, 'positive'),
#   (641, 649, 'positive'),
#   (736, 750, 'negative'),
#   (771, 777, 'positive'),
#   (801, 811, 'positive'),
#   (917, 923, 'positive'),
#   (917, 923, 'positive')],
#  '16378': [(130, 135, 'positive'),
#   (138, 147, 'positive'),
#   (149, 156, 'positive'),
#   (218, 225, 'positive'),
#   (243, 247, 'positive'),
#   (276, 290, 'positive'),
#   (456, 464, 'neutral'),
#   (528, 535, 'negative'),
#   (567, 587, 'negative'),
#   (640, 651, 'positive'),
#   (714, 731, 'negative'),
#   (753, 765, 'positive'),
#   (787, 799, 'positive'),
#   (940, 945, 'positive'),
#   (1205, 1209, 'positive'),
#   (575, 587, 'negative'),
#   (376, 391, 'negative'),
#   (1154, 1158, 'positive')],
#  '34307': [(47, 56, 'negative'),
#   (107, 111, 'negative'),
#   (166, 171, 'negative'),
#   (825, 834, 'negative'),
#   (900, 904, 'negative'),
#   (919, 925, 'negative'),
#   (949, 958, 'negative'),
#   (1065, 1077, 'negative')],
#  '12814': [(36, 41, 'positive'),
#   (237, 247, 'negative'),
#   (408, 413, 'negative')],
#  '35904': [(81, 87, 'positive'),
#   (127, 131, 'positive'),
#   (134, 142, 'positive'),
#   (153, 161, 'positive'),
#   (178, 188, 'positive'),
#   (264, 269, 'positive'),
#   (315, 321, 'positive'),
#   (351, 364, 'positive')],
#  '36725': [(50, 60, 'positive'),
#   (71, 76, 'positive'),
#   (86, 98, 'positive'),
#   (111, 119, 'positive'),
#   (151, 159, 'positive'),
#   (240, 243, 'positive'),
#   (257, 263, 'positive'),
#   (368, 374, 'neutral'),
#   (407, 414, 'positive'),
#   (416, 424, 'positive'),
#   (426, 441, 'positive'),
#   (444, 454, 'positive')],
#  '28258': [(78, 87, 'positive'),
#   (161, 169, 'positive'),
#   (208, 214, 'positive'),
#   (291, 298, 'positive'),
#   (455, 459, 'positive'),
#   (551, 562, 'positive'),
#   (670, 673, 'positive'),
#   (690, 695, 'positive'),
#   (727, 732, 'positive'),
#   (741, 750, 'positive'),
#   (752, 758, 'positive'),
#   (965, 973, 'positive'),
#   (983, 990, 'positive'),
#   (993, 1002, 'positive'),
#   (791, 808, 'positive'),
#   (89, 94, 'positive'),
#   (931, 936, 'positive'),
#   (270, 281, 'positive'),
#   (370, 377, 'positive'),
#   (69, 77, 'positive')],
#  '19467': [(595, 605, 'positive'),
#   (698, 704, 'neutral'),
#   (775, 780, 'positive'),
#   (805, 809, 'positive'),
#   (838, 844, 'positive'),
#   (847, 852, 'positive'),
#   (873, 881, 'positive'),
#   (933, 940, 'positive')],
#  '34761': [(337, 359, 'positive'),
#   (409, 417, 'positive'),
#   (562, 567, 'positive'),
#   (599, 603, 'positive'),
#   (660, 668, 'positive'),
#   (759, 763, 'positive'),
#   (765, 773, 'positive'),
#   (793, 803, 'positive'),
#   (950, 956, 'positive')],
#  '36359': [(242, 248, 'positive'),
#   (420, 425, 'positive'),
#   (420, 425, 'positive'),
#   (579, 591, 'positive'),
#   (623, 632, 'positive')],
#  '36948': [(74, 78, 'positive'),
#   (88, 91, 'positive'),
#   (103, 110, 'positive'),
#   (122, 131, 'positive'),
#   (148, 160, 'positive'),
#   (269, 284, 'negative'),
#   (293, 301, 'negative'),
#   (327, 334, 'negative'),
#   (377, 389, 'positive'),
#   (423, 429, 'positive'),
#   (479, 487, 'positive'),
#   (261, 265, 'positive')],
#  '28745': [(71, 78, 'positive'),
#   (145, 150, 'positive'),
#   (160, 163, 'positive'),
#   (176, 181, 'positive'),
#   (184, 197, 'positive'),
#   (200, 206, 'neutral'),
#   (229, 235, 'positive'),
#   (249, 259, 'positive')],
#  '29395': [(0, 8, 'positive'),
#   (204, 209, 'positive'),
#   (225, 237, 'positive'),
#   (403, 413, 'positive'),
#   (555, 559, 'positive'),
#   (657, 663, 'positive'),
#   (932, 941, 'positive')],
#  '16714': [(230, 238, 'neutral'),
#   (282, 286, 'neutral'),
#   (315, 320, 'positive'),
#   (339, 347, 'positive'),
#   (350, 355, 'positive'),
#   (373, 379, 'positive'),
#   (412, 420, 'positive'),
#   (472, 480, 'neutral'),
#   (559, 564, 'positive'),
#   (658, 672, 'positive'),
#   (782, 788, 'positive')],
#  '3385': [(81, 88, 'positive'),
#   (141, 151, 'positive'),
#   (332, 342, 'negative'),
#   (1057, 1065, 'negative'),
#   (1145, 1154, 'positive')],
#  '35620': [(216, 224, 'positive'),
#   (382, 395, 'positive'),
#   (397, 409, 'positive'),
#   (434, 437, 'positive'),
#   (451, 467, 'positive'),
#   (581, 589, 'positive'),
#   (778, 787, 'positive'),
#   (279, 286, 'positive'),
#   (117, 126, 'positive')],
#  '31004': [(271, 279, 'positive'),
#   (384, 391, 'negative'),
#   (526, 531, 'negative'),
#   (603, 607, 'negative'),
#   (617, 623, 'negative'),
#   (644, 647, 'negative'),
#   (688, 697, 'negative'),
#   (851, 875, 'neutral'),
#   (943, 948, 'negative'),
#   (943, 948, 'negative')],
#  '34889': [(254, 266, 'positive'),
#   (286, 292, 'positive'),
#   (332, 354, 'positive'),
#   (383, 392, 'positive'),
#   (414, 422, 'positive'),
#   (432, 439, 'positive'),
#   (479, 483, 'positive'),
#   (485, 494, 'positive'),
#   (680, 687, 'positive'),
#   (866, 871, 'positive'),
#   (913, 923, 'positive'),
#   (988, 992, 'positive'),
#   (1199, 1204, 'positive')],
#  '14190': [(251, 259, 'positive'),
#   (479, 484, 'positive'),
#   (756, 762, 'positive'),
#   (791, 795, 'positive'),
#   (829, 839, 'positive'),
#   (944, 953, 'positive'),
#   (956, 964, 'positive')],
#  '36166': [(51, 59, 'positive'),
#   (144, 152, 'positive'),
#   (197, 206, 'positive'),
#   (216, 219, 'positive'),
#   (231, 237, 'positive'),
#   (352, 368, 'positive'),
#   (370, 380, 'positive'),
#   (505, 510, 'positive')],
#  '12591': [(446, 465, 'positive'),
#   (505, 514, 'positive'),
#   (527, 535, 'positive'),
#   (549, 557, 'positive'),
#   (583, 592, 'positive'),
#   (611, 620, 'positive'),
#   (649, 660, 'positive'),
#   (679, 687, 'positive'),
#   (695, 699, 'positive'),
#   (803, 809, 'positive'),
#   (875, 887, 'positive'),
#   (1020, 1025, 'positive')],
#  '33591': [(9, 13, 'positive'),
#   (107, 110, 'positive'),
#   (120, 125, 'positive'),
#   (127, 137, 'positive'),
#   (148, 161, 'positive'),
#   (191, 195, 'positive'),
#   (349, 365, 'positive'),
#   (375, 381, 'positive'),
#   (383, 388, 'positive'),
#   (437, 440, 'positive'),
#   (562, 569, 'negative'),
#   (645, 658, 'positive'),
#   (700, 707, 'positive'),
#   (730, 736, 'positive'),
#   (764, 769, 'positive'),
#   (764, 769, 'neutral'),
#   (889, 899, 'positive')],
#  '20086': [(211, 219, 'positive'),
#   (266, 272, 'positive'),
#   (274, 278, 'neutral'),
#   (274, 278, 'neutral'),
#   (430, 454, 'neutral'),
#   (579, 587, 'neutral'),
#   (689, 696, 'neutral'),
#   (722, 729, 'negative')],
#  '11058': [(522, 532, 'neutral'), (584, 591, 'positive')],
#  '20021': [(106, 113, 'negative'),
#   (291, 299, 'positive'),
#   (306, 319, 'positive'),
#   (350, 356, 'positive'),
#   (383, 390, 'positive'),
#   (393, 402, 'positive'),
#   (404, 412, 'positive'),
#   (452, 459, 'positive'),
#   (461, 472, 'positive'),
#   (512, 524, 'positive'),
#   (571, 577, 'negative'),
#   (613, 616, 'negative'),
#   (639, 654, 'positive'),
#   (657, 662, 'positive'),
#   (761, 770, 'negative'),
#   (903, 909, 'positive'),
#   (928, 935, 'positive'),
#   (997, 1002, 'positive'),
#   (1117, 1130, 'positive'),
#   (1173, 1181, 'positive'),
#   (959, 967, 'positive')],
#  '12203': [(680, 689, 'positive'),
#   (759, 768, 'positive'),
#   (910, 919, 'positive')],
#  '13835': [(71, 79, 'positive'),
#   (140, 148, 'neutral'),
#   (247, 255, 'positive'),
#   (309, 314, 'positive'),
#   (332, 344, 'positive'),
#   (346, 371, 'positive'),
#   (402, 408, 'positive'),
#   (429, 442, 'positive'),
#   (444, 456, 'positive'),
#   (479, 509, 'positive'),
#   (548, 557, 'positive'),
#   (599, 609, 'positive'),
#   (638, 651, 'positive'),
#   (723, 736, 'positive'),
#   (784, 792, 'positive')],
#  '19503': [(67, 79, 'positive'),
#   (134, 147, 'positive'),
#   (200, 206, 'positive'),
#   (234, 237, 'positive'),
#   (270, 286, 'positive'),
#   (298, 303, 'neutral'),
#   (390, 398, 'positive'),
#   (406, 428, 'positive'),
#   (470, 488, 'positive'),
#   (304, 315, 'positive'),
#   (512, 518, 'positive'),
#   (239, 250, 'positive'),
#   (158, 167, 'positive'),
#   (383, 388, 'positive')],
#  '20862': [(343, 353, 'negative')],
#  '36781': [(116, 126, 'negative'),
#   (456, 464, 'negative'),
#   (957, 965, 'negative'),
#   (1022, 1029, 'negative'),
#   (1044, 1054, 'negative'),
#   (1069, 1076, 'negative')],
#  '33912': [(420, 428, 'positive'),
#   (510, 518, 'positive'),
#   (621, 624, 'positive'),
#   (789, 797, 'positive'),
#   (809, 813, 'negative'),
#   (809, 813, 'positive'),
#   (844, 852, 'positive'),
#   (984, 1000, 'positive')],
#  '32995': [(159, 165, 'negative'),
#   (434, 438, 'positive'),
#   (465, 483, 'positive'),
#   (528, 531, 'neutral'),
#   (564, 570, 'neutral'),
#   (762, 767, 'positive'),
#   (795, 808, 'positive'),
#   (308, 331, 'negative'),
#   (660, 668, 'positive')],
#  '12863': [(78, 88, 'positive'),
#   (90, 98, 'positive'),
#   (121, 130, 'positive'),
#   (182, 187, 'positive'),
#   (190, 194, 'positive'),
#   (325, 331, 'negative'),
#   (488, 512, 'positive'),
#   (581, 587, 'positive')],
#  '33952': [(72, 81, 'positive'),
#   (125, 139, 'positive'),
#   (156, 164, 'positive'),
#   (213, 217, 'positive'),
#   (213, 217, 'positive'),
#   (272, 276, 'neutral'),
#   (384, 401, 'positive'),
#   (511, 517, 'positive'),
#   (611, 631, 'positive'),
#   (805, 816, 'positive')],
#  '36321': [(57, 67, 'positive'),
#   (130, 139, 'positive'),
#   (263, 271, 'positive'),
#   (325, 334, 'positive'),
#   (368, 382, 'positive'),
#   (368, 382, 'positive'),
#   (584, 589, 'positive'),
#   (675, 683, 'negative'),
#   (728, 734, 'positive'),
#   (728, 734, 'positive'),
#   (828, 840, 'positive'),
#   (975, 991, 'positive'),
#   (993, 1002, 'positive'),
#   (1066, 1071, 'positive'),
#   (361, 366, 'positive'),
#   (817, 826, 'positive'),
#   (750, 755, 'positive'),
#   (432, 438, 'positive'),
#   (801, 812, 'positive')],
#  '32771': [(482, 490, 'positive'),
#   (492, 500, 'neutral'),
#   (583, 591, 'positive'),
#   (683, 688, 'positive'),
#   (762, 774, 'positive'),
#   (941, 946, 'positive'),
#   (1040, 1055, 'positive'),
#   (1137, 1145, 'positive'),
#   (1182, 1187, 'positive'),
#   (1194, 1202, 'positive'),
#   (1209, 1215, 'positive'),
#   (1240, 1257, 'positive'),
#   (322, 331, 'positive')],
#  '36085': [(187, 191, 'positive'),
#   (209, 217, 'positive'),
#   (237, 242, 'positive'),
#   (310, 318, 'positive'),
#   (455, 460, 'positive'),
#   (470, 484, 'positive')],
#  '15363': [(74, 83, 'positive'),
#   (134, 141, 'negative'),
#   (328, 340, 'positive'),
#   (496, 501, 'negative'),
#   (524, 541, 'negative'),
#   (567, 574, 'negative'),
#   (648, 665, 'neutral'),
#   (689, 696, 'positive'),
#   (834, 838, 'negative'),
#   (876, 891, 'positive'),
#   (305, 324, 'positive'),
#   (360, 369, 'positive')],
#  '225': [(171, 183, 'positive'),
#   (206, 214, 'neutral'),
#   (500, 504, 'neutral'),
#   (702, 706, 'positive'),
#   (943, 955, 'negative'),
#   (1148, 1156, 'positive')],
#  '35790': [(53, 59, 'positive'),
#   (53, 59, 'positive'),
#   (61, 69, 'positive'),
#   (71, 82, 'positive'),
#   (144, 149, 'positive'),
#   (246, 254, 'positive'),
#   (335, 342, 'negative'),
#   (430, 437, 'negative'),
#   (608, 613, 'neutral'),
#   (620, 625, 'positive'),
#   (649, 657, 'neutral'),
#   (819, 822, 'positive'),
#   (836, 848, 'neutral')],
#  '37070': [(82, 91, 'positive'),
#   (116, 121, 'positive'),
#   (123, 131, 'positive'),
#   (132, 135, 'positive'),
#   (143, 146, 'positive'),
#   (205, 210, 'positive')],
#  '33816': [(63, 75, 'positive'),
#   (96, 109, 'positive'),
#   (154, 163, 'positive'),
#   (212, 224, 'positive'),
#   (238, 243, 'positive'),
#   (297, 309, 'positive'),
#   (322, 336, 'positive'),
#   (261, 286, 'positive')],
#  '27629': [(192, 202, 'negative'),
#   (437, 458, 'negative'),
#   (518, 523, 'negative'),
#   (613, 625, 'negative'),
#   (669, 677, 'positive'),
#   (699, 705, 'negative'),
#   (722, 731, 'negative')],
#  '33665': [(37, 59, 'positive'),
#   (83, 92, 'positive'),
#   (245, 250, 'positive'),
#   (356, 368, 'positive'),
#   (399, 417, 'positive'),
#   (420, 427, 'positive'),
#   (452, 467, 'positive'),
#   (497, 506, 'positive'),
#   (516, 530, 'positive'),
#   (542, 551, 'positive'),
#   (573, 581, 'positive'),
#   (723, 726, 'positive'),
#   (903, 909, 'positive'),
#   (964, 972, 'positive'),
#   (1065, 1073, 'positive'),
#   (1140, 1152, 'positive'),
#   (136, 144, 'positive')],
#  '31071': [(11, 20, 'neutral'),
#   (83, 86, 'negative'),
#   (247, 252, 'negative'),
#   (339, 351, 'negative'),
#   (420, 429, 'negative'),
#   (531, 541, 'negative'),
#   (630, 650, 'negative'),
#   (726, 734, 'positive'),
#   (737, 754, 'positive'),
#   (778, 783, 'neutral'),
#   (825, 855, 'neutral'),
#   (867, 897, 'neutral'),
#   (952, 957, 'positive')],
#  '16322': [(86, 90, 'neutral'),
#   (92, 101, 'neutral'),
#   (104, 108, 'neutral'),
#   (189, 199, 'positive'),
#   (210, 214, 'positive'),
#   (238, 243, 'positive'),
#   (268, 279, 'positive'),
#   (1117, 1123, 'positive')],
#  '32721': [(137, 145, 'positive'),
#   (168, 172, 'positive'),
#   (180, 186, 'positive'),
#   (219, 229, 'positive'),
#   (401, 405, 'positive'),
#   (499, 504, 'positive'),
#   (564, 569, 'positive'),
#   (599, 606, 'positive'),
#   (881, 887, 'positive'),
#   (954, 958, 'negative'),
#   (973, 976, 'negative'),
#   (1041, 1048, 'negative'),
#   (626, 631, 'positive'),
#   (275, 284, 'positive')],
#  '33405': [(81, 89, 'positive'),
#   (130, 136, 'positive'),
#   (146, 151, 'positive'),
#   (160, 165, 'positive'),
#   (176, 183, 'positive'),
#   (245, 257, 'positive'),
#   (279, 286, 'positive'),
#   (296, 311, 'positive'),
#   (343, 353, 'positive'),
#   (424, 427, 'positive'),
#   (464, 471, 'positive'),
#   (728, 733, 'positive'),
#   (745, 750, 'positive'),
#   (774, 780, 'positive'),
#   (782, 798, 'positive'),
#   (890, 895, 'positive')],
#  '12678': [(14, 23, 'positive'),
#   (55, 63, 'positive'),
#   (74, 79, 'positive'),
#   (95, 101, 'negative'),
#   (217, 224, 'positive'),
#   (230, 251, 'positive'),
#   (310, 322, 'positive'),
#   (342, 351, 'positive'),
#   (385, 394, 'positive'),
#   (438, 456, 'positive'),
#   (480, 489, 'positive')],
#  '2364': [(117, 122, 'positive'),
#   (131, 136, 'positive'),
#   (148, 156, 'positive'),
#   (196, 205, 'positive'),
#   (246, 269, 'positive'),
#   (491, 500, 'positive'),
#   (259, 269, 'positive')],
#  '1200': [(57, 62, 'positive'),
#   (57, 62, 'positive'),
#   (97, 105, 'positive'),
#   (107, 117, 'positive'),
#   (128, 131, 'positive'),
#   (141, 149, 'positive'),
#   (277, 285, 'neutral'),
#   (339, 347, 'positive'),
#   (1054, 1064, 'negative')],
#  '13225': [(9, 12, 'positive'),
#   (73, 81, 'positive'),
#   (97, 101, 'positive'),
#   (97, 101, 'positive'),
#   (123, 128, 'positive'),
#   (159, 164, 'positive'),
#   (253, 265, 'positive'),
#   (314, 323, 'positive'),
#   (334, 343, 'positive'),
#   (344, 353, 'positive')],
#  '27040': [],
#  '2089': [(0, 4, 'positive'), (28, 40, 'negative'), (497, 504, 'negative')],
#  '27169': [(211, 216, 'positive'),
#   (239, 247, 'positive'),
#   (270, 280, 'positive'),
#   (282, 294, 'positive'),
#   (336, 341, 'positive'),
#   (336, 341, 'positive'),
#   (411, 417, 'positive'),
#   (453, 461, 'positive'),
#   (479, 484, 'positive'),
#   (547, 555, 'positive'),
#   (557, 571, 'positive'),
#   (587, 595, 'positive'),
#   (684, 696, 'positive'),
#   (988, 997, 'positive'),
#   (1032, 1036, 'positive'),
#   (1038, 1042, 'positive'),
#   (1044, 1059, 'positive')],
#  '27925': [(142, 154, 'positive'),
#   (176, 186, 'positive'),
#   (252, 258, 'positive'),
#   (282, 299, 'positive'),
#   (540, 544, 'positive'),
#   (562, 568, 'positive'),
#   (562, 568, 'positive'),
#   (662, 686, 'positive'),
#   (662, 686, 'positive'),
#   (793, 808, 'positive'),
#   (882, 894, 'positive'),
#   (1020, 1034, 'positive'),
#   (1104, 1113, 'positive'),
#   (276, 280, 'positive'),
#   (189, 206, 'positive')],
#  '343': [(60, 63, 'positive'),
#   (87, 96, 'positive'),
#   (110, 118, 'positive'),
#   (159, 179, 'positive'),
#   (195, 223, 'positive'),
#   (237, 251, 'positive'),
#   (762, 770, 'positive')],
#  '10239': [(325, 333, 'neutral'),
#   (372, 382, 'positive'),
#   (396, 408, 'neutral'),
#   (506, 532, 'positive'),
#   (528, 532, 'positive'),
#   (766, 784, 'positive'),
#   (954, 963, 'positive'),
#   (981, 990, 'positive'),
#   (1028, 1033, 'positive')],
#  '31140': [(57, 67, 'positive'),
#   (129, 134, 'positive'),
#   (136, 148, 'positive'),
#   (166, 176, 'positive'),
#   (255, 263, 'positive'),
#   (255, 263, 'positive'),
#   (277, 286, 'positive'),
#   (296, 299, 'positive'),
#   (311, 319, 'positive'),
#   (347, 352, 'positive'),
#   (395, 402, 'positive')],
#  '32859': [(110, 119, 'positive'),
#   (215, 228, 'positive'),
#   (425, 455, 'positive'),
#   (504, 509, 'positive'),
#   (504, 509, 'positive'),
#   (594, 597, 'positive'),
#   (660, 668, 'positive'),
#   (740, 744, 'positive'),
#   (789, 798, 'positive'),
#   (410, 419, 'positive'),
#   (705, 714, 'positive')],
#  '10942': [(90, 98, 'positive'),
#   (108, 120, 'positive'),
#   (143, 148, 'positive'),
#   (179, 184, 'positive'),
#   (313, 318, 'positive'),
#   (328, 334, 'positive'),
#   (328, 334, 'positive'),
#   (371, 377, 'positive'),
#   (400, 409, 'positive'),
#   (458, 464, 'positive'),
#   (467, 487, 'positive')],
#  '20784': [(9, 14, 'positive'),
#   (27, 33, 'positive'),
#   (187, 193, 'positive'),
#   (247, 252, 'positive'),
#   (419, 425, 'positive'),
#   (464, 471, 'positive'),
#   (537, 553, 'neutral'),
#   (569, 577, 'neutral'),
#   (737, 743, 'neutral'),
#   (998, 1003, 'positive'),
#   (713, 723, 'negative'),
#   (902, 912, 'negative'),
#   (820, 824, 'positive')],
#  '21716': [(83, 93, 'positive'),
#   (238, 251, 'positive'),
#   (301, 309, 'positive'),
#   (371, 376, 'neutral'),
#   (487, 494, 'positive'),
#   (505, 522, 'positive'),
#   (525, 531, 'positive'),
#   (878, 884, 'negative'),
#   (1163, 1172, 'positive')],
#  '19439': [(94, 102, 'positive'),
#   (163, 171, 'positive'),
#   (220, 227, 'positive'),
#   (386, 398, 'positive'),
#   (614, 619, 'positive'),
#   (631, 637, 'positive'),
#   (656, 662, 'positive'),
#   (692, 699, 'positive'),
#   (714, 735, 'positive'),
#   (748, 752, 'positive'),
#   (766, 770, 'positive'),
#   (786, 811, 'positive'),
#   (835, 841, 'positive'),
#   (843, 870, 'positive')],
#  '11355': [(31, 36, 'positive'),
#   (81, 89, 'positive'),
#   (299, 304, 'neutral'),
#   (416, 423, 'neutral'),
#   (450, 454, 'negative'),
#   (456, 467, 'positive'),
#   (476, 479, 'negative')],
#  '36049': [(119, 127, 'positive'), (157, 169, 'positive')],
#  '11027': [(171, 178, 'positive'),
#   (340, 348, 'positive'),
#   (358, 366, 'positive'),
#   (419, 439, 'positive'),
#   (504, 513, 'positive'),
#   (532, 536, 'positive'),
#   (643, 651, 'positive'),
#   (668, 677, 'positive'),
#   (774, 786, 'positive'),
#   (984, 991, 'positive'),
#   (994, 1002, 'positive'),
#   (1046, 1062, 'positive'),
#   (1141, 1144, 'positive'),
#   (1156, 1165, 'positive'),
#   (1249, 1257, 'positive'),
#   (1295, 1304, 'positive'),
#   (952, 959, 'positive'),
#   (31, 50, 'positive'),
#   (635, 639, 'positive'),
#   (116, 124, 'positive'),
#   (184, 201, 'positive')],
#  '33693': [(21, 32, 'neutral'),
#   (62, 74, 'neutral'),
#   (102, 111, 'negative'),
#   (120, 128, 'neutral'),
#   (252, 258, 'positive'),
#   (252, 258, 'positive'),
#   (302, 318, 'negative'),
#   (336, 340, 'negative'),
#   (381, 386, 'positive'),
#   (407, 424, 'positive'),
#   (407, 424, 'neutral')],
#  '27620': [(73, 81, 'positive'),
#   (163, 175, 'negative'),
#   (328, 346, 'negative'),
#   (365, 373, 'negative'),
#   (620, 623, 'negative'),
#   (726, 730, 'positive'),
#   (732, 740, 'negative')],
#  '33720': [(293, 300, 'positive'),
#   (452, 464, 'positive'),
#   (478, 486, 'positive'),
#   (567, 571, 'positive'),
#   (573, 576, 'positive'),
#   (622, 629, 'positive')],
#  '15567': [(404, 409, 'negative'),
#   (412, 416, 'negative'),
#   (418, 423, 'negative'),
#   (455, 463, 'negative'),
#   (477, 483, 'negative'),
#   (495, 499, 'positive'),
#   (609, 619, 'negative'),
#   (748, 765, 'negative'),
#   (888, 905, 'neutral'),
#   (907, 915, 'neutral'),
#   (917, 922, 'neutral'),
#   (927, 945, 'negative'),
#   (1040, 1045, 'negative'),
#   (1095, 1113, 'negative'),
#   (1172, 1185, 'negative'),
#   (1220, 1229, 'negative'),
#   (1063, 1072, 'negative'),
#   (136, 145, 'positive')],
#  '18756': [(57, 69, 'neutral'),
#   (103, 107, 'negative'),
#   (146, 164, 'negative'),
#   (203, 217, 'positive'),
#   (203, 217, 'positive')],
#  '20861': [(67, 78, 'positive'),
#   (120, 125, 'positive'),
#   (153, 170, 'negative'),
#   (215, 224, 'positive'),
#   (227, 243, 'positive'),
#   (307, 315, 'positive'),
#   (403, 415, 'negative'),
#   (473, 480, 'negative'),
#   (671, 677, 'neutral'),
#   (713, 718, 'negative'),
#   (836, 842, 'negative'),
#   (850, 860, 'negative'),
#   (924, 967, 'negative'),
#   (1004, 1018, 'negative'),
#   (1050, 1059, 'negative'),
#   (444, 453, 'positive'),
#   (424, 433, 'positive'),
#   (706, 711, 'negative')],
#  '16676': [(67, 74, 'positive'),
#   (296, 305, 'positive'),
#   (412, 416, 'positive'),
#   (412, 416, 'positive'),
#   (542, 560, 'positive'),
#   (613, 621, 'positive'),
#   (677, 682, 'positive'),
#   (783, 791, 'positive'),
#   (783, 791, 'positive'),
#   (783, 791, 'positive')],
#  '1368': [(84, 89, 'positive'),
#   (108, 116, 'positive'),
#   (175, 184, 'positive'),
#   (253, 265, 'neutral'),
#   (441, 445, 'positive'),
#   (455, 463, 'positive'),
#   (473, 480, 'positive'),
#   (493, 497, 'positive'),
#   (542, 546, 'positive'),
#   (658, 668, 'negative'),
#   (773, 786, 'positive'),
#   (815, 819, 'positive'),
#   (837, 845, 'positive'),
#   (873, 880, 'neutral'),
#   (883, 889, 'neutral'),
#   (907, 913, 'negative'),
#   (914, 921, 'negative'),
#   (939, 943, 'negative'),
#   (1186, 1195, 'neutral')],
#  '29298': [(48, 56, 'positive'),
#   (58, 70, 'neutral'),
#   (85, 94, 'positive'),
#   (97, 111, 'positive'),
#   (363, 375, 'positive'),
#   (423, 430, 'neutral'),
#   (470, 479, 'positive'),
#   (500, 525, 'positive'),
#   (527, 534, 'positive'),
#   (564, 587, 'positive'),
#   (598, 629, 'positive'),
#   (665, 674, 'positive'),
#   (815, 823, 'positive'),
#   (442, 446, 'positive')],
#  '33621': [(373, 376, 'negative'),
#   (427, 439, 'negative'),
#   (484, 490, 'positive'),
#   (493, 509, 'positive'),
#   (540, 550, 'negative'),
#   (604, 616, 'negative'),
#   (638, 646, 'negative')],
#  '20417': [(66, 74, 'positive'),
#   (226, 233, 'positive'),
#   (249, 253, 'positive'),
#   (535, 540, 'positive'),
#   (569, 572, 'positive'),
#   (602, 615, 'positive'),
#   (692, 698, 'positive'),
#   (734, 742, 'positive'),
#   (768, 772, 'positive'),
#   (774, 779, 'positive'),
#   (781, 787, 'positive'),
#   (880, 886, 'positive')],
#  '25753': [(142, 150, 'positive'),
#   (186, 199, 'positive'),
#   (248, 260, 'positive'),
#   (368, 371, 'positive'),
#   (387, 393, 'positive'),
#   (419, 429, 'positive'),
#   (431, 439, 'positive')],
#  '354': [(346, 354, 'positive'),
#   (549, 554, 'positive'),
#   (596, 602, 'positive'),
#   (626, 633, 'positive'),
#   (735, 742, 'positive'),
#   (838, 844, 'positive'),
#   (920, 926, 'positive'),
#   (1003, 1015, 'positive'),
#   (1076, 1084, 'positive'),
#   (1097, 1118, 'positive'),
#   (1191, 1196, 'positive'),
#   (1214, 1226, 'positive')],
#  '18220': [(507, 512, 'positive'),
#   (627, 636, 'positive'),
#   (682, 699, 'positive'),
#   (711, 717, 'positive'),
#   (738, 746, 'positive'),
#   (801, 806, 'neutral'),
#   (846, 855, 'neutral'),
#   (857, 866, 'neutral'),
#   (867, 876, 'neutral'),
#   (878, 892, 'neutral'),
#   (972, 981, 'positive'),
#   (1131, 1140, 'positive'),
#   (1197, 1209, 'positive'),
#   (341, 350, 'positive')],
#  '24132': [(40, 47, 'positive'),
#   (66, 74, 'positive'),
#   (144, 153, 'positive'),
#   (165, 170, 'positive'),
#   (193, 205, 'positive'),
#   (212, 222, 'positive'),
#   (374, 388, 'positive'),
#   (408, 430, 'positive'),
#   (450, 459, 'positive'),
#   (517, 548, 'positive'),
#   (596, 603, 'positive'),
#   (606, 611, 'positive'),
#   (660, 666, 'positive'),
#   (865, 874, 'positive'),
#   (904, 909, 'positive'),
#   (904, 909, 'positive')],
#  '32856': [(85, 90, 'positive'),
#   (93, 105, 'positive'),
#   (376, 397, 'positive'),
#   (508, 515, 'positive'),
#   (546, 556, 'positive'),
#   (653, 661, 'positive'),
#   (718, 736, 'positive'),
#   (753, 760, 'positive'),
#   (794, 819, 'positive'),
#   (1040, 1048, 'positive'),
#   (1081, 1090, 'positive'),
#   (1132, 1142, 'positive'),
#   (1220, 1237, 'positive')],
#  '32442': [(159, 163, 'positive'),
#   (180, 196, 'positive'),
#   (248, 262, 'positive'),
#   (438, 448, 'positive'),
#   (444, 448, 'positive'),
#   (458, 464, 'positive'),
#   (88, 117, 'positive'),
#   (277, 293, 'positive')],
#  '28710': [(9, 14, 'positive'),
#   (286, 296, 'positive'),
#   (341, 349, 'positive'),
#   (415, 421, 'positive'),
#   (424, 427, 'positive'),
#   (428, 436, 'positive'),
#   (490, 496, 'positive'),
#   (497, 502, 'positive'),
#   (504, 515, 'positive'),
#   (583, 595, 'positive'),
#   (597, 606, 'positive'),
#   (648, 656, 'positive'),
#   (726, 733, 'positive'),
#   (810, 819, 'positive'),
#   (936, 944, 'positive'),
#   (704, 713, 'positive')],
#  '34282': [(96, 108, 'negative'),
#   (832, 837, 'positive'),
#   (860, 866, 'negative')],
#  '16647': [(16, 21, 'positive'),
#   (308, 317, 'positive'),
#   (551, 556, 'positive')],
#  '32513': [(0, 5, 'positive'),
#   (37, 45, 'positive'),
#   (74, 80, 'neutral'),
#   (184, 189, 'positive'),
#   (308, 318, 'negative'),
#   (355, 367, 'negative'),
#   (382, 389, 'negative'),
#   (805, 823, 'positive'),
#   (851, 857, 'neutral'),
#   (908, 918, 'negative'),
#   (957, 968, 'negative')],
#  '12943': [(81, 91, 'positive'),
#   (128, 136, 'positive'),
#   (147, 159, 'positive'),
#   (215, 227, 'positive'),
#   (284, 288, 'positive'),
#   (317, 327, 'positive'),
#   (393, 402, 'positive')],
#  '20397': [(23, 33, 'positive'),
#   (143, 151, 'positive'),
#   (217, 224, 'positive'),
#   (385, 389, 'positive'),
#   (434, 457, 'positive'),
#   (479, 491, 'positive'),
#   (561, 568, 'positive'),
#   (686, 692, 'positive'),
#   (702, 751, 'positive'),
#   (776, 798, 'positive'),
#   (842, 855, 'positive'),
#   (878, 885, 'positive'),
#   (954, 958, 'positive'),
#   (964, 974, 'positive'),
#   (1110, 1115, 'positive')],
#  '12270': [(17, 26, 'positive'),
#   (232, 240, 'positive'),
#   (315, 323, 'positive'),
#   (412, 419, 'positive'),
#   (637, 643, 'positive'),
#   (711, 720, 'positive'),
#   (723, 739, 'positive'),
#   (908, 930, 'positive'),
#   (972, 976, 'positive'),
#   (997, 1004, 'negative'),
#   (1084, 1101, 'positive'),
#   (1153, 1159, 'positive'),
#   (1166, 1170, 'positive'),
#   (620, 636, 'positive'),
#   (60, 68, 'positive'),
#   (866, 871, 'positive'),
#   (1145, 1149, 'positive')],
#  '1308': [(227, 234, 'positive'),
#   (481, 487, 'positive'),
#   (537, 546, 'positive'),
#   (549, 554, 'positive'),
#   (673, 681, 'positive'),
#   (692, 701, 'positive'),
#   (733, 745, 'positive'),
#   (756, 759, 'positive')],
#  '18430': [(196, 204, 'positive'),
#   (244, 253, 'positive'),
#   (269, 279, 'positive'),
#   (283, 291, 'positive'),
#   (295, 299, 'positive'),
#   (330, 342, 'positive'),
#   (390, 399, 'positive'),
#   (452, 455, 'positive'),
#   (458, 478, 'positive'),
#   (583, 589, 'negative'),
#   (602, 622, 'negative'),
#   (779, 788, 'negative'),
#   (812, 821, 'negative'),
#   (907, 914, 'neutral'),
#   (1060, 1070, 'positive'),
#   (1144, 1153, 'positive')],
#  '23858': [(143, 151, 'positive'),
#   (167, 171, 'positive'),
#   (181, 198, 'positive'),
#   (228, 232, 'neutral'),
#   (228, 232, 'neutral'),
#   (472, 476, 'negative'),
#   (636, 646, 'negative'),
#   (782, 791, 'negative'),
#   (824, 828, 'negative'),
#   (868, 877, 'negative'),
#   (1073, 1080, 'negative'),
#   (264, 269, 'positive'),
#   (929, 934, 'positive'),
#   (247, 251, 'positive')],
#  '18003': [(365, 375, 'positive'),
#   (640, 644, 'positive'),
#   (825, 829, 'negative'),
#   (843, 847, 'negative'),
#   (879, 896, 'positive'),
#   (898, 910, 'positive'),
#   (932, 935, 'positive')],
#  '30201': [(121, 126, 'positive'),
#   (167, 173, 'negative'),
#   (176, 188, 'negative'),
#   (247, 257, 'negative'),
#   (404, 408, 'negative'),
#   (525, 531, 'negative')],
#  '3152': [(122, 142, 'positive'),
#   (161, 169, 'positive'),
#   (297, 300, 'positive'),
#   (297, 300, 'positive'),
#   (363, 377, 'positive'),
#   (379, 388, 'positive'),
#   (391, 409, 'positive'),
#   (459, 479, 'positive'),
#   (495, 500, 'positive'),
#   (537, 549, 'positive'),
#   (562, 571, 'positive'),
#   (667, 674, 'positive'),
#   (725, 733, 'positive'),
#   (1043, 1052, 'positive')],
#  '33538': [(17, 36, 'positive'),
#   (75, 83, 'positive'),
#   (158, 167, 'positive'),
#   (179, 184, 'positive'),
#   (200, 206, 'positive'),
#   (228, 237, 'positive'),
#   (249, 255, 'positive'),
#   (269, 286, 'positive'),
#   (345, 348, 'positive'),
#   (380, 386, 'positive'),
#   (414, 420, 'positive'),
#   (435, 442, 'positive'),
#   (528, 535, 'positive'),
#   (616, 620, 'positive'),
#   (629, 636, 'positive'),
#   (637, 649, 'positive'),
#   (716, 727, 'positive'),
#   (551, 559, 'positive'),
#   (687, 692, 'positive')],
#  '36407': [(364, 379, 'positive'),
#   (395, 399, 'positive'),
#   (474, 484, 'positive'),
#   (816, 824, 'positive'),
#   (885, 888, 'positive'),
#   (916, 921, 'positive'),
#   (938, 960, 'positive'),
#   (979, 996, 'positive'),
#   (1022, 1039, 'positive'),
#   (1222, 1227, 'positive')],
#  '33976': [(104, 112, 'positive'),
#   (141, 163, 'negative'),
#   (270, 278, 'negative'),
#   (723, 731, 'negative')],
#  '34334': [(145, 148, 'positive'),
#   (159, 168, 'positive'),
#   (178, 181, 'positive'),
#   (226, 235, 'positive'),
#   (286, 291, 'positive'),
#   (298, 302, 'positive'),
#   (314, 317, 'positive'),
#   (476, 488, 'positive'),
#   (476, 488, 'positive'),
#   (502, 506, 'positive'),
#   (621, 630, 'positive'),
#   (847, 855, 'positive'),
#   (1218, 1223, 'positive'),
#   (489, 493, 'positive'),
#   (1000, 1007, 'positive'),
#   (926, 936, 'negative'),
#   (277, 285, 'positive'),
#   (1010, 1014, 'positive'),
#   (358, 368, 'negative')],
#  '35325': [(22, 30, 'positive'),
#   (22, 30, 'positive'),
#   (50, 55, 'positive'),
#   (57, 65, 'positive'),
#   (68, 74, 'positive'),
#   (103, 121, 'positive'),
#   (128, 136, 'positive'),
#   (138, 143, 'neutral'),
#   (318, 327, 'negative'),
#   (330, 336, 'negative'),
#   (392, 404, 'negative'),
#   (441, 446, 'positive')],
#  '35863': [(583, 592, 'positive'),
#   (794, 799, 'positive'),
#   (813, 827, 'positive'),
#   (830, 845, 'positive'),
#   (868, 875, 'positive'),
#   (979, 988, 'positive'),
#   (1047, 1052, 'negative'),
#   (779, 786, 'positive'),
#   (746, 751, 'positive'),
#   (426, 438, 'positive')],
#  '22970': [(26, 34, 'positive'),
#   (58, 63, 'positive'),
#   (77, 88, 'positive'),
#   (244, 257, 'positive'),
#   (274, 281, 'positive'),
#   (362, 366, 'neutral'),
#   (396, 406, 'neutral'),
#   (537, 546, 'positive')],
#  '11388': [(79, 87, 'positive'),
#   (109, 114, 'positive'),
#   (228, 249, 'positive'),
#   (259, 265, 'positive'),
#   (270, 282, 'positive'),
#   (392, 401, 'positive'),
#   (484, 489, 'positive')],
#  '2168': [(46, 54, 'positive'),
#   (360, 368, 'neutral'),
#   (484, 501, 'neutral'),
#   (540, 545, 'negative'),
#   (567, 580, 'positive'),
#   (636, 654, 'positive'),
#   (681, 687, 'neutral'),
#   (1105, 1110, 'neutral')],
#  '35635': [(773, 781, 'negative'),
#   (1087, 1091, 'negative'),
#   (1206, 1216, 'negative'),
#   (173, 182, 'positive'),
#   (1284, 1292, 'positive'),
#   (901, 906, 'negative'),
#   (150, 155, 'positive')],
#  '1563': [(140, 148, 'positive'),
#   (233, 245, 'positive'),
#   (304, 313, 'negative'),
#   (387, 390, 'negative'),
#   (563, 567, 'neutral'),
#   (715, 725, 'positive'),
#   (728, 733, 'positive'),
#   (770, 774, 'positive'),
#   (789, 795, 'positive'),
#   (797, 801, 'positive'),
#   (797, 801, 'positive'),
#   (921, 930, 'neutral'),
#   (971, 974, 'positive')],
#  '1269': [(261, 269, 'positive'),
#   (282, 299, 'positive'),
#   (316, 321, 'positive'),
#   (343, 354, 'positive'),
#   (378, 382, 'positive'),
#   (490, 503, 'positive'),
#   (624, 641, 'positive'),
#   (663, 675, 'positive'),
#   (901, 910, 'positive')],
#  '30808': [(124, 145, 'positive'),
#   (147, 171, 'positive'),
#   (189, 200, 'positive'),
#   (254, 259, 'positive'),
#   (310, 318, 'positive'),
#   (337, 341, 'positive'),
#   (371, 379, 'positive'),
#   (424, 433, 'positive'),
#   (424, 433, 'positive')],
#  '13186': [(72, 79, 'positive'),
#   (218, 227, 'negative'),
#   (529, 534, 'neutral'),
#   (629, 638, 'neutral')],
#  '14539': [(233, 239, 'positive'),
#   (303, 317, 'positive'),
#   (320, 328, 'positive'),
#   (361, 366, 'positive'),
#   (377, 385, 'neutral'),
#   (459, 481, 'negative'),
#   (545, 557, 'positive'),
#   (603, 613, 'negative'),
#   (759, 769, 'negative'),
#   (1158, 1167, 'positive'),
#   (926, 937, 'positive'),
#   (998, 1010, 'positive')],
#  '26152': [(260, 268, 'positive'),
#   (310, 320, 'positive'),
#   (323, 342, 'positive'),
#   (418, 424, 'positive'),
#   (438, 446, 'positive'),
#   (488, 494, 'positive'),
#   (699, 707, 'positive'),
#   (767, 787, 'positive'),
#   (796, 800, 'positive'),
#   (809, 814, 'positive'),
#   (827, 842, 'positive'),
#   (853, 859, 'positive'),
#   (871, 879, 'positive'),
#   (901, 930, 'positive'),
#   (972, 980, 'positive'),
#   (1016, 1020, 'positive'),
#   (1030, 1038, 'positive'),
#   (1129, 1138, 'positive'),
#   (1154, 1160, 'positive'),
#   (1171, 1184, 'positive'),
#   (576, 587, 'positive'),
#   (760, 765, 'positive'),
#   (496, 505, 'positive'),
#   (282, 290, 'positive'),
#   (1042, 1069, 'positive')],
#  '2495': [(84, 91, 'positive'),
#   (107, 112, 'positive'),
#   (129, 138, 'positive'),
#   (292, 304, 'positive'),
#   (315, 324, 'positive'),
#   (341, 351, 'positive'),
#   (408, 413, 'positive'),
#   (408, 413, 'positive'),
#   (429, 435, 'positive'),
#   (455, 465, 'positive')],
#  '32926': [(93, 102, 'positive'),
#   (183, 197, 'positive'),
#   (483, 500, 'positive'),
#   (483, 500, 'positive'),
#   (546, 549, 'positive'),
#   (612, 620, 'positive'),
#   (692, 696, 'positive'),
#   (741, 750, 'positive'),
#   (864, 870, 'positive')],
#  '33897': [(114, 123, 'positive'),
#   (125, 128, 'positive'),
#   (125, 128, 'positive'),
#   (169, 173, 'positive'),
#   (245, 257, 'positive')],
#  '12131': [(7, 11, 'positive'),
#   (61, 69, 'positive'),
#   (109, 125, 'positive'),
#   (224, 228, 'positive'),
#   (338, 347, 'positive'),
#   (449, 459, 'positive'),
#   (560, 567, 'neutral'),
#   (709, 716, 'positive'),
#   (719, 725, 'positive'),
#   (736, 741, 'positive'),
#   (750, 761, 'positive'),
#   (780, 785, 'positive'),
#   (832, 838, 'positive'),
#   (884, 892, 'positive'),
#   (958, 966, 'positive'),
#   (976, 987, 'positive'),
#   (1009, 1017, 'positive'),
#   (91, 99, 'positive'),
#   (71, 79, 'positive'),
#   (278, 283, 'positive')],
#  '27816': [(46, 54, 'positive'),
#   (67, 81, 'positive'),
#   (91, 96, 'positive'),
#   (91, 96, 'positive'),
#   (133, 139, 'positive'),
#   (149, 165, 'positive'),
#   (226, 235, 'positive'),
#   (275, 285, 'positive'),
#   (300, 308, 'positive'),
#   (321, 346, 'positive'),
#   (349, 361, 'positive'),
#   (558, 567, 'positive'),
#   (593, 599, 'positive'),
#   (119, 123, 'positive'),
#   (614, 619, 'positive')],
#  '25861': [(37, 45, 'positive'),
#   (123, 129, 'negative'),
#   (144, 149, 'positive'),
#   (169, 181, 'negative'),
#   (328, 333, 'positive')],
#  '32206': [(171, 179, 'positive'),
#   (186, 191, 'positive'),
#   (326, 334, 'positive'),
#   (416, 428, 'neutral'),
#   (724, 728, 'neutral'),
#   (791, 796, 'positive'),
#   (832, 847, 'positive'),
#   (866, 880, 'positive'),
#   (891, 897, 'neutral'),
#   (920, 926, 'positive'),
#   (956, 970, 'positive'),
#   (1003, 1017, 'positive'),
#   (1098, 1110, 'positive'),
#   (1128, 1132, 'positive'),
#   (1204, 1209, 'positive'),
#   (600, 604, 'positive'),
#   (1136, 1140, 'positive'),
#   (677, 684, 'negative'),
#   (522, 538, 'positive'),
#   (689, 694, 'negative')],
#  '35501': [(83, 92, 'positive'),
#   (136, 141, 'positive'),
#   (144, 150, 'positive'),
#   (173, 182, 'positive'),
#   (200, 212, 'positive'),
#   (231, 241, 'positive'),
#   (298, 303, 'negative'),
#   (457, 462, 'negative'),
#   (509, 556, 'positive'),
#   (615, 621, 'positive'),
#   (902, 909, 'neutral'),
#   (999, 1003, 'positive'),
#   (1013, 1021, 'positive')],
#  '11825': [(132, 137, 'positive'),
#   (393, 401, 'positive'),
#   (404, 415, 'positive'),
#   (575, 584, 'positive'),
#   (625, 630, 'positive'),
#   (670, 681, 'positive'),
#   (748, 777, 'positive'),
#   (808, 823, 'positive'),
#   (873, 882, 'positive'),
#   (923, 928, 'positive'),
#   (938, 944, 'neutral'),
#   (988, 1003, 'negative'),
#   (1056, 1060, 'negative'),
#   (384, 392, 'positive'),
#   (236, 241, 'positive')],
#  '29321': [(152, 163, 'positive'),
#   (201, 209, 'positive'),
#   (273, 277, 'positive'),
#   (547, 551, 'negative'),
#   (686, 691, 'neutral'),
#   (794, 806, 'neutral'),
#   (937, 944, 'neutral'),
#   (1172, 1184, 'neutral'),
#   (1187, 1193, 'neutral'),
#   (1259, 1271, 'negative')],
#  '9837': [(18, 26, 'positive'),
#   (81, 86, 'positive'),
#   (200, 206, 'positive'),
#   (236, 240, 'positive'),
#   (242, 250, 'positive'),
#   (292, 302, 'positive'),
#   (382, 391, 'positive'),
#   (411, 423, 'positive'),
#   (460, 470, 'positive'),
#   (514, 523, 'positive')],
#  '33252': [(131, 140, 'positive'),
#   (212, 216, 'positive'),
#   (306, 325, 'positive'),
#   (426, 431, 'positive'),
#   (483, 490, 'positive'),
#   (494, 501, 'positive'),
#   (609, 619, 'positive'),
#   (791, 803, 'positive'),
#   (833, 858, 'positive'),
#   (1069, 1086, 'positive')],
#  '10778': [(47, 55, 'positive'),
#   (146, 151, 'positive'),
#   (172, 180, 'positive'),
#   (215, 223, 'positive'),
#   (274, 282, 'positive'),
#   (324, 331, 'positive'),
#   (398, 407, 'positive'),
#   (456, 460, 'positive'),
#   (505, 513, 'positive'),
#   (574, 578, 'positive'),
#   (692, 701, 'positive'),
#   (751, 755, 'positive'),
#   (751, 755, 'positive'),
#   (818, 826, 'positive'),
#   (865, 887, 'positive'),
#   (192, 196, 'positive'),
#   (718, 727, 'positive')],
#  '26887': [(90, 95, 'negative'),
#   (98, 110, 'negative'),
#   (126, 130, 'negative'),
#   (360, 370, 'negative'),
#   (620, 632, 'negative'),
#   (645, 659, 'negative'),
#   (686, 693, 'negative'),
#   (976, 985, 'negative'),
#   (1021, 1030, 'negative')],
#  '33598': [(357, 372, 'positive'),
#   (470, 480, 'positive'),
#   (516, 526, 'positive'),
#   (665, 690, 'positive'),
#   (692, 698, 'positive'),
#   (700, 707, 'positive'),
#   (709, 722, 'positive'),
#   (758, 761, 'positive'),
#   (890, 899, 'positive'),
#   (433, 449, 'positive'),
#   (528, 539, 'positive'),
#   (104, 120, 'positive'),
#   (263, 270, 'positive'),
#   (204, 213, 'positive')],
#  '10099': [(270, 273, 'positive'),
#   (356, 365, 'neutral'),
#   (367, 372, 'neutral'),
#   (483, 492, 'positive'),
#   (549, 559, 'positive')],
#  '31963': [(45, 53, 'neutral'),
#   (78, 91, 'positive'),
#   (168, 177, 'neutral'),
#   (254, 264, 'positive'),
#   (359, 364, 'neutral'),
#   (649, 661, 'positive'),
#   (732, 736, 'negative'),
#   (836, 845, 'positive')],
#  '16137': [(176, 184, 'negative'),
#   (331, 345, 'negative'),
#   (429, 443, 'negative'),
#   (509, 519, 'negative'),
#   (611, 628, 'negative'),
#   (828, 831, 'neutral'),
#   (872, 881, 'neutral'),
#   (932, 940, 'positive'),
#   (965, 979, 'negative'),
#   (1050, 1062, 'negative'),
#   (1114, 1120, 'negative'),
#   (1141, 1145, 'neutral'),
#   (1257, 1262, 'positive'),
#   (721, 736, 'positive'),
#   (745, 758, 'positive')],
#  '3231': [(156, 159, 'positive'),
#   (168, 176, 'positive'),
#   (195, 203, 'positive'),
#   (207, 219, 'positive'),
#   (281, 290, 'positive'),
#   (419, 428, 'positive')],
#  '34575': [(58, 63, 'positive'),
#   (136, 151, 'positive'),
#   (190, 198, 'positive'),
#   (226, 236, 'positive'),
#   (250, 253, 'positive'),
#   (375, 384, 'positive'),
#   (425, 437, 'positive'),
#   (544, 560, 'positive')],
#  '19265': [(95, 100, 'positive'),
#   (121, 126, 'positive'),
#   (198, 203, 'positive'),
#   (216, 224, 'positive'),
#   (275, 283, 'positive'),
#   (309, 312, 'neutral'),
#   (341, 347, 'positive')],
#  '35085': [(0, 5, 'positive'),
#   (52, 64, 'negative'),
#   (194, 202, 'negative'),
#   (487, 495, 'positive'),
#   (550, 559, 'negative'),
#   (680, 683, 'positive'),
#   (680, 683, 'negative')],
#  '3976': [(71, 80, 'positive'),
#   (322, 335, 'positive'),
#   (564, 568, 'positive'),
#   (564, 568, 'positive'),
#   (739, 748, 'neutral'),
#   (854, 862, 'positive'),
#   (880, 886, 'positive'),
#   (901, 922, 'positive'),
#   (933, 940, 'positive'),
#   (1019, 1027, 'positive'),
#   (1038, 1043, 'positive'),
#   (1053, 1064, 'positive'),
#   (1067, 1076, 'positive')],
#  '24214': [(265, 272, 'negative'), (293, 297, 'negative')],
#  '13252': [(158, 177, 'positive'),
#   (191, 199, 'neutral'),
#   (314, 324, 'positive'),
#   (350, 358, 'neutral'),
#   (391, 400, 'neutral'),
#   (420, 426, 'neutral'),
#   (471, 477, 'positive'),
#   (481, 492, 'positive'),
#   (620, 627, 'positive'),
#   (653, 661, 'positive'),
#   (667, 675, 'positive'),
#   (681, 688, 'positive'),
#   (723, 733, 'positive'),
#   (723, 733, 'positive'),
#   (856, 893, 'negative'),
#   (856, 893, 'positive'),
#   (926, 938, 'positive'),
#   (1024, 1033, 'positive'),
#   (1111, 1119, 'positive'),
#   (593, 614, 'positive'),
#   (1196, 1223, 'positive')],
#  '18780': [(53, 57, 'positive'),
#   (128, 133, 'positive'),
#   (172, 194, 'positive'),
#   (202, 208, 'positive'),
#   (328, 337, 'positive'),
#   (493, 500, 'positive'),
#   (646, 649, 'neutral'),
#   (765, 770, 'positive'),
#   (803, 806, 'positive'),
#   (809, 821, 'positive')],
#  '2006': [(96, 109, 'positive'),
#   (135, 142, 'positive'),
#   (174, 183, 'positive'),
#   (237, 252, 'positive'),
#   (270, 277, 'positive')],
#  '24217': [(28, 37, 'positive'),
#   (63, 77, 'positive'),
#   (80, 95, 'positive'),
#   (233, 251, 'positive'),
#   (283, 290, 'positive'),
#   (328, 332, 'positive'),
#   (355, 373, 'positive'),
#   (384, 393, 'positive'),
#   (425, 435, 'positive'),
#   (437, 444, 'neutral'),
#   (483, 495, 'positive'),
#   (525, 533, 'neutral'),
#   (553, 558, 'negative'),
#   (553, 557, 'neutral'),
#   (591, 597, 'neutral'),
#   (694, 699, 'negative'),
#   (725, 733, 'negative'),
#   (787, 791, 'positive'),
#   (826, 830, 'negative'),
#   (835, 839, 'positive'),
#   (880, 888, 'negative'),
#   (907, 915, 'positive'),
#   (1002, 1008, 'positive'),
#   (1059, 1067, 'positive'),
#   (743, 751, 'negative'),
#   (205, 212, 'positive'),
#   (0, 5, 'positive'),
#   (633, 637, 'negative')],
#  '22386': [(80, 84, 'negative'),
#   (123, 130, 'negative'),
#   (292, 298, 'positive'),
#   (348, 358, 'negative'),
#   (510, 519, 'positive'),
#   (589, 599, 'negative')],
#  '2606': [(87, 95, 'positive'),
#   (104, 112, 'positive'),
#   (151, 156, 'positive'),
#   (201, 211, 'positive'),
#   (364, 374, 'negative'),
#   (559, 569, 'negative'),
#   (788, 797, 'negative')],
#  '11155': [(270, 277, 'positive'),
#   (386, 394, 'positive'),
#   (424, 427, 'negative'),
#   (468, 480, 'negative'),
#   (497, 510, 'negative'),
#   (520, 526, 'negative'),
#   (548, 553, 'negative'),
#   (562, 565, 'negative'),
#   (607, 615, 'neutral'),
#   (642, 649, 'negative'),
#   (650, 654, 'negative'),
#   (746, 754, 'negative'),
#   (779, 799, 'negative'),
#   (904, 911, 'positive'),
#   (1009, 1014, 'negative'),
#   (1028, 1034, 'negative'),
#   (1037, 1045, 'negative'),
#   (1145, 1151, 'negative'),
#   (1169, 1185, 'positive'),
#   (1188, 1192, 'positive'),
#   (1215, 1220, 'positive'),
#   (363, 366, 'positive'),
#   (175, 183, 'positive'),
#   (149, 154, 'positive')],
#  '13748': [(75, 80, 'negative'),
#   (268, 276, 'negative'),
#   (342, 347, 'negative'),
#   (526, 535, 'negative'),
#   (842, 854, 'negative')],
#  '13623': [(277, 284, 'neutral'),
#   (356, 364, 'positive'),
#   (487, 502, 'positive'),
#   (595, 604, 'positive'),
#   (606, 615, 'positive'),
#   (617, 632, 'positive'),
#   (635, 653, 'positive'),
#   (741, 747, 'positive'),
#   (771, 790, 'neutral'),
#   (847, 877, 'positive'),
#   (886, 894, 'positive'),
#   (926, 953, 'neutral'),
#   (1021, 1027, 'positive'),
#   (1030, 1035, 'positive'),
#   (1055, 1058, 'positive'),
#   (1090, 1096, 'positive'),
#   (1108, 1120, 'positive'),
#   (1156, 1164, 'positive')],
#  '14865': [(24, 33, 'positive'),
#   (151, 159, 'neutral'),
#   (171, 176, 'positive'),
#   (219, 235, 'positive'),
#   (248, 252, 'positive'),
#   (298, 311, 'positive'),
#   (352, 361, 'positive')],
#  '19746': [(180, 188, 'positive'),
#   (335, 344, 'positive'),
#   (355, 367, 'positive'),
#   (607, 612, 'positive'),
#   (673, 682, 'positive'),
#   (787, 795, 'negative')],
#  '29383': [(326, 334, 'neutral'),
#   (453, 466, 'negative'),
#   (604, 617, 'positive'),
#   (688, 719, 'positive'),
#   (814, 821, 'neutral'),
#   (871, 877, 'negative'),
#   (886, 895, 'negative'),
#   (1062, 1079, 'negative'),
#   (1198, 1202, 'positive'),
#   (1205, 1215, 'positive')],
#  '11770': [(16, 20, 'positive'),
#   (49, 53, 'positive'),
#   (55, 69, 'positive'),
#   (79, 91, 'positive'),
#   (173, 181, 'positive'),
#   (267, 272, 'negative'),
#   (310, 314, 'negative'),
#   (319, 325, 'negative'),
#   (342, 348, 'negative'),
#   (351, 355, 'negative'),
#   (547, 553, 'positive'),
#   (599, 612, 'positive'),
#   (660, 674, 'positive'),
#   (800, 806, 'positive'),
#   (831, 836, 'positive'),
#   (896, 936, 'positive'),
#   (938, 947, 'positive'),
#   (976, 987, 'positive'),
#   (1007, 1015, 'positive')],
#  '3236': [(46, 50, 'negative'),
#   (103, 107, 'negative'),
#   (293, 300, 'negative'),
#   (302, 309, 'negative'),
#   (335, 343, 'negative'),
#   (368, 387, 'negative'),
#   (454, 462, 'negative'),
#   (489, 499, 'negative'),
#   (582, 587, 'positive'),
#   (599, 616, 'positive'),
#   (599, 616, 'positive'),
# ...
#   (317, 321, 'positive')],
#  '15159': [(82, 85, 'positive'),
#   (82, 85, 'positive'),
#   (96, 102, 'positive'),
#   (144, 147, 'positive'),
#   (161, 173, 'neutral'),
#   (368, 371, 'positive'),
#   (368, 371, 'positive'),
#   (397, 401, 'positive'),
#   (458, 466, 'positive')],
#  '22975': [(59, 71, 'negative'),
#   (105, 120, 'positive'),
#   (143, 147, 'positive'),
#   (202, 214, 'positive'),
#   (219, 225, 'negative'),
#   (287, 299, 'positive'),
#   (327, 342, 'positive'),
#   (394, 399, 'positive'),
#   (484, 490, 'positive'),
#   (510, 517, 'positive'),
#   (542, 550, 'positive'),
#   (401, 406, 'positive'),
#   (557, 561, 'positive'),
#   (301, 311, 'positive')],
#  '33838': [(240, 248, 'positive'),
#   (593, 604, 'positive'),
#   (735, 744, 'positive'),
#   (930, 936, 'negative'),
#   (959, 966, 'positive')],
#  '21399': [(51, 60, 'positive'),
#   (62, 70, 'positive'),
#   (140, 145, 'positive'),
#   (196, 219, 'positive'),
#   (302, 317, 'positive'),
#   (349, 373, 'positive'),
#   (386, 404, 'positive'),
#   (447, 459, 'positive'),
#   (498, 507, 'positive')],
#  '1515': [(170, 176, 'positive'),
#   (179, 192, 'positive'),
#   (205, 213, 'positive'),
#   (216, 225, 'positive'),
#   (246, 250, 'negative'),
#   (331, 343, 'negative'),
#   (446, 451, 'negative'),
#   (577, 586, 'negative'),
#   (20, 33, 'positive')],
#  '2107': [(170, 179, 'negative'), (610, 616, 'negative')],
#  '35867': [(122, 127, 'positive'),
#   (140, 144, 'positive'),
#   (173, 180, 'positive'),
#   (194, 200, 'positive'),
#   (210, 222, 'positive'),
#   (247, 255, 'positive'),
#   (300, 309, 'positive'),
#   (390, 399, 'positive'),
#   (440, 449, 'positive'),
#   (322, 326, 'positive'),
#   (596, 611, 'positive')],
#  '2692': [(51, 58, 'positive')],
#  '36126': [(238, 243, 'positive'),
#   (357, 366, 'positive'),
#   (376, 392, 'positive'),
#   (410, 415, 'positive'),
#   (419, 436, 'positive'),
#   (465, 475, 'positive'),
#   (478, 491, 'positive'),
#   (544, 552, 'positive'),
#   (560, 566, 'positive'),
#   (738, 750, 'positive'),
#   (786, 796, 'positive'),
#   (848, 856, 'positive')],
#  '1052': [(75, 80, 'positive'),
#   (153, 156, 'neutral'),
#   (158, 166, 'positive'),
#   (182, 190, 'positive'),
#   (192, 198, 'positive'),
#   (232, 238, 'positive'),
#   (298, 307, 'positive'),
#   (315, 327, 'negative'),
#   (371, 379, 'negative'),
#   (671, 681, 'negative'),
#   (927, 932, 'positive'),
#   (1009, 1018, 'negative'),
#   (951, 955, 'positive'),
#   (13, 22, 'positive')],
#  '2468': [(115, 123, 'positive'),
#   (135, 141, 'positive'),
#   (153, 162, 'positive'),
#   (183, 191, 'positive'),
#   (431, 438, 'positive'),
#   (505, 510, 'positive'),
#   (597, 602, 'positive'),
#   (604, 619, 'positive'),
#   (635, 641, 'positive'),
#   (663, 673, 'positive'),
#   (743, 749, 'positive'),
#   (674, 691, 'positive'),
#   (406, 409, 'positive'),
#   (76, 85, 'positive')],
#  '14031': [(134, 144, 'positive'),
#   (183, 191, 'positive'),
#   (215, 228, 'positive'),
#   (296, 305, 'positive'),
#   (469, 484, 'positive'),
#   (540, 548, 'positive'),
#   (550, 559, 'positive'),
#   (630, 639, 'positive'),
#   (687, 696, 'positive')],
#  '16151': [(0, 8, 'positive'),
#   (186, 194, 'negative'),
#   (219, 225, 'negative'),
#   (244, 250, 'negative'),
#   (360, 371, 'positive'),
#   (411, 415, 'positive'),
#   (432, 436, 'positive'),
#   (478, 494, 'positive'),
#   (538, 556, 'positive'),
#   (624, 629, 'positive'),
#   (632, 642, 'positive'),
#   (658, 665, 'positive'),
#   (682, 695, 'positive'),
#   (712, 724, 'positive'),
#   (819, 829, 'positive'),
#   (872, 880, 'positive')],
#  '24578': [(94, 102, 'positive'),
#   (135, 145, 'positive'),
#   (244, 247, 'positive'),
#   (260, 266, 'negative'),
#   (365, 371, 'positive'),
#   (510, 517, 'negative')],
#  '1032': [(112, 122, 'negative'),
#   (131, 137, 'negative'),
#   (213, 218, 'negative'),
#   (332, 340, 'negative'),
#   (751, 759, 'negative'),
#   (818, 823, 'negative'),
#   (874, 882, 'positive'),
#   (884, 896, 'negative'),
#   (925, 930, 'negative'),
#   (952, 958, 'negative'),
#   (967, 975, 'negative'),
#   (1203, 1207, 'positive'),
#   (1239, 1246, 'positive')],
#  '32840': [(236, 241, 'positive'),
#   (331, 340, 'positive'),
#   (545, 553, 'positive'),
#   (603, 611, 'positive'),
#   (645, 655, 'positive'),
#   (729, 741, 'positive'),
#   (753, 756, 'positive'),
#   (815, 823, 'positive'),
#   (849, 864, 'positive'),
#   (940, 947, 'positive')],
#  '36512': [(50, 58, 'positive'),
#   (111, 116, 'positive'),
#   (235, 244, 'positive'),
#   (286, 294, 'positive'),
#   (311, 317, 'positive'),
#   (320, 329, 'positive'),
#   (350, 356, 'positive'),
#   (367, 371, 'positive'),
#   (388, 393, 'positive'),
#   (420, 428, 'positive'),
#   (461, 470, 'positive'),
#   (567, 580, 'positive'),
#   (583, 588, 'positive'),
#   (668, 673, 'positive'),
#   (668, 673, 'positive'),
#   (739, 761, 'positive'),
#   (1021, 1029, 'positive')],
#  '9870': [(149, 158, 'positive'),
#   (184, 196, 'positive'),
#   (209, 214, 'positive'),
#   (217, 225, 'positive'),
#   (234, 246, 'positive'),
#   (357, 376, 'positive'),
#   (402, 417, 'positive'),
#   (649, 669, 'positive'),
#   (703, 714, 'positive'),
#   (780, 790, 'positive'),
#   (841, 846, 'positive'),
#   (863, 873, 'positive'),
#   (876, 887, 'positive'),
#   (894, 903, 'positive'),
#   (1242, 1255, 'positive')],
#  '33520': [(130, 135, 'positive'),
#   (138, 150, 'positive'),
#   (161, 170, 'positive'),
#   (188, 209, 'positive')],
#  '17398': [(11, 19, 'positive'),
#   (28, 38, 'positive'),
#   (41, 50, 'positive'),
#   (61, 73, 'positive'),
#   (75, 87, 'positive'),
#   (106, 114, 'positive'),
#   (151, 154, 'positive'),
#   (157, 163, 'neutral'),
#   (176, 196, 'positive')],
#  '1878': [(19, 28, 'positive'),
#   (128, 137, 'positive'),
#   (162, 172, 'positive'),
#   (223, 235, 'positive'),
#   (318, 325, 'positive'),
#   (410, 415, 'positive'),
#   (561, 570, 'positive')],
#  '13823': [(495, 506, 'positive'),
#   (610, 615, 'positive'),
#   (610, 615, 'positive'),
#   (639, 643, 'positive'),
#   (639, 643, 'positive'),
#   (680, 692, 'positive'),
#   (735, 744, 'positive')],
#  '3202': [(85, 94, 'positive'),
#   (161, 171, 'positive'),
#   (239, 246, 'positive'),
#   (320, 324, 'positive'),
#   (366, 370, 'positive'),
#   (394, 399, 'positive'),
#   (531, 536, 'positive'),
#   (531, 536, 'positive'),
#   (554, 562, 'positive'),
#   (597, 602, 'positive'),
#   (611, 623, 'positive'),
#   (660, 668, 'positive'),
#   (765, 776, 'positive')],
#  '30744': [(177, 182, 'positive'),
#   (199, 203, 'positive'),
#   (220, 230, 'negative'),
#   (257, 261, 'negative'),
#   (311, 318, 'positive'),
#   (323, 328, 'positive'),
#   (334, 343, 'positive'),
#   (381, 387, 'positive'),
#   (101, 116, 'negative')],
#  '34228': [(89, 92, 'negative'),
#   (177, 180, 'negative'),
#   (312, 319, 'positive'),
#   (354, 368, 'negative'),
#   (354, 368, 'negative'),
#   (404, 418, 'negative'),
#   (456, 483, 'negative'),
#   (498, 512, 'neutral'),
#   (567, 586, 'positive'),
#   (611, 625, 'positive'),
#   (635, 641, 'negative'),
#   (662, 670, 'negative')],
#  '2203': [(174, 181, 'negative'),
#   (381, 386, 'positive'),
#   (433, 439, 'negative'),
#   (472, 478, 'negative'),
#   (579, 586, 'positive')],
#  '12118': [(132, 136, 'positive'),
#   (194, 202, 'positive'),
#   (290, 295, 'neutral'),
#   (359, 376, 'negative'),
#   (379, 397, 'negative'),
#   (469, 482, 'positive'),
#   (503, 509, 'negative'),
#   (549, 565, 'neutral'),
#   (590, 594, 'negative'),
#   (776, 801, 'negative'),
#   (848, 858, 'negative'),
#   (1021, 1028, 'positive')],
#  '30368': [(176, 186, 'positive'),
#   (224, 242, 'positive'),
#   (359, 369, 'positive'),
#   (607, 611, 'positive'),
#   (622, 627, 'positive'),
#   (648, 662, 'positive'),
#   (648, 662, 'positive'),
#   (721, 728, 'positive'),
#   (812, 822, 'positive'),
#   (824, 839, 'positive'),
#   (937, 944, 'negative'),
#   (1058, 1066, 'positive'),
#   (1179, 1189, 'positive')],
#  '10663': [(112, 121, 'positive'),
#   (149, 169, 'positive'),
#   (214, 228, 'positive'),
#   (245, 252, 'positive'),
#   (451, 469, 'positive'),
#   (499, 507, 'positive'),
#   (564, 571, 'positive'),
#   (657, 660, 'positive'),
#   (674, 692, 'positive'),
#   (732, 744, 'positive'),
#   (773, 778, 'positive'),
#   (794, 798, 'positive'),
#   (843, 849, 'positive'),
#   (910, 919, 'positive'),
#   (1093, 1098, 'positive')],
#  '14568': [(8, 12, 'positive'),
#   (118, 126, 'positive'),
#   (153, 164, 'positive'),
#   (198, 204, 'positive'),
#   (254, 257, 'positive'),
#   (312, 336, 'positive'),
#   (370, 382, 'positive'),
#   (432, 449, 'positive'),
#   (529, 538, 'positive'),
#   (605, 611, 'negative'),
#   (788, 796, 'positive'),
#   (788, 796, 'positive'),
#   (788, 796, 'positive'),
#   (799, 805, 'positive'),
#   (846, 857, 'positive')],
#  '10645': [(75, 81, 'neutral'),
#   (192, 200, 'neutral'),
#   (232, 235, 'positive'),
#   (268, 280, 'conflict'),
#   (411, 423, 'negative'),
#   (481, 488, 'neutral')],
#  '36381': [(17, 29, 'neutral'),
#   (243, 267, 'negative'),
#   (462, 469, 'negative'),
#   (848, 853, 'positive'),
#   (877, 883, 'positive')],
#  '30148': [(271, 276, 'neutral'),
#   (277, 284, 'neutral'),
#   (438, 447, 'negative'),
#   (725, 733, 'negative'),
#   (750, 757, 'positive')],
#  '33622': [(175, 178, 'positive'),
#   (265, 285, 'positive'),
#   (322, 330, 'positive'),
#   (333, 342, 'positive'),
#   (385, 391, 'positive'),
#   (401, 409, 'positive'),
#   (440, 443, 'positive'),
#   (478, 507, 'positive'),
#   (520, 542, 'positive'),
#   (637, 641, 'positive'),
#   (684, 691, 'positive'),
#   (763, 767, 'positive')],
#  '36205': [(270, 278, 'positive'),
#   (422, 435, 'positive'),
#   (475, 483, 'positive'),
#   (591, 602, 'positive'),
#   (689, 692, 'positive'),
#   (772, 777, 'positive'),
#   (840, 846, 'positive'),
#   (867, 879, 'positive'),
#   (1019, 1025, 'positive')],
#  '1666': [(158, 166, 'positive'),
#   (199, 205, 'neutral'),
#   (206, 211, 'positive'),
#   (239, 243, 'positive'),
#   (245, 264, 'positive'),
#   (268, 275, 'positive'),
#   (276, 293, 'positive'),
#   (350, 363, 'positive'),
#   (387, 394, 'positive')],
#  '36274': [(29, 45, 'positive'),
#   (88, 93, 'positive'),
#   (171, 184, 'positive'),
#   (333, 349, 'positive'),
#   (351, 377, 'positive'),
#   (379, 394, 'positive'),
#   (397, 405, 'positive'),
#   (496, 502, 'positive'),
#   (601, 611, 'positive'),
#   (655, 668, 'positive'),
#   (675, 683, 'positive'),
#   (708, 717, 'negative'),
#   (852, 861, 'positive')],
#  '17572': [(94, 123, 'negative'),
#   (418, 428, 'positive'),
#   (452, 455, 'positive'),
#   (536, 544, 'positive'),
#   (615, 642, 'positive'),
#   (645, 670, 'positive'),
#   (672, 688, 'positive'),
#   (691, 696, 'positive'),
#   (715, 722, 'positive'),
#   (746, 754, 'positive'),
#   (74, 82, 'negative'),
#   (194, 202, 'positive'),
#   (304, 313, 'positive')],
#  '1427': [(222, 241, 'positive'),
#   (333, 337, 'negative'),
#   (350, 357, 'negative'),
#   (407, 422, 'positive'),
#   (504, 511, 'positive'),
#   (566, 579, 'positive'),
#   (784, 796, 'positive'),
#   (913, 926, 'positive'),
#   (1052, 1067, 'positive'),
#   (1109, 1121, 'positive'),
#   (1177, 1184, 'positive'),
#   (1197, 1206, 'positive'),
#   (1209, 1226, 'positive'),
#   (1234, 1245, 'positive'),
#   (589, 600, 'positive'),
#   (394, 402, 'positive'),
#   (27, 36, 'positive'),
#   (1035, 1051, 'positive')],
#  '25709': [(168, 175, 'positive'),
#   (347, 353, 'positive'),
#   (365, 372, 'positive'),
#   (402, 408, 'positive'),
#   (418, 426, 'neutral'),
#   (583, 587, 'positive'),
#   (597, 617, 'positive'),
#   (666, 711, 'positive'),
#   (814, 818, 'positive'),
#   (885, 897, 'positive'),
#   (1102, 1111, 'positive')],
#  '3647': [(68, 74, 'positive'),
#   (77, 84, 'positive'),
#   (86, 92, 'positive'),
#   (86, 92, 'positive'),
#   (134, 146, 'positive'),
#   (217, 229, 'positive'),
#   (243, 253, 'positive'),
#   (366, 374, 'positive'),
#   (277, 286, 'positive'),
#   (198, 202, 'positive')],
#  '15335': [(121, 131, 'positive'),
#   (134, 142, 'positive'),
#   (258, 267, 'positive'),
#   (286, 289, 'positive'),
#   (368, 377, 'positive'),
#   (436, 444, 'positive'),
#   (759, 762, 'positive'),
#   (783, 789, 'positive'),
#   (905, 910, 'positive'),
#   (935, 947, 'positive'),
#   (951, 954, 'positive'),
#   (972, 979, 'positive'),
#   (1016, 1025, 'positive'),
#   (1118, 1129, 'positive')],
#  '12366': [],
#  '36576': [(94, 103, 'positive'),
#   (137, 146, 'positive'),
#   (166, 174, 'positive'),
#   (179, 186, 'positive'),
#   (359, 368, 'positive'),
#   (381, 398, 'positive'),
#   (399, 417, 'positive'),
#   (418, 425, 'positive'),
#   (426, 442, 'positive'),
#   (443, 457, 'positive'),
#   (501, 507, 'positive'),
#   (541, 548, 'positive'),
#   (558, 564, 'positive'),
#   (570, 575, 'positive'),
#   (706, 716, 'positive')],
#  '36926': [(81, 86, 'positive'),
#   (99, 104, 'positive'),
#   (113, 121, 'positive'),
#   (140, 149, 'positive'),
#   (171, 180, 'positive'),
#   (238, 244, 'positive'),
#   (303, 306, 'positive'),
#   (303, 306, 'positive'),
#   (365, 382, 'positive'),
#   (390, 420, 'positive'),
#   (428, 432, 'positive'),
#   (453, 464, 'positive')],
#  '10625': [(416, 426, 'positive'),
#   (479, 487, 'neutral'),
#   (634, 641, 'negative'),
#   (646, 656, 'negative'),
#   (823, 828, 'negative'),
#   (867, 874, 'negative'),
#   (880, 884, 'negative'),
#   (1015, 1020, 'positive')],
#  '19677': [(47, 51, 'positive'),
#   (154, 159, 'positive'),
#   (169, 175, 'positive'),
#   (188, 194, 'positive'),
#   (188, 194, 'positive'),
#   (197, 204, 'positive'),
#   (197, 204, 'positive'),
#   (296, 308, 'positive'),
#   (328, 342, 'positive'),
#   (416, 420, 'positive'),
#   (465, 469, 'positive')],
#  '3552': [(92, 97, 'positive'),
#   (100, 117, 'positive'),
#   (133, 145, 'positive'),
#   (226, 233, 'positive'),
#   (252, 265, 'positive'),
#   (415, 421, 'positive'),
#   (442, 451, 'positive'),
#   (454, 468, 'positive')],
#  '22527': [(108, 124, 'positive'),
#   (126, 155, 'positive'),
#   (170, 179, 'positive'),
#   (201, 213, 'positive'),
#   (314, 319, 'positive'),
#   (358, 364, 'positive')],
#  '2345': [(62, 71, 'positive'),
#   (73, 85, 'positive'),
#   (97, 106, 'positive'),
#   (146, 155, 'positive'),
#   (305, 311, 'positive'),
#   (800, 812, 'positive'),
#   (864, 870, 'positive'),
#   (894, 898, 'positive'),
#   (894, 898, 'positive'),
#   (1028, 1036, 'positive')],
#  '8996': [(18, 32, 'positive'),
#   (83, 90, 'positive'),
#   (146, 157, 'positive'),
#   (168, 176, 'positive'),
#   (178, 186, 'positive'),
#   (230, 239, 'positive'),
#   (285, 290, 'positive'),
#   (300, 306, 'positive'),
#   (313, 323, 'positive'),
#   (388, 396, 'positive'),
#   (670, 675, 'positive'),
#   (696, 702, 'positive'),
#   (719, 723, 'positive'),
#   (823, 827, 'positive'),
#   (848, 857, 'positive'),
#   (955, 962, 'positive'),
#   (967, 976, 'positive')],
#  '9878': [(143, 150, 'negative'),
#   (265, 269, 'negative'),
#   (326, 332, 'negative'),
#   (380, 387, 'negative'),
#   (420, 424, 'negative'),
#   (542, 551, 'negative'),
#   (640, 649, 'negative')],
#  '33825': [(165, 186, 'positive'),
#   (210, 215, 'positive'),
#   (259, 267, 'positive'),
#   (309, 319, 'positive'),
#   (371, 379, 'positive'),
#   (510, 513, 'positive'),
#   (547, 551, 'positive'),
#   (321, 330, 'positive'),
#   (573, 587, 'positive'),
#   (111, 126, 'positive')],
#  '15655': [(62, 70, 'positive'),
#   (112, 121, 'positive'),
#   (165, 171, 'positive'),
#   (215, 241, 'positive'),
#   (253, 270, 'positive'),
#   (296, 314, 'positive'),
#   (362, 368, 'positive'),
#   (432, 438, 'positive')],
#  '17475': [(131, 139, 'positive'),
#   (151, 162, 'positive'),
#   (199, 205, 'positive'),
#   (217, 225, 'positive'),
#   (244, 258, 'negative'),
#   (303, 317, 'neutral'),
#   (355, 363, 'negative'),
#   (513, 527, 'positive'),
#   (536, 539, 'positive'),
#   (554, 560, 'positive'),
#   (561, 567, 'neutral'),
#   (582, 594, 'positive'),
#   (718, 728, 'positive'),
#   (181, 190, 'positive'),
#   (500, 505, 'positive'),
#   (259, 268, 'positive'),
#   (337, 354, 'positive')],
#  '22015': [(12, 21, 'negative'),
#   (355, 364, 'negative'),
#   (770, 778, 'neutral'),
#   (790, 799, 'negative')],
#  '18518': [(33, 46, 'positive'),
#   (122, 131, 'positive'),
#   (210, 216, 'positive'),
#   (352, 360, 'positive'),
#   (484, 494, 'positive'),
#   (528, 537, 'positive')],
#  '10231': [(40, 45, 'positive'),
#   (92, 107, 'positive'),
#   (122, 129, 'positive'),
#   (139, 146, 'positive'),
#   (201, 214, 'positive'),
#   (217, 221, 'positive'),
#   (222, 230, 'neutral'),
#   (252, 257, 'neutral'),
#   (300, 305, 'positive')],
#  '11793': [(42, 51, 'positive'),
#   (118, 132, 'positive'),
#   (155, 159, 'positive'),
#   (234, 238, 'positive'),
#   (241, 246, 'positive'),
#   (342, 357, 'positive'),
#   (427, 434, 'positive'),
#   (437, 442, 'positive'),
#   (614, 632, 'negative'),
#   (754, 771, 'positive'),
#   (797, 804, 'neutral'),
#   (860, 872, 'neutral'),
#   (953, 965, 'positive'),
#   (968, 973, 'positive'),
#   (1015, 1023, 'positive')]}

# %% [markdown]
# Оставляем только полярные аспекты

# %%
spans_polar = defaultdict(list)
spans_neu = defaultdict(list)
for k, i in spans.items():
    c = 0
    for j in i:
        if j[2] not in ['neutral', 'conflict']:
            spans_polar[k].append(j)
            c+=1

# %%
fin_spans = defaultdict(dict)
for k, i in spans_polar.items():
    fin_spans[k]['text'] = senti_texts[k]
    fin_spans[k]['aspects'] = i

# %%
fin_spans
# Out:
# defaultdict(dict,
#             {'15758': {'text': 'Был в заведении со своей девушкой в пятницу. Очень неплохо. Ресторану еще много есть над чем поработать, конечно, но тем не менее, место довольно милое, обслуживание приятное и еда довольно вкусна. Заказывали салаты и горячее(стейк из лосося и блюдо под названием "сытая хавронья" из свинины). Принесли быстро. Крепкого алкоголя, кроме пива у них пока нет, видимо с лицензией проблемы, но медовуха оказалась очень даже приятной. Хотелось бы, конечно, большего разнообразия в меню, но так как они недавно открылись, думаю, со временем все у них наладится.',
#               'aspects': [(131, 136, 'positive'),
#                (153, 165, 'positive'),
#                (177, 180, 'positive'),
#                (389, 397, 'positive')]},
#              '2073': {'text': 'Три дня назад отмечали в этом "ресторане" день рождения. Сегодня решила почитать отзывы по этому заведению, так как вечер был просто испорчен. Складывается такое впечатление, что мы были где-то в другом месте. Да, неплохой интерьер, неплохая кухня... но все остальное просто ужас. Во-первых такого отвратительного обслуживания я не видела нигде. На весь ресторан работала одна официантка, что само по себе странно. Если бы она просто не справлялась с обилием заказов, то еще как то извинительно, но она не очень то и старалась. Например вино нам несли 20 мин., курить мы выходили на улицу, где для этого стоят кресла и столик, попросили ее принести пепельницу... она пообещала, но до конца нашего застолья так этого и не сделала. На закуску мы среди прочего заказывали оливки, так их нам принесли почти в конце вечера, про один заказ она вообще забыла, на что просто извинилась. Отдельная история - живая музыка. Хороший певец, с хорошим голосом... но для такого маленького помещения - это просто тихий ужас. Разговаривать было невозможно не только с другим концом стола, но и соседей справа-слева приходилось переспрашивать. Соглашусь, на вкус и цвет товарищей нет, но я в этот ресторан больше ни ногой и всех своих друзей обязательно предупрежу',
#               'aspects': [(97, 106, 'negative'),
#                (314, 326, 'negative'),
#                (377, 387, 'negative'),
#                (899, 911, 'negative'),
#                (974, 983, 'negative'),
#                (1179, 1187, 'negative')]},
#              '24713': {'text': 'Отмечали в банкетном зале свадьбу сына в июле 2013. Зал замечательный. Но... Мы выбрали среднее в ценовой категории меню. Когда пришли, меня удивило небольшое кол-во закусок. Мне казалось, что должно быть больше. Сырная тарелка поразила засохшим сыром. Фрукты были на последнем издыхании. Когда попробовала салаты- пришла в ужас. По качеству тянут на забегаловку, а не на банкетный зал. До заказа банкета я кое-что заказала в кафе на первом этаже. Еда понравилась. Но, такое впечатление, что на банкет готовит кто-то другой. Горячее тоже не понравилось. Торт у нас был свой. Свадьба, конечно, прошла весело, но качество еды ее не украсило. Когда молодые уехали, гости разошлись, я попросила упаковать нам оставшееся. Администратор при оформлении сказал, что все будет упаковано и собрано, включая алкоголь и соки. К моему удивлению, официанты мне сказали, что я могу сама все собрать со столов, они за отдельную плату дадут мне контейнеры. После ТРИДЦАТИ минут пререканий, мне удалось заставить их кое-что сложить. Оставшийся алкоголь, воду и соки собирали сами. В этом году женится второй сын. Когда он сказал, что этот зал уже занят на нужную дату- я обрадовалась.',
#               'aspects': [(52, 55, 'positive'),
#                (166, 173, 'negative'),
#                (213, 227, 'negative'),
#                (246, 251, 'negative'),
#                (253, 259, 'negative'),
#                (307, 313, 'negative'),
#                (448, 451, 'positive'),
#                (525, 532, 'negative'),
#                (620, 623, 'negative'),
#                (833, 842, 'negative'),
#                (502, 509, 'negative')]},
#              '16630': {'text': 'Уютная и тёплая домашняя обстановка! Милый и отзывчивый персонал, очень внимательное обслуживание. Еда, стоит ли говорить, что трудно удивить человека, привыкшего и знающего грузинскую кухню. Могу сказать одно, я была приятно удивлена! Спасибо персоналу, ему удается создать ощущение, что этот ресторан - особенное место где каждый чувствует себя долгожданным гостем!)))))))))))',
#               'aspects': [(25, 35, 'positive'),
#                (56, 64, 'positive'),
#                (85, 97, 'positive'),
#                (99, 102, 'positive'),
#                (244, 253, 'positive'),
#                (294, 302, 'positive'),
#                (315, 320, 'positive')]},
#              '27841': {'text': 'Первый раз зашла случайно, хотелось кофе попить...Сразу было очарована обслуживающим персоналом: встречают так, как будто ждали именно тебя и очень рады визиту. Кофе вкусное, тортики отменные. Потом несколько раз заходили с друзьями, посидеть, выпить пивка. Выбор пива небольшой, но это нормально все-таки это больше кондитерская...Хотя все нашли себе напиток по вкусу, есть и Тиммерманс и Невское. Очень понравились закусочки: и жаренные крылышки, и особенно кальмары. Их подают еще и с колечками лука. Правда без соуса, в меню мы соуса тоже не обнаружили, но приветливая девушка-официантка на наш вопрос о соусе, предложила 2 вида и сразу же принесла. Интерьер неплохой, жалко только, что диванчики и плазменная панель только в зале для некурящих. Обслуживание на 10, все вовремя, мило и с улыбкой. Отлично, что появилось такое приятное местечко в нашем районе.',
#               'aspects': [(71, 95, 'positive'),
#                (161, 165, 'positive'),
#                (175, 182, 'positive'),
#                (352, 359, 'positive'),
#                (377, 387, 'positive'),
#                (390, 397, 'positive'),
#                (417, 426, 'positive'),
#                (430, 447, 'positive'),
#                (460, 468, 'positive'),
#                (515, 520, 'negative'),
#                (573, 591, 'positive'),
#                (750, 762, 'positive'),
#                (839, 847, 'positive')]},
#              '12880': {'text': 'Не судите человека по одёжке... 9 мая...Пасмурный,но теплый Питерский вечер... В компании подруг решили прогуляться по центру,перекусить решили в Tefsi,так как были рядом и слышали много хорошего. Встретили нас на входе удивленно, так как выглядели мы,как тинейджеры),но как говорят у нас в компании "можем себе позволить"))). Не буду говорить об интерьере, так как наверно в предыдущих отзывах все уже написано,могу сказать одно-понравилось, кухня тоже нас порадовала- хачапури отличный, хинкали большие,но мясо чуть-чуть суховато,баклажаны запеченные отменные, люля неплох, но не хватало соуса, а официант не предложил дополнительно его заказать.Вот и все хорошее заканчивается, так как сервис в этом заведение на нуле, блюда одновременно не приносили, в итоге я ела,когда все остальные свои блюда уже съели,тарелки грязные со стола не убирали,но самое главное,когда принесли сдачу- чека не было,сразу все хорошие впечатления об этом ресторане испарились,естественно никто к нам больше не подошел,а когда мы уходили никто с нами не попрощался.Чаевые не оставили,так как считаю,что персонал этого заведения уже заработал себе на "чай".',
#               'aspects': [(347, 356, 'positive'),
#                (443, 448, 'positive'),
#                (470, 478, 'positive'),
#                (489, 496, 'positive'),
#                (508, 512, 'negative'),
#                (532, 541, 'positive'),
#                (590, 595, 'negative'),
#                (599, 607, 'negative'),
#                (689, 695, 'negative'),
#                (936, 945, 'negative'),
#                (1083, 1091, 'negative'),
#                (1098, 1107, 'negative')]},
#              '32040': {'text': 'Хороший ресторан с неплохим обслуживанием. Были в нем два раза. Оба раза остались довольны. Уютный интерьер в итальянском стиле, вежливые и внимательные девушки официанты, приятная музыка без бум-бумов. Кухня – не плохая, хотя, некоторые блюда, были приготовлены не по правилам. А что самое главное - не много людей. Оба раза, когда мы были в ресторане, параллельно с нами было занято лишь 2-3 столика. Ресторан хорошо подходит для романтического ужина. По цене: ужин на двоих обходится где-то 2000р',
#               'aspects': [(8, 16, 'positive'),
#                (99, 107, 'positive'),
#                (153, 170, 'positive'),
#                (181, 187, 'positive'),
#                (238, 243, 'negative'),
#                (403, 411, 'positive')]},
#              '19111': {'text': 'Был с друзьями в четвером в этом ресторане. Что могу сказать: 1. Персонал мне понравился, официантка была очень приятной, общительной и доброжелательной, по нашей просьбе без проблем сфотографировала нас, еду приносила быстро, лишнии тарелки тоже не задерживалаись на столе. В гардеробе дядечка тоже очень вежливый и все остальные кого видели из персонала произвели приятное впечатление. 2. Были в воскресенье в 15:30, народу никого не было, это немного удивило, потом подошли еще люди конечно. Зал большой, мебель приличная, большой телевизор на стене удобно смотреть с любого столика наверно. 3. Сначала хотели заказать чешские спиртные напитки, но их не оказалось к сожалению, немного расстроились, но не сильно. Заказали виски - виски нормальное, понравилось. Также заказали мясное ассорти, и капусту тушенную с мясом. Претензий к качеству блюд нету. Ничего суперского, но на уровне. В целом ресторан оставил приятное впечатление.',
#               'aspects': [(65, 73, 'positive'),
#                (90, 100, 'positive'),
#                (287, 294, 'positive'),
#                (346, 355, 'positive'),
#                (495, 498, 'positive'),
#                (534, 543, 'positive'),
#                (622, 646, 'negative'),
#                (733, 738, 'positive'),
#                (896, 904, 'positive')]},
#              '10847': {'text': 'Вчера, стало быть в понедельник, 14 февраля, отправился в это местечко, ранее мне неизвестное. Обстановка милая, уютная. Есть, конечно, как и в любом другом кафе столики, которые уютными не назовешь, но всем не угодишь и в целом мне обстановка понравилась. Сразу видно, что к интерьеру подходили как можно тщательнее, это радует. Администратор и официанты весьма вежливы. В кафе чувствуется от персонала, что люди хотят работать и это им нравится, а это самое главное!) Никаких задержек при подаче блюд/напитков не было. Единственное удивление образовалось, когда на десерт мне принесли ложку вместо десертной вилки, но это проблем не вызвало. Но вы попробовали бы этот десерт м.м.м. Десерт был очень вкусный, нам понравилось) Суши панированные в рыбных сухарях или как-то так вызвали очень много восхищения, т.к. это было действительно вкусно. По кухне можно сказать, что это кафе для тех, кто любит соотношение цены и качества. Есть все необходимое. В целом кафе оставляет очень приятные воспоминания. Всем очень рекомендую сходить и попробовать местную японскую кухню. На втором этаже на диванчиках весьма удобно разместиться компанией.',
#               'aspects': [(95, 105, 'positive'),
#                (233, 243, 'positive'),
#                (276, 285, 'positive'),
#                (330, 343, 'positive'),
#                (346, 355, 'positive'),
#                (394, 403, 'positive'),
#                (670, 676, 'positive'),
#                (684, 690, 'positive'),
#                (727, 761, 'positive'),
#                (848, 853, 'positive'),
#                (877, 881, 'positive'),
#                (960, 964, 'positive'),
#                (1056, 1070, 'positive'),
#                (1075, 1087, 'positive'),
#                (1091, 1101, 'positive')]},
#              '10354': {'text': 'Я не ходила в этот ресторан в детстве, не знаю, как всё было когда-то, но сейчас это вполне симпатичное и уютное заведение с хорошей кухней. Впервые посетили "Чебурек" c месяц назад - отмечали с друзьями прошедшую ранее свадьбу. Администрация любезно предоставила нам новый банкетный зал, где мы закрылись, включили свою музыку, курили кальян, веселились, и нам никто не мешал. Кухня всем друзьям понравилась, обслуживание тоже (девушки-официантки замечательные). Меня же больше всего порадовало, что администрация пошла нам навстречу и сделала хорошую скидку на банкет :) Уже через неделю моя подруга вернулась в "Чебурек" со своими родными, где они отметили юбилей отца. Мы также возвращаемся сюда снова и снова. Единственное, что расстраивает - это рост цен. За последний месяц цены менялись уже два раза. Растут они по чуть-чуть, но всё равно стоимость ужина на двоих с каждым посещением получалась у нас всё выше и выше :) Но без этого, конечно, никуда. Из кухни могу порекомендовать: чебуреки с сыром сулугуни и зеленью (волшебные!), сациви из баклажан, суп чанахи, конечно же, хинкали, ну и, наверное, бараньи ножки (не помню точное название блюда). Всё это не оставит равнодушным никого, очень вкусно и "аутентично"!))',
#               'aspects': [(113, 122, 'positive'),
#                (113, 122, 'positive'),
#                (133, 139, 'positive'),
#                (229, 242, 'positive'),
#                (378, 383, 'positive'),
#                (410, 422, 'positive'),
#                (429, 447, 'positive'),
#                (501, 514, 'positive'),
#                (614, 623, 'positive'),
#                (857, 861, 'negative'),
#                (990, 1025, 'positive'),
#                (1040, 1058, 'positive'),
#                (1060, 1070, 'positive'),
#                (1084, 1091, 'positive'),
#                (1109, 1122, 'positive')]},
#              '21059': {'text': 'Добрый день. Отмечали в этом ресторане 7 марта,был банкет на 20 человек. Так как открылись они недавно,отзывов нет никаких,было немного страшно идти в новое место,но так как живем рядом,решили рискнуть,и не пожалели!!!! Заранее все оплатили,нам помогли меню составить индивидуально под наши запросы и бюджет. К нашему приходу все уже было готово,столы накрыты,еда вынесена. Кухня просто обалденная,порции большие,все остались очень довольны!!Приятно удивила программа-живая музыка(девушка очень красиво пела),и грузинские танцевальный коллектив,потрясающе!!! Зал очень большой, светлый,кроме нас там было еще 2 банкета,но за счет большого пространства никто никому не мешал. Огромный плюс,что алкоголь можно с собой приносить,пробкового сбора нет. В общем все остались очень очень довольны,спасибо Вам большое за чудесный праздник,обязательно придем к Вам еще!!!!!!',
#               'aspects': [(374, 379, 'positive'),
#                (398, 404, 'positive'),
#                (458, 467, 'positive'),
#                (468, 480, 'positive'),
#                (511, 544, 'positive'),
#                (559, 562, 'positive'),
#                (726, 742, 'positive'),
#                (157, 162, 'negative')]},
#              '25960': {'text': 'Первые месяцы после открытия просто не могли нарадоваться такому классному местечку. И с друзьями весело посидеть и вдвоем с молодым человеком. Обслуживание было отличное и качество блюд на высоте. Бывали там раза 3 в неделю. Теперь как то все испортилось. Народу стало ужасно много всегда. Сервис упал резко. Последний раз нам даже не вытерли столик после прежних посетителей. Очень часто не бывает того что есть в меню (хотя раньше такого не было) да и качество еды испортилось на мой взгляд. А вот цены остались на прежнем уровне. Вобщем больше не радует это место.',
#               'aspects': [(75, 83, 'positive'),
#                (144, 156, 'positive'),
#                (182, 186, 'positive'),
#                (291, 297, 'negative'),
#                (416, 420, 'negative'),
#                (464, 467, 'positive'),
#                (562, 567, 'negative')]},
#              '2965': {'text': 'Посетили ресторан Ялта 11.05.12,по случаю Дня Рождения,заказали столик на 8 человек за день до торжества,при заказе нам показали ресторан,предложили несколько вариантов для размещения наших гостей,мы выбрали отдельно стоящие 2 столика окруженные диванами и креслами,рядом с панорамным окном,предоплату за заказ не оставляли,(что выгодно отличило этот ресторан от других,учитывая что наше событие было запланировано на вечер пятницы). Ресторан выгодно отличается спокойной атмосферой,приятной, НЕ громкой живой музыкой,что оставляет шанс для приятной беседы.Обслуживание не навязчивое,я бы сказала незаметное,очень приятные официанты,сразу принесли вазу для цветов,приняли заказ,все очень вежливо,с хорошим знанием меню и доброжелательностью. Кухня порадовала разнообразием,хорошим,информативным меню,по которому легко можно было выбрать блюдо на любой вкус,так как представлена японская,русская ,грузинская кухня.Порции большие,посуда хорошая,вкус отменный.Чек немного выше ,чем в других ресторанах,этого класса,но наши положительные эмоции стоили этого. Очень приятно провели время,очень рады что выбрали этот ресторан ,довольны остались уровнем сервиса и кухней.',
#               'aspects': [(351, 359, 'positive'),
#                (472, 482, 'positive'),
#                (504, 517, 'positive'),
#                (557, 569, 'positive'),
#                (623, 632, 'positive'),
#                (706, 718, 'positive'),
#                (742, 747, 'positive'),
#                (795, 799, 'positive'),
#                (913, 919, 'positive'),
#                (928, 934, 'positive'),
#                (1111, 1119, 'positive'),
#                (1147, 1154, 'positive'),
#                (1157, 1163, 'positive'),
#                (837, 842, 'positive'),
#                (434, 442, 'positive'),
#                (943, 947, 'positive')]},
#              '37036': {'text': 'Отмечали в этом ресторане день рождение в субботу вечером. Хочу выразить большую благодарность прежде всего руководству ресторана, обслуживающему персоналу и конечно же тем поварам, которые готовят посетителям заведения столь вкусные блюда. Понравилось абсолютно все. Конечно же впечатляет интерьер: уютно и красиво. Стол был шикарный. Хочу отметить, что для ресторана такого уровня цены не высокие. Хочется снова окунуться в незабываемую атмосферу, которая присуща данному заведению.',
#               'aspects': [(108, 129, 'positive'),
#                (131, 155, 'positive'),
#                (173, 180, 'positive'),
#                (226, 233, 'positive'),
#                (234, 239, 'positive'),
#                (290, 298, 'positive'),
#                (317, 321, 'positive'),
#                (439, 448, 'positive')]},
#              '10985': {'text': 'Решили недалеко от дома сходить в китайский ресторанчик, самым близким оказался Жен-Жен. На первый взгляд с улицы были видны китайские аттрибуты. Внутри на первом этаже танцпол, гудела европейская попса, нас попросили пройти на второй этаж. Была приятно удивлена "китайским интерьером" - диванчики как в бистро, скатерти на столах по типу а-ля столовая, европейские светильники/люстры, в общем в плане интерьера китайского никакого абсолютно! Заведение неуютное. Ну так как ехать в другое место уже не было сил, решили заказать все-такие еду. Меню не порадовало - отпечатанные листки, не особо понятен состав блюд и вес, о картинках даже речи не было. Ну ладно - с китайской кухней знакомы - заказали говядину, свинину, рис, пару закусок, порции оказались большими, еда - вкусной, принесли все горячее. Конечно посуда и сервировка стола могли бы быть и получше. По поводу сервиса - официантка не здоровалась, не успели сесть - пришла за заказом,правда блюда вынесли быстро, но счет пришлось ждать....при том, что кроме нас было занято всего 2 столика еще. в общем покушать было вкусно, но второй раз идти не хочется - люблю все же чтоб присутствоавал китайский антураж в подобных местах.',
#               'aspects': [(264, 284, 'negative'),
#                (288, 297, 'negative'),
#                (312, 330, 'negative'),
#                (402, 411, 'negative'),
#                (443, 452, 'negative'),
#                (543, 547, 'negative'),
#                (602, 613, 'negative'),
#                (701, 709, 'positive'),
#                (711, 718, 'positive'),
#                (720, 723, 'positive'),
#                (730, 737, 'positive'),
#                (739, 745, 'positive'),
#                (766, 769, 'positive'),
#                (811, 817, 'negative'),
#                (820, 830, 'negative'),
#                (882, 892, 'negative')]},
#              '11267': {'text': 'Давно не была в таком ужасном месте. Обслуживание просто ни в какие рамки не лезет, офицантки просто не обращают на тебя никакого внимания, а если уж все-таки удастся кого-нибудь поймать, то на тебя смотрят с таким выражением лица.. "ах, вам еще и принести что-то надо...". По-поводу самой еды - ни одно блюдо восхищения не вызвало. В силу обстоятельств, была в этом ресторанчике не один раз, но как-то с каждым разом убеждаюсь в совем первом впечатлении. Однажды при заказе супа из меню официантка сказала, что следует заказать другой, так как этот скис (!!!). Интерьер - очень темный, не каждому тоже будет по вкусу. В общем, не советую ходить в это место. На той же улице есть довольно много заведений лучшего качества.',
#               'aspects': [(30, 35, 'negative'),
#                (37, 49, 'negative'),
#                (84, 93, 'negative'),
#                (367, 379, 'negative'),
#                (475, 479, 'negative'),
#                (562, 570, 'negative'),
#                (652, 657, 'negative')]},
#              '27569': {'text': 'В первый раз попали в Арагви ещё в феврале. Компания была большая, столик забронировали заранее. Всё очень понравилось - и кухня, и обслуживание, и обстановка. этот ресторан сразу стал любимым, поэтому время от времени туда заглядываем. Последний раз была с подругой 16 апреля. На всякий случай заранее заказали столик. Несмотря на будний день, все столики были заняты, поэтому бронь оказалась очень уместна. Готовят в Арагви очень вкусно, ждать еду приходится недолго. Заказывали зелень с овощами, так там принесли этогго добра целую корзинку.)) шашлык на любителя- кому-то нравится из телятины, кому-то из свинины. Очень вкусные чебуреки! десертов немного, но тоже очень вкусные. Пробовали лёгкий десерт и печёную грушу. жаль,что нет грузинских вин... но их нигде нет. Музыка в ресторане негромкая, обстановка располагает к общению. Так что если нужно спокойное, приятное место, где можно вкусно и недорого поесть, Арагви - самый лучший вариант!приходите, не пожалеете!',
#               'aspects': [(123, 128, 'positive'),
#                (132, 144, 'positive'),
#                (148, 158, 'positive'),
#                (165, 173, 'positive'),
#                (446, 449, 'positive'),
#                (481, 497, 'positive'),
#                (631, 639, 'positive'),
#                (641, 649, 'positive'),
#                (736, 750, 'negative'),
#                (771, 777, 'positive'),
#                (801, 811, 'positive'),
#                (917, 923, 'positive'),
#                (917, 923, 'positive')]},
#              '16378': {'text': 'Сегодня были компанией из 4х человек, были уже далеко не в первый раз, но только сегодня вот собрался оставить отзыв. По порядку: Кухня - Суп-Харчо, шашлыки (перепробовали практически все из представленных) 5+ оценка, лепешки, весьма неплохое вино (на мой вкус), ну и конечно чай с чабрецом :), вот зачем сюда стоит и нужно ходить, согласитесь, что в таком месте какой-нибудь салат Греческий брать совершенно бесполезно, он и не должен быть хорошим тут :) Интерьер - В целом достаточно тематично, исключая уже упомянутую кем-то колонку в зале и может быть недостаток света в главном зале, мне, как и многим, кто здесь писал больше нравится светлый зал, он намного уютнее, единственное - стоит обратить внимание на чистоту скатертей, не всегда идеально. Обслуживание - Приятные, вежливые молодые люди, не слишком часто, но и не редко подходят, работают не бездушно, с улыбкой и вообще органично смотрятся, никаких нареканий. Вообще приятное место для посиделок, как деловых, так и частных, любителям "понтов и собачек" точно не сюда, заведение все-таки не дотягивает до того уровня, чтобы привлекать таких персонажей, но и слава богу. При всем написанном цена очень адекватная, по крайней мере на ту часть меню, которая нас интересует. Спасибо за внимание.',
#               'aspects': [(130, 135, 'positive'),
#                (138, 147, 'positive'),
#                (149, 156, 'positive'),
#                (218, 225, 'positive'),
#                (243, 247, 'positive'),
#                (276, 290, 'positive'),
#                (528, 535, 'negative'),
#                (567, 587, 'negative'),
#                (640, 651, 'positive'),
#                (714, 731, 'negative'),
#                (753, 765, 'positive'),
#                (787, 799, 'positive'),
#                (940, 945, 'positive'),
#                (1205, 1209, 'positive'),
#                (575, 587, 'negative'),
#                (376, 391, 'negative'),
#                (1154, 1158, 'positive')]},
#              '34307': {'text': 'Недавно пришли компанией, давно не были в этом заведении и лучше бы не приходили!!!! Была пятница, людей в зале под завязку, сели за единственный свободный стол, так столы стоят настолько близко, что выйти из- за него невозможно((( но это не самое страшное...... Очень долго несут заказ либо вобще про тебя забывают, все время приходят и переспрашивают( ну если у тебя плохая память- возьми бумагу и записывай) . Мы брали горячее, салатики, пиво и закуски к пиву, которые так и не дождались, хотя по прошествии часа 1 раз даже напомнили, чего мы делать не должны в принципе. Но вот в счет их ВКЛЮЧИТЬ они не забыли!!!! Салаты раньше были вкуснее. Еду приносят черти как, во- первых без приборов, все время нужно напоминать, во вторых, по времени ужасно,1 из нас уже час как поел, а второму еще даже готовить видимо не начали.Официанта то не дождешься, то еще доесть не успел, уже тарелку забирают. В зале стоит галдеж, музыку вобще не слышно. В это заведение мы раньше ходили с удовольствием, что случилось- непонятно. Больше ни ногой!!!! Цены пивного ресторана, а обслуживание дешевой привокзальной пивнушки(((((((',
#               'aspects': [(47, 56, 'negative'),
#                (107, 111, 'negative'),
#                (166, 171, 'negative'),
#                (825, 834, 'negative'),
#                (900, 904, 'negative'),
#                (919, 925, 'negative'),
#                (949, 958, 'negative'),
#                (1065, 1077, 'negative')]},
#              '12814': {'text': 'Сегодня побывал в данном заведении. Кухня была нормальная, я бы даже сказал, что вкусно было все приготовлено. Но есть одно НО... При том что ресторан был практически пуст заказ, я ждал больше сорока минут плюс ко всему, про один десерт официантка совсем забыла и несла его еще минут 20. И что больше всего удивили и не понравилось, то что в меню в составе десерта было написаны одни ингридиенты, а реальном блюде часть инегридиентов я так и не нашел! Так что если кто собиреться там пообедать или поужинать, то учтите, что заказ вы можете ждать Очень долго!',
#               'aspects': [(36, 41, 'positive'),
#                (237, 247, 'negative'),
#                (408, 413, 'negative')]},
#              '35904': {'text': '27.04.2013 Посетила ваш ресторан Евразия,с семьей в г.Ломоносове!Все понравилось!Сервис на высочайшем уровне, большой выбор по меню и напиткам )приятный интерьер, тихо, спокойно!Официантка Марина,была вежлива,приветлива очень быстро приняла заказ)очень порадовала кухня, быстро готовят, невероятно все было вкусно. Ребята работают в команде,все время администратор помогал официантам.Спасибо вам огромное ) Удачи вам и процветания!!!',
#               'aspects': [(81, 87, 'positive'),
#                (127, 131, 'positive'),
#                (134, 142, 'positive'),
#                (153, 161, 'positive'),
#                (178, 188, 'positive'),
#                (264, 269, 'positive'),
#                (315, 321, 'positive'),
#                (351, 364, 'positive')]},
#              '36725': {'text': 'Посетили зтот ресторан 8 марта втроем по купонам. Обстановка приятная, столы большие, обслуживание порадовало, персонал внимательный. Очень понравился официант Шахид, отвечал на все вопросы относительно блюд, заказ не пришлось долго ждать. Еда понравилась, порции большие, красиво оформлены, все вкусно. Все столики были заняты, но никто не мешал спокойно поговорить, музыка играла не громко. Очень вкусные десерты: тирамису, черничный пирог и черный лес. По ценам с купонами получилось вполне приемлемо. С бутылочкой вина, салатами, горячим и десертами получилось меньше 1000 рублей на человека.',
#               'aspects': [(50, 60, 'positive'),
#                (71, 76, 'positive'),
#                (86, 98, 'positive'),
#                (111, 119, 'positive'),
#                (151, 159, 'positive'),
#                (240, 243, 'positive'),
#                (257, 263, 'positive'),
#                (407, 414, 'positive'),
#                (416, 424, 'positive'),
#                (426, 441, 'positive'),
#                (444, 454, 'positive')]},
#              '28258': {'text': 'Заехали с мужем поужинать в пятницу ( 17.01.14.) в 23:00. Первым нас встретил парковщик, помог припарковаться и даже открыл двери и вежливо нас поприветствовал. Интерьер ресторана мне нравится, я люблю такой дизайн. Все просто и со вкусом, много интересных мелочей. Нас обслуживала приятная девушка. К сожалению не запомнили ее имя. Она была внимательна и ненавязчива и помогла мне с выбором пасты, подробно рассказав состав и способ приготовления блюда. Меню ресторана большое в виде журнала, есть все что угодно....вареники, суши, вок, пасты и т.д. Дизайн меню интересный, дизайнеры молодцы! Я ела крем суп из белых грибов (примерно 350 р.) и пенне с уткой ( 450 р.). Суп был вкусный, но паста была просто божественна. Много соуса, мягкое мясо утки. Пастой я была очень довольна))) Муж ел салат с говядиной и карпаччо ( цены я не помню). Нам все очень понравилось. От визита мы получили положительные эмоции...поболтали и вкусно поели! Будем приезжать еще в этот ресторан. Спасибо поварам и персоналу за хорошие эмоции!',
#               'aspects': [(78, 87, 'positive'),
#                (161, 169, 'positive'),
#                (208, 214, 'positive'),
#                (291, 298, 'positive'),
#                (455, 459, 'positive'),
#                (551, 562, 'positive'),
#                (670, 673, 'positive'),
#                (690, 695, 'positive'),
#                (727, 732, 'positive'),
#                (741, 750, 'positive'),
#                (752, 758, 'positive'),
#                (965, 973, 'positive'),
#                (983, 990, 'positive'),
#                (993, 1002, 'positive'),
#                (791, 808, 'positive'),
#                (89, 94, 'positive'),
#                (931, 936, 'positive'),
#                (270, 281, 'positive'),
#                (370, 377, 'positive'),
#                (69, 77, 'positive')]},
#              '19467': {'text': 'На днях я таки посетила Террасу, в которой не была уже пару месяцев. Соскучилась!) Зашли небольшой женской компанией, часов в 9. Народ в это время собрался крайне гламурный, всё вокруг пестрило брендами и драгоценностями. Мне нравится стильный гламур (не знаю, употребляется ли такое выражение), а не... розовый. Это я к тому, что за соседним столиком сидели две дамочки с ног до головы в розовом. Очень забавные, повеселили.) Часов в 11 (сидели мы довольно долго) к нам подсели трое молодых людей, чтобы познакомиться. Знакомиться мы не стали, но и настроение они нам, к счастью, не испортили. Официантка попалась хорошая: внимательная, без оценивающих взглядов, и ждать часами её не приходилось. Сервис в Террасе не плохой, но раз на раз не приходится. В этот раз повезло. Кухня, как всегда, на уровне. Меню интересное и разнообразное. Салаты и паста просто потрясающие. Алкоголь, действительно, вкусный.) Цены приемлемые. В целом Терраса не разочаровывает и продолжает оставаться одним из любимых мест.',
#               'aspects': [(595, 605, 'positive'),
#                (775, 780, 'positive'),
#                (805, 809, 'positive'),
#                (838, 844, 'positive'),
#                (847, 852, 'positive'),
#                (873, 881, 'positive'),
#                (933, 940, 'positive')]},
#              '34761': {'text': 'Хочется поделиться со всеми пользователями сайта отзывом о ресторане Duplex. Данный ресторан мы выбрали для празднования свадебного праздничного ужина в кругу друзей и близких. Предварительно посетив данный ресторан, нам удалось оценить качество блюд и наглядно посмотреть интерьер внутри. Так как торжество планировалось на 25 человек, места для наших гостей было вполне достаточно и для танцев в том числе. Менеджер Алексей, который принимал наш заказ и подписывал договор, провёл всё мероприятие сам, чем очень нас порадовал. В меню мы выбирали разнообразные блюда и все они были очень вкусными. Стол был богатым и ярким. Украшать зал отдельно не пришлось, интерьер очень уютный и располагающий для торжественного мероприятия. Все остались очень довольны, едой, сервисом и доброжелательной атмосферой в ресторане. Спасибо большое Алексею, за наш праздник! Если бы мне пришлось второй раз выбирать ресторан, я не усомнившись сделала выбор в пользу Duplex!',
#               'aspects': [(337, 359, 'positive'),
#                (409, 417, 'positive'),
#                (562, 567, 'positive'),
#                (599, 603, 'positive'),
#                (660, 668, 'positive'),
#                (759, 763, 'positive'),
#                (765, 773, 'positive'),
#                (793, 803, 'positive'),
#                (950, 956, 'positive')]},
#              '36359': {'text': 'Н Начну из далека)) года 1,5-2 назад заходила в "дали" и осталась с неоднозначными впечатлениями (то ли понравилось,то ли нет).Кухня никакая,какой-то странный персонал в непонятной форме,обслуживание тоже ни о чем.Единственное что зацепило - дизайн кафе,уж очень красивый. Буквально на днях решила рискнуть и зайти отдохнуть. Кафе можно было узнать только по оставленному дизайну,все остальное поменялось. Заказала себе салат,так мне даже было жалко его съесть,настолько было красиво украшен))я уже не говорю,что было очень вкусно). Очень понравилось ненавязчивое и качественное обслуживание. Спасибо Вам большое за уютную атмосферу,от Вас даже не хотелось уходить,все настолько было тепло и радушно!)',
#               'aspects': [(242, 248, 'positive'),
#                (420, 425, 'positive'),
#                (420, 425, 'positive'),
#                (579, 591, 'positive'),
#                (623, 632, 'positive')]},
#              '36948': {'text': 'Была в этом ресторане уже четыре раза с декабря прошлого года. Прекрасное вино, вкусная еда с красивой подачей, спокойная атмосфера и замечательное обслуживание. Что касается оценок (от 1 - 10): - 7 ставлю за кухню потому, что хотелось бы больше разнообразия в меню по основным блюдам. - 5 за интерьер - не очень уютно на этих стульях, сумочку никуда не поставить, оптимальные места у окна (относительно комфортно) - 10 за сервис - всегда внимательный и в то же время незаметный персонал, что и должно соответствовать ресторанному обслуживанию.',
#               'aspects': [(74, 78, 'positive'),
#                (88, 91, 'positive'),
#                (103, 110, 'positive'),
#                (122, 131, 'positive'),
#                (148, 160, 'positive'),
#                (269, 284, 'negative'),
#                (293, 301, 'negative'),
#                (327, 334, 'negative'),
#                (377, 389, 'positive'),
#                (423, 429, 'positive'),
#                (479, 487, 'positive'),
#                (261, 265, 'positive')]},
#              '28745': {'text': 'На день рождения моей девушки, мы решили сходить в ресторан. Я выбрал "Мидзуки" основываясь на отзывах с этого сайта, и не ошибся - очень уютное место, вкусная еда (заказывали роллы и рис с курицей), музыка ненавязчивая и тихая. Сервис - хороший, - официантки, заметив что на них смотришь, - не делают вид, что не заметили, а подходят:) Ждать заказа пришлось не больше, чем ожидаешь от ресторана - тарелки появились ровно в тот момент, когда мне в первый раз пришло в голову, что пора бы уже всё-таки принести)) В общем, вечер провели замечательно, теперь буду водить туда друзей.',
#               'aspects': [(71, 78, 'positive'),
#                (145, 150, 'positive'),
#                (160, 163, 'positive'),
#                (176, 181, 'positive'),
#                (184, 197, 'positive'),
#                (229, 235, 'positive'),
#                (249, 259, 'positive')]},
#              '29395': {'text': 'Ресторан очень хороший!!! С ним у меня связано очень трепеиное и важное событие...в этом ресторане мне мой будущий муж сделал предложение (кстати, свадьба через неделю и мы будем отмечать ее только там). Кухня замечательная, обслуживание на 10.Не пришлось ждать меню, как это обычно бывает в некоторых ресторанах. Мы сели, заказали грузинские блюда, шампанское, через минут 5 нам принесли самое вкусное шампанское, которое я пила в жизни. .... Заказ тоже не пришлось ждать очень долго, минут 20, нормально. Мы кушали, кушали, и никак не могли насладиться едой, она была такой вкусной, необычной, т.к. я была первый раз в грузинском ресторане. Там спокойно, музыка такая спокойная и восточная...))) Правда не помню живая ли она была, вроде, нет. Мы были там днем, а вечером там я это точно знаю, что намечалась какая-то программа. Мне очень понравилось!!!! Если Вы ищите ресторан для какого-либо важного события, можете смело идти в "ТБИЛИСО"!!! Если не понравитсяЯ, можете меня исбить...:-))))',
#               'aspects': [(0, 8, 'positive'),
#                (204, 209, 'positive'),
#                (225, 237, 'positive'),
#                (403, 413, 'positive'),
#                (555, 559, 'positive'),
#                (657, 663, 'positive'),
#                (932, 941, 'positive')]},
#              '16714': {'text': 'Были в пятницу (19.03.10), заказывали столик для родительского праздника на воскресенье, заодно и попробовали немного кухню сами. Взяли шашлык по азейрбаджански (из баранины), хачипури Имеритенское, салат Байрам и овощи на гриле. Хачипури немного подкачало, показалось что маловато сыра, хотя наверное на любителя. Салат сочный и вкусный, баранина и овощи очень достойные. Сервис оставляет приятное впечатление. Официант ненавязчивы, но учтивый...очень хорошее сочетание. Интерьер к сожалению не оценил...на уровне, но не более, хотя может быть для приятного обеда более и не надо. Родители остались очень довольны. Особенно хочется выразить признательность администратору, работавшему в эти дни (к сожалению не запомнил имя девушки). Очень хотелось, чтобы родителям понравилось, и сервис оказался выше всяких похвал.',
#               'aspects': [(315, 320, 'positive'),
#                (339, 347, 'positive'),
#                (350, 355, 'positive'),
#                (373, 379, 'positive'),
#                (412, 420, 'positive'),
#                (559, 564, 'positive'),
#                (658, 672, 'positive'),
#                (782, 788, 'positive')]},
#              '3385': {'text': 'Не могу не рассказать, как прошел банкет на мою свадьбу. Итак, когда мы приехали закуски уже были готовы, все было вкусно и как должно быть. Официантка, все делала четко. Бокалы были полны, тарелки пустые во время убирались. Второе мы заказывали по меню. После заказа прошло около полу часа, а может и больше, когда к о мне подошла официантка и сказала, что на кухне нет света, и надо делать другой заказ на горячее (на углях). После бракосочетания и прогулки по городу, как понимаете гости всегда голодные. Да, закуски, как-то смягчили желание поесть, но не на столько, чтобы ждать еще час. Делать было нечего, все опять сели за стол и стали выбирать себе другие блюда, через 20 минут был сделан еще один заказ. И через 30 минут стало совсем смешно, когда ко мне подошла администратор и сказала, что горячего на углях не будет. Будет выполнен первоначальный заказ. В тот день мне ни чем нельзя было испортить настроение. Через 15 минут, на столах появился наш заказ. Тогда уже было все равно, главное накормить гостей, ну и себя) Торт. заказанный заранее (наполеон) не оправдал моих ожиданий, ну что ж на вкус и цвет товарища нет. Что касается интерьера, то он очень подходит для торжеств, удалось поработать с фотографом в интерьерах зала VIP. Рекомендую, но. видимо, ВСЮ кухню надо заказывать заранее. а лучше еще и попробовать!',
#               'aspects': [(81, 88, 'positive'),
#                (141, 151, 'positive'),
#                (332, 342, 'negative'),
#                (1057, 1065, 'negative'),
#                (1145, 1154, 'positive')]},
#              '35620': {'text': 'Об этом заведение достаточно расхожее мнение, решила проверить сама, так как живу по близости. Зашла днем пообедать, встретили достаточно радушно, спросили в первые я в заведение или уже была, это говорит о том, что персонал заботлив к своим гостям и помнит всех постоянных) Мне помогли с выбором столика и рассказали о всех акциях и предложениях. Особенно порадовала 50% скидка на японское меню) Обслуживание быстрое и внимательное, еда понравилась, ассортимент бара большой но я пила только чай, так как пришла пообедать и о качестве напитков сказать ничего не могу. При расчете официант красочно рассказал о программе в выходные дни, о вечеринках и артистах, просто не смогла ему отказать и обещала обязательно придти! Вообще мое впечатление достаточно положительное об этом заведение и я планирую его посещать теперь часто.',
#               'aspects': [(216, 224, 'positive'),
#                (382, 395, 'positive'),
#                (397, 409, 'positive'),
#                (434, 437, 'positive'),
#                (451, 467, 'positive'),
#                (581, 589, 'positive'),
#                (778, 787, 'positive'),
#                (279, 286, 'positive'),
#                (117, 126, 'positive')]},
#              '31004': {'text': 'Были с мужем, хотели отметить дату знакомства, НО! Долго (минут 15-20)ждали в гардеробе, пока нас пригласят внутрь, хотя было уже достаточно поздно и когда мы вошли оказалось, что зал был полупустой. Ладно... Не нервничаем... Доброжелательные такие, праздник всё-таки... Интерьер интересный. Заказываем блюда, названий не помню (я - что-то из курицы, муж захотел попробовать конину). Горячее готовилось минут 10... быстро - не спорю, но КАК за 10 минут можно приготовить конину? Было полное ощущение и от вида и от вкуса, что блюда стояли уже пару суток и были просто разогреты в микроволновке. Никакой соли, никаких специй, совершенно пресная еда (хотя, не спорю, кто-то любит и так, но официанты могли бы предупредить и поставить на стол побольше специй)! Сервировано просто никак. Доесть не смогли. Настроение импортилось. Самым съедобным оказался салат из зелени и овощей, согласитесь, сложно испортить. Цены в общем, средние,но при такой кухне совершенно неоправданные. Мы и за доплату больше туда не пойдём.',
#               'aspects': [(271, 279, 'positive'),
#                (384, 391, 'negative'),
#                (526, 531, 'negative'),
#                (603, 607, 'negative'),
#                (617, 623, 'negative'),
#                (644, 647, 'negative'),
#                (688, 697, 'negative'),
#                (943, 948, 'negative'),
#                (943, 948, 'negative')]},
#              '34889': {'text': 'Гуляли в центре с сестрой, измывали от жары в эти прекрасные редкие теплые деньки... Нагуляли аппетит, решили зайти в ресторанчик пообедать. Давно собиралась посетить ресторан Кухню, а тут и недалеко оказались. Уже на пороге почувствовав легкую прохладу кондиционера и услышав приятную музыку, поняли, что сделали правильный выбор! Девушки администраторы вежливые и приятные, уютная атмосфера, ненавящево стильный интерьер, удобные столики, чисто и со вкусом. Меню. Разнообразие блюд, официанты компетентные, назовут ингредиенты, посоветуют что- то в соответствии с вашими предпочтениями в еде. Пообедали замечательно, быстро, сытно и что самое главное- очень вкусно! Потрясающие десерты, я как настоящий ценитель сладкого, ставлю самую высокую оценку. На самом деле можно много расхваливать, но, наверное, каждому стоит самому оценить. Могу смело рекомендовать это место тем, кто хотел бы ты посидеть в приятной атомосфере и получить удовольствие от хороших и качественно приготовленных блюд! Найти минусы всегда можно в любом месте, в какое мы бы не пришли, все зависит и от нашего настроения. Хотя в некоторых местах нашего города они сами себя находят, эти минусы... Здесь объективно - отличное место.',
#               'aspects': [(254, 266, 'positive'),
#                (286, 292, 'positive'),
#                (332, 354, 'positive'),
#                (383, 392, 'positive'),
#                (414, 422, 'positive'),
#                (432, 439, 'positive'),
#                (479, 483, 'positive'),
#                (485, 494, 'positive'),
#                (680, 687, 'positive'),
#                (866, 871, 'positive'),
#                (913, 923, 'positive'),
#                (988, 992, 'positive'),
#                (1199, 1204, 'positive')]},
#              '14190': {'text': 'Добрый день! Мы с молодым человеком любим открывать новые места..разные рестораны..особенно итальянские. Были во многих уже. Нашла по рейтингу ресторан, пришли, все гости сидели на террасе (лето все таки), а мы сели внутри (поближе к конждиционеру)). Интерьер очень уютный. Сидели прямо напротив кухни (где пиццу готовят) около окна. Есть отзывы, что пахнет кухней..но я не особо заметила..да и легкий аромат пиццы думаю только аппетита прибавит) Начиталась отзывов, что хорошая пицца - взяли именно ее, и остались очень довольны!! Во всех итальянских ресторанах беру тирамису, хлебную козинку и ...захожу в туалет. Таким образом я ставлю оценку заведению. Хлеб должен быть свежий, тираму таять во рту, а на туалетах не должны экономить!! Все понравилось, десерт волшебный! Мило посидели, в окно видела Спас на крови...романтик) Официантка вежливая очень. Напитки принесла быстро...да и еду совсем не пришлось ждать! в общем большое спасибо за атмосферу и угощения. Обязательно придем еще!',
#               'aspects': [(251, 259, 'positive'),
#                (479, 484, 'positive'),
#                (756, 762, 'positive'),
#                (791, 795, 'positive'),
#                (829, 839, 'positive'),
#                (944, 953, 'positive'),
#                (956, 964, 'positive')]},
#              '36166': {'text': 'Здравствуйте! Регулярно с друзьями посещаем данный ресторан! Если хочется провести выходные в какой-нибудь компании душевно, весело, вкусно, то ресторан очень хорошо для этого подходит! Прекрасная Маргарита, вкусная еда и отличная музыка!!! Живу в другом районе, но с радостью приезжаю именно сюда, да простят меня остальные мексиканские рестораны, за мексиканкой едой, атмосферой и отлично провести вечер! Радует также, что кухня по выходным работает долго в отличие от многих других заведений! В общем, место ни разу не подводило, рекомендую!',
#               'aspects': [(51, 59, 'positive'),
#                (144, 152, 'positive'),
#                (197, 206, 'positive'),
#                (216, 219, 'positive'),
#                (231, 237, 'positive'),
#                (352, 368, 'positive'),
#                (370, 380, 'positive'),
#                (505, 510, 'positive')]},
#              '12591': {'text': 'Я недавно переехала в Пушкин.Абсолютно не было времени ,чтобы прогуляться даже по парку,я уже не говорю про какие-либо рестораны.Недавно мне повезло и я выкроила время,чтобы пойти в Екатериненский парк.Погода выдалась ужасная ,решила скрыться в каком-нибудь уютном кафе.Подошла к первому человеку,идущему на встречу и поинтересовалась ,где есть хорошее место,чтобы выпить кофе.Мужчина ,не сомневаясь ответил,что на улице Московской есть чудесное кафе "White-Rabbit". Придя туда ,меня удивила очень уютная атмосфера,приветливый персонал и конечно же интерьер,отдаю должное хозяевам и дизайнеру!В тот день я пила американо(пожалуй самый вкусный)и ела филадельфию,осталась довольна,продукты свежие,кофе ароматный! Через неделю сходила с подругой,заказали 2 стейка (стриплойн) и бутылку красного вина.Такие стейки редко встретишь в СПб,очень вкусные!Всё очень понравилось!Кстати обслуживание очень приятное,их не видно,но тарелки исчезают сразу же.! Думаю пойти на вечер итальянского вина Novello. Спасибо за такое чудесное место в Пушкине!Удачи!',
#               'aspects': [(446, 465, 'positive'),
#                (505, 514, 'positive'),
# ...
#              '10625': {'text': 'Субботним вечером зашли компанией в кафе Dolce Italy, попить кофе с пирожными. Было без пятнадцати девять, а кафе, как оказалось, закрывается ровно в девять вечера. Нам любезно предложили разместиться в ресторане, а пирожные пообещали принести туда. Так и произошло наше знакомство с рестораном Italy. Народу было много, полный зал. Для нас смогли найти только столик для курящих, но это сильно не помешало, так как вентиляция справляется. То что мы заказывали, нам понравилось. Интерьер спокойный, сделано со вкусом, но без особых изысков. На мой взгляд, больше подходит для компании, чем для того, чтобы прийти вдвоём. Что касается сервиса, то официантка в начале про нас забыла, пришлось окримнуть, чтоб сделать заказа. Но в остальном всё вежливо и предупредительно. К салату цезарь нужен был соус без анчоусов. Вначале повар сказал, что они могут предложить лишь майонез, что соус готовится утром одинаковый для всех. Минут через десять прибежал снова и обещал сделать всё в лучшем виде.. В общем, зайдём в это место снова. Обязательно попробуем больше итальянских блюд. Давно уже хотим с женой найти для себя хороший итальянский ресторан. Вдруг Italy окажется именно им? :)',
#               'aspects': [(416, 426, 'positive'),
#                (634, 641, 'negative'),
#                (646, 656, 'negative'),
#                (823, 828, 'negative'),
#                (867, 874, 'negative'),
#                (880, 884, 'negative'),
#                (1015, 1020, 'positive')]},
#              '19677': {'text': 'Хочу оставить свой отзыв об этом замечательном кафе. Отмечали мамин юбилей, все было просто замечательно! Недовольных не осталось, всем очень понравилась кухня! Большие порции, интересные салаты и горячее, все было очень сытно и вкусно за сравнительно небольшую цену! Очень приятное ненавязчивое обслуживание! Отдельное спасибо администратору Сергею! Остались только хорошие воспоминания! И какой восхитительный был торт! Всем рекомендую посетить это замечательное кафе! Отлично подходит для проведения небольших банкетов! Уютно и по-домашнему!',
#               'aspects': [(47, 51, 'positive'),
#                (154, 159, 'positive'),
#                (169, 175, 'positive'),
#                (188, 194, 'positive'),
#                (188, 194, 'positive'),
#                (197, 204, 'positive'),
#                (197, 204, 'positive'),
#                (296, 308, 'positive'),
#                (328, 342, 'positive'),
#                (416, 420, 'positive'),
#                (465, 469, 'positive')]},
#              '3552': {'text': 'Недавно праздновала день рождение на 40 человек, это было просто незабываемо. Очень вкусная пицца и салаты на закуску, большой выбор горячих блюд на любой вкус, все гости были удивлены качеством приготовления и очень вкусными блюдами. Заказали большой торт тирамису на десерт, собственного приготовления- это было очень вкусно, но места в животе уже не оставалось, поэтому раздавали гостям в домой. Тихая, приятная музыка. Очень внимательные официанты и администраторы. Спасибо вам огромное за праздник и очень душевную обстановку:))',
#               'aspects': [(92, 97, 'positive'),
#                (100, 117, 'positive'),
#                (133, 145, 'positive'),
#                (226, 233, 'positive'),
#                (252, 265, 'positive'),
#                (415, 421, 'positive'),
#                (442, 451, 'positive'),
#                (454, 468, 'positive')]},
#              '22527': {'text': 'Сегодня отмечали день рождения небольшой компанией из шести человек. Нас разместили в VIP зале. Понравилось оформление стола, подсвечник с горящими свечами создал уютную атмосферу семейного торжества. Обслуживание прекрасное: тарелки убирали сразу, новые блюда приносили быстро, так что ничего не надо было ждать. Кухня тоже приятно удивила, особенно размер порций. Все было свежим и отменно вкусным. Единственное "но"- это отсутствие живой музыки, с ней наш вечер был бы еще приятнее.иЗа сравнительно небольшие деньги отлично отдохнули и поели. Следующий раз не буду думать, куда пойти отмечать какое-нибудь торжество.',
#               'aspects': [(108, 124, 'positive'),
#                (126, 155, 'positive'),
#                (170, 179, 'positive'),
#                (201, 213, 'positive'),
#                (314, 319, 'positive'),
#                (358, 364, 'positive')]},
#              '2345': {'text': 'Вчера впервые побывали у вас на Комендантском 2. Очень уютная атмосфера. Обслуживание и внимание персонала выше всяких похвал! (отдельное спасибо официанту Евгению, обслуживающего наш столик). Долгое время мы были завсегдатаями другого итальянского ресторана, теперь наши сердца (и желудки))) принадлежат Капоне!!! Было немного рискованно для нас прийти к вам вчера впервые, т.к. планировался ужин в честь моего Д.Р. Но мы остались в полном восторге, и уже сегодня с утра, созваниваясь с друзьями всем настоятельно рекомендовала к вам прийти!!! Уже довольно давно отношусь к своему дню рождения более чем спокойно, ограничиваясь тихим семейным ужином. НО вчера ... впервые за много лет вернулось настроение праздника, как из детства! За что огромное вам спасибо!!! Отдельно хочется отметить качество живой музыки! Были приятно удивлены! И конечно наши комплименты повару!!! И вкус и оформление блюд достойны самой высокой оценки!!! Обязательно будем заходить к вам по всем поводам, и без оных, и конечно будем рекомендовать ваш ресторан всем своим друзьям! Еще раз огромное спасибо за великолепный вечер!!!',
#               'aspects': [(62, 71, 'positive'),
#                (73, 85, 'positive'),
#                (97, 106, 'positive'),
#                (146, 155, 'positive'),
#                (305, 311, 'positive'),
#                (800, 812, 'positive'),
#                (864, 870, 'positive'),
#                (894, 898, 'positive'),
#                (894, 898, 'positive'),
#                (1028, 1036, 'positive')]},
#              '8996': {'text': 'Были с друзьями в пабе Метрополь, всё очень понравилось. При входе открывает дверь швейцар, далее стойка с хостес, все очень вежливые, просторная гардеробная, красивая лестница. Интерьер на очень достойном уровне, чувствуется что заведение держит свою марку. В пабе большие деревянные столы, удобные стулья, есть телевизоры, в тот день крутили какой-то концерт. Ненавязчивый и услужливый официант, даже не записывал наш заказ, всё запоминал, видимо знает своё дело :) Сразу скажу про цены, это не забегаловка, поэтому на хороший ужин с пивом, одному человеку нужно как минимум иметь при себе 1500 руб. Но если вы действительно хотите провести приятный вечер в приличном месте, то оно того стоит. Порции не маленькие, а пиво вкусное, блюда готовили не очень долго, мы не успели утомиться в ожидании. В общем, впечатления от паба позитивные, спасибо персоналу ресторанного комплекса за то, что стараетесь сделать клиентов довольными!!! Отдельное спасибо за красоту, за интерьеры!',
#               'aspects': [(18, 32, 'positive'),
#                (83, 90, 'positive'),
#                (146, 157, 'positive'),
#                (168, 176, 'positive'),
#                (178, 186, 'positive'),
#                (230, 239, 'positive'),
#                (285, 290, 'positive'),
#                (300, 306, 'positive'),
#                (313, 323, 'positive'),
#                (388, 396, 'positive'),
#                (670, 675, 'positive'),
#                (696, 702, 'positive'),
#                (719, 723, 'positive'),
#                (823, 827, 'positive'),
#                (848, 857, 'positive'),
#                (955, 962, 'positive'),
#                (967, 976, 'positive')]},
#              '9878': {'text': 'Пришли в данное заведение 4 июня 2014 года покушать шашлык... Заказали из говядины и свинины. Сидели ждали заказ минут 30, потом к нам подошел человек "на кочерге" и сказал, что он очень извиняется и что шашлык скоро принесут...через минут 10 нам принесли холодное мясо ( причем что мы взяли 2 разных)...Когда мы сказали, что шашлык холодный перед нами снова извинился все тот же мужчина и предложил его подогреть... на вкус он был просто отстой (мой муж половину просто не съел, хотя обычно есть все, что не приколочено)... Это единственное заведение, в котором мы не оставили на чай за последние 5 лет! Никому не посоветую еду из данного заведения. Хотя счет нам принесли за минуту.',
#               'aspects': [(143, 150, 'negative'),
#                (265, 269, 'negative'),
#                (326, 332, 'negative'),
#                (380, 387, 'negative'),
#                (420, 424, 'negative'),
#                (542, 551, 'negative'),
#                (640, 649, 'negative')]},
#              '33825': {'text': '06.09.2013 были на ужине в ресторане Пури. Выбирали по местоположению и ориентировались на отзывы посетителей. Заказали столик по телефону. Встретила нас прекрасная девушка администратор, проводила до столика. Место оказалось просто замечательным. Интересный интерьер, все красочное и при этом очень домашняя обстановка. Обслужили нас по высшему разряду. Очень грамотный официант Андрей, за что ему отдельное спасибо. Уделял нам достаточного много времени и при этом не был навязчивым. Порекомендовал отличный чай, от которого мы были в восторге. Меню очень разнообразное. Принесли заказ быстро. Все вкусно. Буду рекомендовать сходить друзьям и знакомым. Появилось желание посетить и другие заведения сети Гинза.',
#               'aspects': [(165, 186, 'positive'),
#                (210, 215, 'positive'),
#                (259, 267, 'positive'),
#                (309, 319, 'positive'),
#                (371, 379, 'positive'),
#                (510, 513, 'positive'),
#                (547, 551, 'positive'),
#                (321, 330, 'positive'),
#                (573, 587, 'positive'),
#                (111, 126, 'positive')]},
#              '15655': {'text': 'Сегодня посетили этот ресторан с девушкой. Очень понравилось. Интерьер отличный, все из дерева и очень красиво! Официанты внимательны и ненавязчивы! Играет приятная музыка! Что касается кухни: Остался в восторге от теплого салата с говядиной, и конечно стейк из говядины! Еще не могу не отметить крем-суп из лосося! Ребята просто молодцы - очень очень вкусно! И порции "достойные". В общем были приятно удивлены таким замечательным местом, обязательно придем еще, и не один раз!',
#               'aspects': [(62, 70, 'positive'),
#                (112, 121, 'positive'),
#                (165, 171, 'positive'),
#                (215, 241, 'positive'),
#                (253, 270, 'positive'),
#                (296, 314, 'positive'),
#                (362, 368, 'positive'),
#                (432, 438, 'positive')]},
#              '17475': {'text': 'Была вчера в этом ресторане!Поехала туда не целеноправленно,так что ничего конкретного об этом месте не знала)Начнем со входа!Есть гардероб и приятный гардеробщик,далее открывается вид в зал-хорошая мебель и приятный интерьер ,печально что нет некурящей зоны!Встретили нормально (никакой улыбки на лице администратора при этом не было) ,проводили к столу.Официант не ориентируется в меню,не видит столы,из рук все валится,грязные тарелки стояли по 10 минут на столе и это при неполном зале!!!?Да уж) Кухня:кушали японскую кухню,вкусная еда и немаленькие порции,подача обычная.А еще салат цезарь-тоже вкусно!Услышала что скидку постоянным гостям по фамилии,без карточки,не делают- не знаю хорошо ли это?!Проводили всем персоналом,уже с улыбкой и доброжелательным видом!',
#               'aspects': [(131, 139, 'positive'),
#                (151, 162, 'positive'),
#                (199, 205, 'positive'),
#                (217, 225, 'positive'),
#                (244, 258, 'negative'),
#                (355, 363, 'negative'),
#                (513, 527, 'positive'),
#                (536, 539, 'positive'),
#                (554, 560, 'positive'),
#                (582, 594, 'positive'),
#                (718, 728, 'positive'),
#                (181, 190, 'positive'),
#                (500, 505, 'positive'),
#                (259, 268, 'positive'),
#                (337, 354, 'positive')]},
#              '22015': {'text': 'Впечатление заведение оставило не самые лучшие!!а жаль.....новое место в центре города!!Во-первых гостей никто не встречает и не провожает к столу,не говоря уже о том,что зал для курящих или не курящих предложен вообще не был!!Подруга заказала бизнес-ланч,а меню я так и не увидела,так как его просто не принесли!!!Заказ был принят ужасно,вслед уходящему официанту мы договаривали свой заказ!!!я заказала чай,но даже его принесли без жасмина!!)))хлеб не был предложен,в принципе вообще ничего предложено не было!!!с таким обслуживанием у заведения вряд ли появятся постоянные гости!!дальше..хуже...счёт нам вынесли,когда мы еще кушали,и даже не просили его,видно в этом заведении не любят ,когда гости задерживаются,сложилось впечатление,что нам определённо пора!!!=))) Интерьер милый,есть диванчики,правда не очень мягкие!!',
#               'aspects': [(12, 21, 'negative'),
#                (355, 364, 'negative'),
#                (790, 799, 'negative')]},
#              '18518': {'text': 'Мы были в этом ресторане 2 раза. Обслуживанием очень довольны, скатерти меняют после каждого посетителя, все очень чисто. Официанты очень подготовленные, могут рассказать, что из чего готовиться, как подаётся. Порции достаточно большие. Всё вкусно! Единственный минус - в праздники и выходные у них очень много посетителей, хотя это говорит о том, что ресторан хороший...И поэтому готовят очень долго! Закуски и салаты приносят быстро, а горячее нужно ждать. За ожидание нам принесли комплимент - мороженое для ребенка. Кстати, мороженое они готовят сами! Очень вкусно!',
#               'aspects': [(33, 46, 'positive'),
#                (122, 131, 'positive'),
#                (210, 216, 'positive'),
#                (352, 360, 'positive'),
#                (484, 494, 'positive'),
#                (528, 537, 'positive')]},
#              '10231': {'text': 'Я несколько раз была в этом заведении,о кухне могу сказать только самое хорошее.Потрясающая паста с лососем,очень вкусные супчики,отличные десерты.Последний раз была с друзьями,все остались довольны и обслуживанием и едой.Интерьер не плохой, несколько залов на разный вкус и компанию.Вообщем стоящее место для обеда и посиделок с друзьями.',
#               'aspects': [(40, 45, 'positive'),
#                (92, 107, 'positive'),
#                (122, 129, 'positive'),
#                (139, 146, 'positive'),
#                (201, 214, 'positive'),
#                (217, 221, 'positive'),
#                (300, 305, 'positive')]},
#              '11793': {'text': 'Являемся постоянными посетителями данного заведения более года. Главное, что хотелось бы отметить - постоянно высокое качество кухни. Это одно из немногих мест, где хочется попробовать все и сразу. Обязательно рекомендуем попробовать суши и роллы. Она обалденны, готовят их быстро, всегда свежие и очень вкусные! Удивительная особенность для сети ресторанов то, что и в других ресторанах (Комендантский, Петроградская) уровень сервиса и кухни остается на том же уровне. Особенно это хорошо видно, если Вы являетесь постоянным посетителем Палок или Евразии =)) Единственное, что хочется отметить из негативного - в зале для некурящих бывает холодно, когда открывается входная дверь, но это мелочи. Если Вы идете туда в первый раз - обязательно попробуйте мороженое в кляре - лучшее в городе. А вот горячее раз на раз не приходится. Бывает приносят и холодным.. Обслуживание хорошее, но иногда приносят все сразу: и суши и суп и десерт. Надеюсь, качество обслуживания и кухни будет столь же высоким, все-таки любимый ресторан!',
#               'aspects': [(42, 51, 'positive'),
#                (118, 132, 'positive'),
#                (155, 159, 'positive'),
#                (234, 238, 'positive'),
#                (241, 246, 'positive'),
#                (342, 357, 'positive'),
#                (427, 434, 'positive'),
#                (437, 442, 'positive'),
#                (614, 632, 'negative'),
#                (754, 771, 'positive'),
#                (953, 965, 'positive'),
#                (968, 973, 'positive'),
#                (1015, 1023, 'positive')]}})

# %%
print(ipymarkup.show_line_markup(fin_spans['2073']['text'], fin_spans['2073']['aspects']))
# Out:
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><div><span style="display: inline-block; vertical-align: top">Три дня назад отмечали в этом &quot;ресторане&quot; день рождения. Сегодня решила почитать</span></div><div><span style="display: inline-block; vertical-align: top"> отзывы по этому </span><span style="display: inline-block; vertical-align: top; position: relative; margin-bottom: 11px"><span style="border-bottom: 3px solid #90caf9; padding-bottom: 8px">заведению</span><span style="font-size: 11px; line-height: 1; white-space: nowrap; text-shadow: 1px 1px 0px white; position: absolute; left: 0; bottom: -8px">negative</span></span><span style="display: inline-block; vertical-align: top">, так как вечер был просто испорчен. Складывается </span></div><div><span style="display: inline-block; vertical-align: top">такое впечатление, что мы были где-то в другом месте. Да, неплохой интерьер, </span></div><div><span style="display: inline-block; vertical-align: top">неплохая кухня... но все остальное просто ужас. Во-первых такого отвратительного</span></div><div><span style="display: inline-block; vertical-align: top"> </span><span style="display: inline-block; vertical-align: top; position: relative; margin-bottom: 11px"><span style="border-bottom: 3px solid #90caf9; padding-bottom: 8px">обслуживания</span><span style="font-size: 11px; line-height: 1; white-space: nowrap; text-shadow: 1px 1px 0px white; position: absolute; left: 0; bottom: -8px">negative</span></span><span style="display: inline-block; vertical-align: top"> я не видела нигде. На весь ресторан работала одна </span><span style="display: inline-block; vertical-align: top; position: relative; margin-bottom: 11px"><span style="border-bottom: 3px solid #90caf9; padding-bottom: 8px">официантка</span><span style="font-size: 11px; line-height: 1; white-space: nowrap; text-shadow: 1px 1px 0px white; position: absolute; left: 0; bottom: -8px">negative</span></span><span style="display: inline-block; vertical-align: top">, что </span></div><div><span style="display: inline-block; vertical-align: top">само по себе странно. Если бы она просто не справлялась с обилием заказов, то </span></div><div><span style="display: inline-block; vertical-align: top">еще как то извинительно, но она не очень то и старалась. Например вино нам несли</span></div><div><span style="display: inline-block; vertical-align: top"> 20 мин., курить мы выходили на улицу, где для этого стоят кресла и столик, </span></div><div><span style="display: inline-block; vertical-align: top">попросили ее принести пепельницу... она пообещала, но до конца нашего застолья </span></div><div><span style="display: inline-block; vertical-align: top">так этого и не сделала. На закуску мы среди прочего заказывали оливки, так их </span></div><div><span style="display: inline-block; vertical-align: top">нам принесли почти в конце вечера, про один заказ она вообще забыла, на что </span></div><div><span style="display: inline-block; vertical-align: top">просто извинилась. Отдельная история - </span><span style="display: inline-block; vertical-align: top; position: relative; margin-bottom: 11px"><span style="border-bottom: 3px solid #90caf9; padding-bottom: 8px">живая музыка</span><span style="font-size: 11px; line-height: 1; white-space: nowrap; text-shadow: 1px 1px 0px white; position: absolute; left: 0; bottom: -8px">negative</span></span><span style="display: inline-block; vertical-align: top">. Хороший певец, с хорошим </span></div><div><span style="display: inline-block; vertical-align: top">голосом... но для такого маленького </span><span style="display: inline-block; vertical-align: top; position: relative; margin-bottom: 11px"><span style="border-bottom: 3px solid #90caf9; padding-bottom: 8px">помещения</span><span style="font-size: 11px; line-height: 1; white-space: nowrap; text-shadow: 1px 1px 0px white; position: absolute; left: 0; bottom: -8px">negative</span></span><span style="display: inline-block; ver ...
# None

# %%
import json
with open("../data/final_sem_markup_train.json", 'w') as f:
    json.dump(fin_spans, f)
