# %%
import json
import xml.etree.ElementTree as ET
from razdel import tokenize

# %%
with open('../../data/final_sem_markup_train.json', 'r') as f:
    train = json.load(f)

# %%
test_path = '../../data/se16_ru_rest_test.xml'

# %%
def parse_aspects_sem(path):
    root_node = ET.parse(path).getroot()
    global_aspects = dict()
    tag_list = ['to','from','polarity','category','target']
    for rev in root_node.findall('Review/sentences/sentence'):
        id_ = rev.get('id')
        aspects = dict()
        for i, a in enumerate(rev.findall('Opinions/Opinion')):
            aspects[i] = dict()
            for tag in tag_list:
                aspects[i][f'{tag}'] = a.get(tag)
        global_aspects[f'{id_}'] = aspects
    return global_aspects

# %%
def parse_texts_sem(path):
    root_node = ET.parse(path).getroot()
    texts = dict()
    for rev in root_node.findall('Review/sentences/sentence'):
        texts[rev.get('id')] = rev.find('text').text
    return texts

# %%
list(tokenize(parse_texts_sem(test_path)['10106:0']))
# Out:
# [Substring(0, 5, 'Очень'),
#  Substring(6, 11, 'милый'),
#  Substring(11, 12, ','),
#  Substring(13, 19, 'уютный'),
#  Substring(20, 31, 'ресторанчик'),
#  Substring(32, 34, 'со'),
#  Substring(35, 44, 'скромными'),
#  Substring(45, 51, 'ценами'),
#  Substring(52, 54, 'за'),
#  Substring(55, 63, 'огромные'),
#  Substring(64, 70, 'порции'),
#  Substring(71, 81, 'вкуснейших'),
#  Substring(82, 86, 'блюд'),
#  Substring(86, 87, '.')]

# %%
test_texts = parse_texts_sem(test_path)

# %%
test_aspects = parse_aspects_sem(test_path)

# %%
test_aspects
# Out:
# {'10106:0': {0: {'to': '31',
#    'from': '20',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'ресторанчик'},
#   1: {'to': '70',
#    'from': '64',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'порции'},
#   2: {'to': '70',
#    'from': '64',
#    'polarity': 'positive',
#    'category': 'FOOD#PRICES',
#    'target': 'порции'},
#   3: {'to': '86',
#    'from': '82',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'блюд'}},
#  '10106:1': {},
#  '10106:2': {0: {'to': '6',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Салаты'},
#   1: {'to': '27',
#    'from': '20',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'зеленью'},
#   2: {'to': '33',
#    'from': '29',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'мясо'},
#   3: {'to': '42',
#    'from': '36',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'курица'},
#   4: {'to': '59',
#    'from': '53',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'десерт'},
#   5: {'to': '93',
#    'from': '72',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Семифреддо миндальный'}},
#  '10106:3': {0: {'to': '10',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Официантки'}},
#  '10106:4': {0: {'to': '73',
#    'from': '61',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'обслуживания'}},
#  '10106:5': {},
#  '10106:6': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10106:7': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10122:0': {0: {'to': '17',
#    'from': '9',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'ресторан'}},
#  '10122:1': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10122:2': {0: {'to': '5',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Кухня'}},
#  '10122:3': {0: {'to': '42',
#    'from': '26',
#    'polarity': 'positive',
#    'category': 'DRINKS#QUALITY',
#    'target': 'спиртные напитки'},
#   1: {'to': '49',
#    'from': '45',
#    'polarity': 'positive',
#    'category': 'DRINKS#QUALITY',
#    'target': 'вино'},
#   2: {'to': '79',
#    'from': '71',
#    'polarity': 'positive',
#    'category': 'DRINKS#QUALITY',
#    'target': 'коктейли'}},
#  '10122:4': {0: {'to': '20',
#    'from': '11',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'музыканты'}},
#  '10122:5': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#PRICES',
#    'target': 'NULL'}},
#  '10122:6': {0: {'to': '31',
#    'from': '25',
#    'polarity': 'negative',
#    'category': 'RESTAURANT#MISCELLANEOUS',
#    'target': 'сигары'},
#   1: {'to': '191',
#    'from': '177',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'администратору'}},
#  '10122:7': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10122:8': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10135:0': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Интерьер'}},
#  '10135:1': {0: {'to': '38',
#    'from': '30',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'интерьер'}},
#  '10135:2': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'NULL'}},
#  '10135:3': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'NULL'}},
#  '10135:4': {0: {'to': '34',
#    'from': '25',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#PRICES',
#    'target': 'ресторана'}},
#  '10135:5': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10135:6': {0: {'to': '22',
#    'from': '10',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'обслуживание'}},
#  '10135:7': {0: {'to': '50',
#    'from': '42',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официант'}},
#  '10135:8': {0: {'to': '49',
#    'from': '40',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официанты'}},
#  '10135:9': {0: {'to': '9',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Официанты'}},
#  '10135:10': {0: {'to': '13',
#    'from': '4',
#    'polarity': 'negative',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'ресторана'}},
#  '10135:11': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '10135:12': {},
#  '10135:13': {0: {'to': '50',
#    'from': '38',
#    'polarity': 'negative',
#    'category': 'FOOD#QUALITY',
#    'target': 'салат Кларет'},
#   1: {'to': '83',
#    'from': '79',
#    'polarity': 'neutral',
#    'category': 'DRINKS#QUALITY',
#    'target': 'вину'},
#   2: {'to': '94',
#    'from': '86',
#    'polarity': 'neutral',
#    'category': 'FOOD#QUALITY',
#    'target': 'десертам'},
#   3: {'to': '114',
#    'from': '110',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'мясо'}},
#  '10135:14': {0: {'to': '32',
#    'from': '23',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'ресторана'},
#   1: {'to': '103',
#    'from': '96',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'сервис.'}},
#  '10139:0': {},
#  '10139:1': {},
#  '10139:2': {0: {'to': '24',
#    'from': '17',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'встреча'}},
#  '10139:3': {},
#  '10139:4': {0: {'to': '29',
#    'from': '12',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'девушка-блондинка'}},
#  '10139:5': {},
#  '10139:6': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '10139:7': {},
#  '10139:8': {},
#  '10139:9': {0: {'to': '24',
#    'from': '11',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'стейк "Тауэр"'},
#   1: {'to': '48',
#    'from': '42',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'повару'},
#   2: {'to': '102',
#    'from': '95',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'девушке'}},
#  '10139:10': {0: {'to': '22',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Салат цезарь с курицей'},
#   1: {'to': '57',
#    'from': '51',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'гренки'},
#   2: {'to': '89',
#    'from': '83',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'гренок'}},
#  '10139:11': {0: {'to': '4',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'DRINKS#QUALITY',
#    'target': 'Пиво'},
#   1: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '10139:12': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '10139:13': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Интерьер'}},
#  '10139:14': {0: {'to': '13',
#    'from': '7',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'диваны'}},
#  '10139:15': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'NULL'}},
#  '10139:16': {},
#  '10139:17': {},
#  '10139:18': {0: {'to': '33',
#    'from': '22',
#    'polarity': 'negative',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'вентиляцией'}},
#  '10139:19': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'NULL'}},
#  '10139:20': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10139:21': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10139:22': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10139:23': {},
#  '10139:24': {0: {'to': '9',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Персоналу'}},
#  '10195:0': {0: {'to': '63',
#    'from': '51',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'ресторанчике'}},
#  '10195:1': {0: {'to': '15',
#    'from': '10',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'кухни'}},
#  '10195:2': {},
#  '10195:3': {0: {'to': '23',
#    'from': '16',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'овсянку'}},
#  '10195:4': {0: {'to': '6',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'Порция'}},
#  '10195:5': {},
#  '10195:6': {0: {'to': '6',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Тортик'},
#   1: {'to': '26',
#    'from': '20',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'порция'}},
#  '10195:7': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Интерьер'}},
#  '10195:8': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'NULL'}},
#  '10195:9': {0: {'to': '14',
#    'from': '5',
#    'polarity': 'neutral',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'диванчики'}},
#  '10195:10': {0: {'to': '53',
#    'from': '47',
#    'polarity': 'negative',
#    'category': 'RESTAURANT#MISCELLANEOUS',
#    'target': 'туалет'}},
#  '10195:11': {},
#  '10195:12': {0: {'to': '12',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Обслуживание'}},
#  '10195:13': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10287:0': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'NULL'},
#   1: {'to': '14',
#    'from': '9',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'место'},
#   2: {'to': '53',
#    'from': '47',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'порции'},
#   3: {'to': '70',
#    'from': '63',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'горячее'}},
#  '10287:1': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Интерьер'}},
#  '10287:2': {0: {'to': '32',
#    'from': '22',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официантка'}},
#  '10287:3': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '1040:0': {0: {'to': '9',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'RESTAURANT#PRICES',
#    'target': 'заведение'}},
#  '1040:1': {0: {'to': '45',
#    'from': '37',
#    'polarity': 'negative',
#    'category': 'DRINKS#STYLE_OPTIONS',
#    'target': 'алкоголь'},
#   1: {'to': '82',
#    'from': '73',
#    'polarity': 'negative',
#    'category': 'DRINKS#STYLE_OPTIONS',
#    'target': 'коктейлях'}},
#  '1040:2': {},
#  '1040:3': {0: {'to': '4',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'DRINKS#STYLE_OPTIONS',
#    'target': 'Вино'},
#   1: {'to': '50',
#    'from': '46',
#    'polarity': 'negative',
#    'category': 'DRINKS#STYLE_OPTIONS',
#    'target': 'пива'}},
#  '1040:4': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '1040:5': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '1040:6': {0: {'to': '6',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Бармен'}},
#  '1040:7': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'},
#   1: {'to': '39',
#    'from': '31',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'интерьер'}},
#  '10403:0': {0: {'to': '14',
#    'from': '9',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'место'}},
#  '10403:1': {0: {'to': '38',
#    'from': '28',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'обстановка'},
#   1: {'to': '53',
#    'from': '48',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'кухня'},
#   2: {'to': '78',
#    'from': '66',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'обслуживание'}},
#  '10403:2': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#PRICES',
#    'target': 'NULL'}},
#  '10403:3': {},
#  '10403:4': {0: {'to': '12',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Обслуживание'}},
#  '10403:5': {},
#  '10403:6': {0: {'to': '44',
#    'from': '36',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'краватке'}},
#  '10403:7': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '10403:8': {0: {'to': '3',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Еда'},
#   1: {'to': '32',
#    'from': '26',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'десерт'},
#   2: {'to': '43',
#    'from': '35',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'наполеон'}},
#  '10403:9': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10403:10': {0: {'to': '32',
#    'from': '20',
#    'polarity': 'neutral',
#    'category': 'DRINKS#QUALITY',
#    'target': 'Космополитан'},
#   1: {'to': '53',
#    'from': '46',
#    'polarity': 'neutral',
#    'category': 'DRINKS#QUALITY',
#    'target': 'коктель'}},
#  '10442:0': {0: {'to': '56',
#    'from': '51',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'блюдо'}},
#  '10442:1': {0: {'to': '40',
#    'from': '11',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Чебуреки с сыром и картофелем'},
#   1: {'to': '69',
#    'from': '53',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'сметанным соусом'}},
#  '10442:2': {0: {'to': '25',
#    'from': '20',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'блюдо'}},
#  '10442:3': {0: {'to': '23',
#    'from': '8',
#    'polarity': 'neutral',
#    'category': 'FOOD#QUALITY',
#    'target': 'салат с форелью'},
#   1: {'to': '161',
#    'from': '145',
#    'polarity': 'negative',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'оформление блюда'}},
#  '10442:4': {0: {'to': '17',
#    'from': '0',
#    'polarity': 'conflict',
#    'category': 'FOOD#QUALITY',
#    'target': 'Шашлык из свинины'},
#   1: {'to': '79',
#    'from': '59',
#    'polarity': 'negative',
#    'category': 'FOOD#QUALITY',
#    'target': 'пересоленный кусочек'}},
#  '10442:5': {},
#  '10442:6': {0: {'to': '12',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Обслуживание'},
#   1: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'},
#   2: {'to': '30',
#    'from': '15',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'скорость подачи'}},
#  '10442:7': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Интерьер'},
#   1: {'to': '44',
#    'from': '34',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'скамеечках'}},
#  '10442:8': {0: {'to': '58',
#    'from': '53',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'камин'}},
#  '10442:9': {0: {'to': '11',
#    'from': '8',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'зал'}},
#  '10442:10': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'NULL'},
#   1: {'to': '44',
#    'from': '39',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'место'},
#   2: {'to': '44',
#    'from': '39',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'место'}},
#  '10522:0': {0: {'to': '115',
#    'from': '109',
#    'polarity': 'negative',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'столик'}},
#  '10522:1': {},
#  '10522:2': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'NULL'}},
#  '10522:3': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'NULL'}},
#  '10522:4': {0: {'to': '7',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Девушка'}},
#  '10522:5': {0: {'to': '3',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Еда'},
#   1: {'to': '34',
#    'from': '29',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'роллы'}},
#  '10522:6': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Интерьер'}},
#  '10522:7': {0: {'to': '17',
#    'from': '12',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'залах'},
#   1: {'to': '58',
#    'from': '54',
#    'polarity': 'negative',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'зале'}},
#  '10546:0': {},
#  '10546:1': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '10546:2': {},
#  '10546:3': {0: {'to': '4',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'RESTAURANT#MISCELLANEOUS',
#    'target': 'Меню'}},
#  '10546:4': {},
#  '10546:5': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '10546:6': {},
#  '10546:7': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '10546:8': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '10546:9': {0: {'to': '58',
#    'from': '54',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Суши'},
#   1: {'to': '83',
#    'from': '68',
#    'polarity': 'negative',
#    'category': 'FOOD#QUALITY',
#    'target': 'салат с лососем'}},
#  '10546:10': {0: {'to': '10',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Суп ким-чи'},
#   1: {'to': '27',
#    'from': '21',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'порция'}},
#  '10546:11': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'NULL'},
#   1: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'NULL'},
#   2: {'to': '46',
#    'from': '42',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'блюд'}},
#  '10546:12': {},
#  '10546:13': {0: {'to': '51',
#    'from': '42',
#    'polarity': 'neutral',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официанты'}},
#  '10632:0': {0: {'to': '34',
#    'from': '30',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'кафе'}},
#  '10632:1': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'conflict',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'},
#   1: {'to': '12',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Обслуживание'},
#   2: {'to': '42',
#    'from': '34',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официант'}},
#  '10632:2': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'RESTAURANT#PRICES',
#    'target': 'NULL'},
#   1: {'to': '5',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'FOOD#QUALITY',
#    'target': 'Кухня'}},
#  '10632:3': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Шарлотка'},
#   1: {'to': '59',
#    'from': '51',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'десертов'}},
#  '10632:4': {},
#  '10632:5': {0: {'to': '47',
#    'from': '40',
#    'polarity': 'negative',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'террасы'}},
#  '10632:6': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'NULL'}},
#  '10632:7': {},
#  '10632:8': {},
#  '10632:9': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10731:0': {},
#  '10731:1': {},
#  '10731:2': {0: {'to': '35',
#    'from': '27',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'интерьер'},
#   1: {'to': '49',
#    'from': '37',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'обслуживание'},
#   2: {'to': '56',
#    'from': '51',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'кухня'}},
#  '10731:3': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10731:4': {0: {'to': '13',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Администратор'}},
#  '10731:5': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10731:6': {0: {'to': '26',
#    'from': '23',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'зал'},
#   1: {'to': '86',
#    'from': '78',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'персонал'},
#   2: {'to': '108',
#    'from': '103',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'кухня'},
#   3: {'to': '139',
#    'from': '127',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'горячих блюд'}},
#  '10731:7': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10731:8': {0: {'to': '37',
#    'from': '23',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#MISCELLANEOUS',
#    'target': 'сайт ресторана'},
#   1: {'to': '43',
#    'from': '39',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#MISCELLANEOUS',
#    'target': 'меню'}},
#  '1077:0': {},
#  '1077:1': {0: {'to': '47',
#    'from': '38',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'персоналу'},
#   1: {'to': '73',
#    'from': '59',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'администратору'},
#   2: {'to': '106',
#    'from': '94',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'обслуживание'}},
#  '1077:2': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'Ресторан'}},
#  '1077:3': {0: {'to': '43',
#    'from': '31',
#    'polarity': 'positive',
#    'category': 'LOCATION#GENERAL',
#    'target': 'расположение'}},
#  '1077:4': {0: {'to': '20',
#    'from': '17',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'еда'},
#   1: {'to': '27',
#    'from': '22',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'повар'},
#   2: {'to': '154',
#    'from': '146',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'угощения'}},
#  '1077:5': {0: {'to': '38',
#    'from': '29',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'атмосфера'}},
#  '1077:6': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '1077:7': {},
#  '1077:8': {},
#  '10800:0': {},
#  '10800:1': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'},
#   1: {'to': '43',
#    'from': '35',
#    'polarity': 'neutral',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Интерьер'}},
#  '10800:2': {},
#  '10800:3': {0: {'to': '63',
#    'from': '50',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'администратор'}},
#  '10800:4': {0: {'to': '27',
#    'from': '15',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'обслуживание'},
#   1: {'to': '43',
#    'from': '37',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'порции'},
#   2: {'to': '74',
#    'from': '65',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официанты'}},
#  '10800:5': {},
#  '10800:6': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '10800:7': {},
#  '10800:8': {0: {'to': '27',
#    'from': '15',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'салат Тройка'},
#   1: {'to': '47',
#    'from': '29',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'салат из кальмаров'},
#   2: {'to': '53',
#    'from': '49',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'язык'}},
#  '10800:9': {0: {'to': '70',
#    'from': '54',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'фирменного блюда'},
#   1: {'to': '97',
#    'from': '72',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'баклажанов в соевом соусе'}},
#  '10800:10': {0: {'to': '12',
#    'from': '6',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'десерт'},
#   1: {'to': '53',
#    'from': '28',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'фрукты в горячей карамели'}},
#  '10800:11': {0: {'to': '27',
#    'from': '18',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'заведение'}},
#  '10816:0': {},
#  '10816:1': {},
#  '10816:2': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'FOOD#QUALITY',
#    'target': 'NULL'}},
#  '10816:3': {},
#  '10816:4': {},
#  '10816:5': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Интерьер'}},
#  '10816:6': {0: {'to': '34',
#    'from': '27',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'веранде'}},
#  '10816:7': {},
#  '10816:8': {0: {'to': '24',
#    'from': '17',
#    'polarity': 'negative',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'веранде'}},
#  '10816:9': {},
#  '10816:10': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '10816:11': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '10816:12': {},
#  '10816:13': {},
#  '10833:0': {},
#  '10833:1': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Интерьер'}},
#  '10833:2': {0: {'to': '29',
#    'from': '23',
#    'polarity': 'neutral',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'музыка'}},
#  '10833:3': {0: {'to': '12',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Обслуживание'}},
#  '10833:4': {0: {'to': '21',
#    'from': '6',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'салат с лососем'},
#   1: {'to': '69',
#    'from': '63',
#    'polarity': 'negative',
#    'category': 'FOOD#QUALITY',
#    'target': 'лосось'}},
#  '10833:5': {},
#  '10833:6': {0: {'to': '19',
#    'from': '15',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'крем'}},
#  '10833:7': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'NULL'}},
#  '10833:8': {0: {'to': '27',
#    'from': '19',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'десертов'},
#   1: {'to': '47',
#    'from': '39',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'сладкого'}},
#  '10833:9': {0: {'to': '23',
#    'from': '18',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'место'}},
#  '11796:0': {},
#  '11796:1': {},
#  '11796:2': {0: {'to': '22',
#    'from': '19',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'зал'},
#   1: {'to': '60',
#    'from': '50',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'диванчиках'}},
#  '11796:3': {0: {'to': '25',
#    'from': '16',
#    'polarity': 'neutral',
#    'category': 'SERVICE#GENERAL',
#    'target': 'офицантки'}},
#  '11796:4': {},
#  '11796:5': {0: {'to': '29',
#    'from': '19',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'обстановка'}},
#  '11796:6': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#PRICES',
#    'target': 'NULL'}},
#  '11796:7': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'NULL'}},
#  '11796:8': {0: {'to': '38',
#    'from': '18',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'суп с морепродуктами'},
#   1: {'to': '54',
#    'from': '48',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'порции'}},
#  '11796:9': {0: {'to': '23',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Мидии под спайси соусом'}},
#  '11796:10': {0: {'to': '19',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'Куриное филе с пюре'},
#   1: {'to': '51',
#    'from': '47',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'филе'},
#   2: {'to': '79',
#    'from': '73',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'порции'}},
#  '11796:11': {},
#  '11796:12': {0: {'to': '47',
#    'from': '12',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'с креветкой, филадельфией и овощами'}},
#  '11796:13': {0: {'to': '5',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Кухня'}},
#  '11796:14': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '11796:15': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '12819:0': {0: {'to': '20',
#    'from': '8',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'обслуживание'}},
#  '12819:1': {},
#  '12819:2': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '12819:3': {},
#  '12819:4': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '12819:5': {0: {'to': '17',
#    'from': '8',
#    'polarity': 'negative',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'заведение'}},
#  '15336:0': {},
#  '15336:1': {},
#  '15336:2': {},
#  '15336:3': {},
#  '15336:4': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Интерьер'}},
#  '15336:5': {},
#  '15336:6': {},
#  '15336:7': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '15336:8': {},
#  '15336:9': {0: {'to': '27',
#    'from': '17',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'пепельницу'}},
#  '15336:10': {0: {'to': '63',
#    'from': '55',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официант'}},
#  '15336:11': {},
#  '15336:12': {},
#  '15336:13': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '15336:14': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'},
#   1: {'to': '94',
#    'from': '84',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'пепельницу'}},
#  '15336:15': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '15336:16': {0: {'to': '48',
#    'from': '38',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официантом'}},
#  '15336:17': {0: {'to': '50',
#    'from': '41',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официанта'}},
#  '15336:18': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '15336:19': {},
#  '15336:20': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '15336:21': {},
#  '15336:22': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Интерьер'}},
#  '15336:23': {0: {'to': '5',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'FOOD#QUALITY',
#    'target': 'Кухня'}},
#  '15336:24': {0: {'to': '6',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Сервис'}},
#  '15336:25': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '15336:26': {0: {'to': '30',
#    'from': '22',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'персонал'}},
#  '1408:0': {},
#  '1408:1': {},
#  '1408:2': {},
#  '1408:3': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'},
#   1: {'to': '113',
#    'from': '105',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'интерьер'}},
#  '1408:4': {},
#  '1408:5': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Персонал'},
#   1: {'to': '75',
#    'from': '60',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'девушки хостесс'},
#   2: {'to': '117',
#    'from': '106',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официантами'}},
#  '1408:6': {0: {'to': '5',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Кухня'}},
#  '1408:7': {0: {'to': '10',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'Оформление'}},
#  '1408:8': {0: {'to': '119',
#    'from': '56',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'подкопченный лосось с гофрами , красной икрой и кремом "шантий"'},
#   1: {'to': '125',
#    'from': '121',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'рыба'},
#   2: {'to': '190',
#    'from': '178',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'ингредиентов'}},
#  '1408:9': {0: {'to': '4',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'DRINKS#QUALITY',
#    'target': 'Пиво'}},
#  '1408:10': {},
#  '1408:11': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '14130:0': {0: {'to': '5',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'Место'}},
#  '14130:1': {},
#  '14130:2': {0: {'to': '51',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Уютное, более менее спокойное, располагает к отдыху'}},
#  '14130:3': {},
#  '14130:4': {0: {'to': '49',
#    'from': '24',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'стейк с трюфельным маслом'}},
#  '14130:5': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'FOOD#QUALITY',
#    'target': 'Салатики'}},
#  '14130:6': {0: {'to': '14',
#    'from': '8',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'десерт'}},
#  '14130:7': {},
#  '14130:8': {},
#  '14130:9': {},
#  '14130:10': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '14130:11': {0: {'to': '62',
#    'from': '53',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официанты'}},
#  '14130:12': {0: {'to': '12',
#    'from': '2',
#    'polarity': 'negative',
#    'category': 'DRINKS#QUALITY',
#    'target': 'коктейлями'},
#   1: {'to': '39',
#    'from': '19',
#    'polarity': 'negative',
#    'category': 'DRINKS#QUALITY',
#    'target': 'маргарита клубничная'}},
#  '14130:13': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '14130:14': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '14130:15': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '14130:16': {0: {'to': '15',
#    'from': '7',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'ресторан'}},
#  '14130:17': {0: {'to': '9',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Атмосфера'}},
#  '14209:0': {},
#  '14209:1': {},
#  '14209:2': {},
#  '14209:3': {0: {'to': '19',
#    'from': '9',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'обстановка'},
#   1: {'to': '45',
#    'from': '36',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'диванчики'},
#   2: {'to': '64',
#    'from': '55',
#    'polarity': 'neutral',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'освещение'}},
#  '14209:4': {},
#  '14209:5': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Официант'}},
#  '14209:6': {0: {'to': '10',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'Сервировка'}},
#  '14209:7': {0: {'to': '5',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Блюда'}},
#  '14209:8': {0: {'to': '24',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Горячее принесли вовремя'}},
#  '14209:9': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '14209:10': {0: {'to': '12',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Обслуживание'}},
#  '14209:11': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '14209:12': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#PRICES',
#    'target': 'NULL'}},
#  '14209:13': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#PRICES',
#    'target': 'NULL'}},
#  '14209:14': {0: {'to': '14',
#    'from': '9',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'место'}},
#  '14209:15': {0: {'to': '14',
#    'from': '9',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'кухня'}},
#  '14407:0': {},
#  '14407:1': {0: {'to': '17',
#    'from': '9',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'интерьер'}},
#  '14407:2': {0: {'to': '24',
#    'from': '12',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'обслуживание'},
#   1: {'to': '53',
#    'from': '43',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официантка'},
#   2: {'to': '203',
#    'from': '195',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'скатерти'},
#   3: {'to': '218',
#    'from': '204',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'смена приборов'},
#   4: {'to': '249',
#    'from': '234',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'сервировка блюд'}},
#  '14407:3': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'},
#   1: {'to': '28',
#    'from': '9',
#    'polarity': 'negative',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'шашлыка из баранины'},
#   2: {'to': '86',
#    'from': '79',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'свинины'},
#   3: {'to': '210',
#    'from': '198',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'салат цезарь'},
#   4: {'to': '310',
#    'from': '306',
#    'polarity': 'positive',
#    'category': 'DRINKS#QUALITY',
#    'target': 'квас'}},
#  '14407:4': {},
#  '14407:5': {},
#  '14407:6': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '14415:0': {},
#  '14415:1': {0: {'to': '45',
#    'from': '35',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'обстановка'}},
#  '14415:2': {0: {'to': '9',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Атмосфера'}},
#  '14415:3': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Персонал'},
#   1: {'to': '35',
#    'from': '23',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'обслуживание'}},
#  '14415:4': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '14415:5': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'NULL'}},
#  '14415:6': {0: {'to': '19',
#    'from': '14',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'блюда'},
#   1: {'to': '59',
#    'from': '55',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'мясо'}},
#  '14415:7': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'Ресторан'}},
#  '14545:0': {},
#  '14545:1': {0: {'to': '10',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Обстановка'}},
#  '14545:2': {0: {'to': '7',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Публика'}},
#  '14545:3': {},
#  '14545:4': {0: {'to': '48',
#    'from': '43',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'прием'}},
#  '14545:5': {0: {'to': '7',
#    'from': '3',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'меню'}},
#  '14545:6': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'NULL'}},
#  '14545:7': {},
#  '14545:8': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'NULL'}},
#  '14545:9': {0: {'to': '34',
#    'from': '18',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'хачапури с сыром'}},
#  '14545:10': {},
#  '14545:11': {},
#  '14545:12': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'DRINKS#QUALITY',
#    'target': 'NULL'}},
#  '14545:13': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'conflict',
#    'category': 'RESTAURANT#PRICES',
#    'target': 'NULL'}},
#  '14545:14': {0: {'to': '12',
#    'from': '7',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#PRICES',
#    'target': 'место'},
#   1: {'to': '12',
#    'from': '7',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'место'}},
#  '14545:15': {},
#  '14545:16': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Персонал'}},
#  '14545:17': {0: {'to': '9',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Атмосфера'}},
#  '14545:18': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'NULL'}},
#  '14545:19': {0: {'to': '40',
#    'from': '33',
#    'polarity': 'negative',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'столики'}},
#  '14551:0': {0: {'to': '27',
#    'from': '4',
#    'polarity': 'negative',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'ресторана при гостинице'},
#   1: {'to': '127',
#    'from': '109',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'деревянные столики'},
#   2: {'to': '150',
#    'from': '130',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'стулья под зонтиками'},
#   3: {'to': '165',
#    'from': '152',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'свежий воздух'}},
#  '14551:1': {0: {'to': '18',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Девушки официантки'}},
#  '14551:2': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '14551:3': {},
#  '14551:4': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '14551:5': {},
#  '14551:6': {0: {'to': '40',
#    'from': '36',
#    'polarity': 'negative',
#    'category': 'FOOD#QUALITY',
#    'target': 'мясо'},
#   1: {'to': '71',
#    'from': '49',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'красный соус к шашлыку'}},
#  '14551:7': {0: {'to': '27',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'DRINKS#QUALITY',
#    'target': 'Пиво холодное "Lapin Kulta"'}},
#  '14551:8': {0: {'to': '48',
#    'from': '26',
#    'polarity': 'negative',
#    'category': 'FOOD#QUALITY',
#    'target': 'салат с морепродуктами'},
#   1: {'to': '106',
#    'from': '93',
#    'polarity': 'negative',
#    'category': 'FOOD#QUALITY',
#    'target': 'судак в кляре'}},
#  '14551:9': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '14551:10': {0: {'to': '10',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Мороженное'},
#   1: {'to': '46',
#    'from': '25',
#    'polarity': 'positive',
#    'category': 'DRINKS#QUALITY',
#    'target': 'чай зеленый с лимоном'}},
#  '14551:11': {0: {'to': '6',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Сервис'}},
#  '14551:12': {},
#  '14551:13': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '14551:14': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'NULL'}},
#  '14757:0': {},
#  '14757:1': {0: {'to': '33',
#    'from': '25',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'ресторан'},
#   1: {'to': '43',
#    'from': '35',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'интерьер'}},
#  '14757:2': {0: {'to': '51',
#    'from': '46',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'блюда'}},
#  '14757:3': {0: {'to': '20',
#    'from': '14',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'музыка'},
#   1: {'to': '106',
#    'from': '96',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'обстановка'}},
#  '14757:4': {0: {'to': '19',
#    'from': '7',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'обслуживание'},
#   1: {'to': '71',
#    'from': '62',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официанту'}},
#  '14757:5': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '14757:6': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '151:0': {},
#  '151:1': {},
#  '151:2': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '151:3': {0: {'to': '3',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Еда'},
#   1: {'to': '3',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'Еда'},
#   2: {'to': '46',
#    'from': '40',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
# ...
#    'from': '60',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'салаты'}},
#  '15824:4': {0: {'to': '12',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'Тушеное мясо'}},
#  '15824:5': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'NULL'}},
#  '15824:6': {0: {'to': '20',
#    'from': '10',
#    'polarity': 'neutral',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'обстановки'}},
#  '15824:7': {},
#  '15824:8': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'NULL'}},
#  '15824:9': {0: {'to': '15',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Зал для курящих'}},
#  '15824:10': {0: {'to': '15',
#    'from': '3',
#    'polarity': 'neutral',
#    'category': 'SERVICE#GENERAL',
#    'target': 'обслуживанию'}},
#  '15824:11': {},
#  '15824:12': {0: {'to': '36',
#    'from': '27',
#    'polarity': 'neutral',
#    'category': 'FOOD#QUALITY',
#    'target': 'мороженое'}},
#  '15847:0': {},
#  '15847:1': {0: {'to': '63',
#    'from': '55',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официант'}},
#  '15847:2': {},
#  '15847:3': {0: {'to': '31',
#    'from': '22',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официанта'}},
#  '15847:4': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '15847:5': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '15847:6': {0: {'to': '40',
#    'from': '32',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официант'}},
#  '15847:7': {},
#  '15847:8': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '15847:9': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '15847:10': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '15847:11': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '15847:12': {0: {'to': '148',
#    'from': '139',
#    'polarity': 'negative',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'заведений'}},
#  '15855:0': {0: {'to': '11',
#    'from': '7',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#MISCELLANEOUS',
#    'target': 'пабе'}},
#  '15855:1': {0: {'to': '13',
#    'from': '6',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#MISCELLANEOUS',
#    'target': 'экранов'}},
#  '15855:2': {0: {'to': '34',
#    'from': '9',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'музыкальное сопровождение'}},
#  '15855:3': {},
#  '15855:4': {0: {'to': '27',
#    'from': '23',
#    'polarity': 'positive',
#    'category': 'DRINKS#QUALITY',
#    'target': 'пива'},
#   1: {'to': '27',
#    'from': '23',
#    'polarity': 'positive',
#    'category': 'DRINKS#STYLE_OPTIONS',
#    'target': 'пива'}},
#  '15855:5': {0: {'to': '4',
#    'from': '0',
#    'polarity': 'neutral',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'Меню'}},
#  '15855:6': {0: {'to': '5',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Кухня'}},
#  '15855:7': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Интерьер'},
#   1: {'to': '51',
#    'from': '36',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#MISCELLANEOUS',
#    'target': 'дамской комнате'}},
#  '15855:8': {0: {'to': '34',
#    'from': '25',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'персонала'}},
#  '15855:9': {0: {'to': '60',
#    'from': '50',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официантка'},
#   1: {'to': '201',
#    'from': '191',
#    'polarity': 'neutral',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официантка'}},
#  '15855:10': {0: {'to': '42',
#    'from': '32',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официантов'}},
#  '15855:11': {0: {'to': '42',
#    'from': '37',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'место'}},
#  '15856:0': {0: {'to': '57',
#    'from': '39',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'ресторане "Тройка"'}},
#  '15856:1': {},
#  '15856:2': {},
#  '15856:3': {},
#  '15856:4': {0: {'to': '14',
#    'from': '2',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'обслуживанию'}},
#  '15856:5': {},
#  '15856:6': {},
#  '15856:7': {},
#  '15856:8': {0: {'to': '207',
#    'from': '202',
#    'polarity': 'neutral',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'блюда'},
#   1: {'to': '207',
#    'from': '202',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'блюда'}},
#  '15856:9': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'NULL'}},
#  '15856:10': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '15856:11': {0: {'to': '35',
#    'from': '27',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'артистов'}},
#  '15856:12': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'NULL'}},
#  '15856:13': {0: {'to': '42',
#    'from': '37',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'место'}},
#  '15856:14': {0: {'to': '26',
#    'from': '8',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'ресторану "Тройка"'}},
#  '15866:0': {0: {'to': '42',
#    'from': '22',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'коллективу ресторана'}},
#  '15866:1': {0: {'to': '91',
#    'from': '71',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'работникам ресторана'}},
#  '15866:2': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'},
#   1: {'to': '31',
#    'from': '18',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'варианты меню'}},
#  '15866:3': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '15866:4': {0: {'to': '48',
#    'from': '43',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'кухня'},
#   1: {'to': '99',
#    'from': '89',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'шеф-повару'}},
#  '15866:5': {0: {'to': '15',
#    'from': '9',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'посуда'},
#   1: {'to': '27',
#    'from': '17',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'оформление'},
#   2: {'to': '35',
#    'from': '29',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'подача'},
#   3: {'to': '55',
#    'from': '51',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'вкус'}},
#  '15866:6': {0: {'to': '17',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Работа официантов'}},
#  '15866:7': {0: {'to': '38',
#    'from': '19',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'работу управляющего'}},
#  '15866:8': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '15866:9': {0: {'to': '16',
#    'from': '8',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'ресторан'}},
#  '15866:10': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '15866:11': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '15914:0': {0: {'to': '14',
#    'from': '9',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'место'},
#   1: {'to': '97',
#    'from': '84',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'администратор'}},
#  '15914:1': {0: {'to': '64',
#    'from': '61',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'еды'},
#   1: {'to': '64',
#    'from': '61',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'еды'}},
#  '15914:2': {0: {'to': '46',
#    'from': '33',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'администрация'}},
#  '15914:3': {0: {'to': '22',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Обслуживающий персонал'}},
#  '15914:4': {},
#  '15914:5': {0: {'to': '26',
#    'from': '20',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'местом'}},
#  '15914:6': {0: {'to': '17',
#    'from': '9',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'интерьер'},
#   1: {'to': '34',
#    'from': '28',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'музыка'},
#   2: {'to': '55',
#    'from': '47',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'персонал'}},
#  '15914:7': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '15914:8': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '15966:0': {},
#  '15966:1': {},
#  '15966:2': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '15966:3': {0: {'to': '88',
#    'from': '75',
#    'polarity': 'positive',
#    'category': 'LOCATION#GENERAL',
#    'target': 'вида на залив'}},
#  '15966:4': {0: {'to': '19',
#    'from': '13',
#    'polarity': 'neutral',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'музыка'},
#   1: {'to': '49',
#    'from': '40',
#    'polarity': 'neutral',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официанты'}},
#  '15966:5': {0: {'to': '8',
#    'from': '3',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'кухня'}},
#  '15966:6': {0: {'to': '18',
#    'from': '8',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'шеф-повару'}},
#  '15966:7': {},
#  '15966:8': {0: {'to': '6',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Порции'},
#   1: {'to': '6',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'Порции'}},
#  '15966:9': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '15966:10': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#PRICES',
#    'target': 'NULL'}},
#  '15974:0': {},
#  '15974:1': {0: {'to': '46',
#    'from': '38',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'интерьер'}},
#  '15974:2': {0: {'to': '60',
#    'from': '52',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'менеджер'}},
#  '15974:3': {0: {'to': '66',
#    'from': '58',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официант'}},
#  '15974:4': {0: {'to': '59',
#    'from': '50',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официанту'}},
#  '15974:5': {0: {'to': '38',
#    'from': '30',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'персонал'}},
#  '15974:6': {0: {'to': '101',
#    'from': '91',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'официантов'}},
#  '15974:7': {0: {'to': '69',
#    'from': '45',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'комплимент от шеф-повара'}},
#  '15974:8': {},
#  '15974:9': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'NULL'}},
#  '15974:10': {0: {'to': '5',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Кухня'}},
#  '15974:11': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '15974:12': {0: {'to': '20',
#    'from': '12',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'персонал'}},
#  '15974:13': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '15974:14': {},
#  '15974:15': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '15974:16': {},
#  '15974:17': {0: {'to': '5',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'Кухня'}},
#  '15974:18': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10837:0': {},
#  '10837:1': {},
#  '10837:2': {0: {'to': '16',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'Девушка-официант'}},
#  '10837:3': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Интерьер'}},
#  '10837:4': {},
#  '10837:5': {0: {'to': '23',
#    'from': '15',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'интерьер'}},
#  '10837:6': {0: {'to': '44',
#    'from': '27',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'декоративные окна'}},
#  '10837:7': {0: {'to': '4',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'Меню'},
#   1: {'to': '55',
#    'from': '48',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'десерты'},
#   2: {'to': '101',
#    'from': '97',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'блюд'},
#   3: {'to': '137',
#    'from': '133',
#    'polarity': 'positive',
#    'category': 'FOOD#STYLE_OPTIONS',
#    'target': 'торт'}},
#  '10837:8': {0: {'to': '32',
#    'from': '20',
#    'polarity': 'positive',
#    'category': 'DRINKS#STYLE_OPTIONS',
#    'target': 'винная карта'}},
#  '10837:9': {0: {'to': '4',
#    'from': '0',
#    'polarity': 'positive',
#    'category': 'DRINKS#QUALITY',
#    'target': 'Вино'},
#   1: {'to': '58',
#    'from': '42',
#    'polarity': 'positive',
#    'category': 'SERVICE#GENERAL',
#    'target': 'хозяин заведения'}},
#  '10837:10': {0: {'to': '39',
#    'from': '35',
#    'polarity': 'positive',
#    'category': 'FOOD#QUALITY',
#    'target': 'ужин'}},
#  '10837:11': {0: {'to': '37',
#    'from': '31',
#    'polarity': 'negative',
#    'category': 'RESTAURANT#MISCELLANEOUS',
#    'target': 'туалет'},
#   1: {'to': '85',
#    'from': '80',
#    'polarity': 'negative',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'холла'}},
#  '10837:12': {0: {'to': '26',
#    'from': '21',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'Дианы'},
#   1: {'to': '141',
#    'from': '133',
#    'polarity': 'positive',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'ресторан'},
#   2: {'to': '141',
#    'from': '133',
#    'polarity': 'positive',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'ресторан'}},
#  '10855:0': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'RESTAURANT#GENERAL',
#    'target': 'NULL'}},
#  '10855:1': {},
#  '10855:2': {},
#  '10855:3': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'SERVICE#GENERAL',
#    'target': 'NULL'}},
#  '10855:4': {},
#  '10855:5': {0: {'to': '6',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Музыка'}},
#  '10855:6': {0: {'to': '0',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'NULL'}},
#  '10855:7': {0: {'to': '8',
#    'from': '0',
#    'polarity': 'negative',
#    'category': 'AMBIENCE#GENERAL',
#    'target': 'Интерьер'}},
#  '10855:8': {},
#  '10855:9': {},
#  ...}

# %%
test_mark = dict()
for k in test_aspects.keys():
    test_mark[k] = dict()
    test_mark[k]['text'] = test_texts[k]
    test_mark[k]['aspects'] = []
    for a in test_aspects[k].values():
        test_mark[k]['aspects'].append(tuple(a.values()))

# %%
test_mark
# Out:
# {'10106:0': {'text': 'Очень милый, уютный ресторанчик со скромными ценами за огромные порции вкуснейших блюд.',
#   'aspects': [('31', '20', 'positive', 'AMBIENCE#GENERAL', 'ресторанчик'),
#    ('70', '64', 'positive', 'FOOD#STYLE_OPTIONS', 'порции'),
#    ('70', '64', 'positive', 'FOOD#PRICES', 'порции'),
#    ('86', '82', 'positive', 'FOOD#QUALITY', 'блюд')]},
#  '10106:1': {'text': 'Мы отмечали день рожденья,нам разрешили принести свой тортик со свечками.',
#   'aspects': []},
#  '10106:2': {'text': 'Салаты со свежайшей зеленью, мясо и курица нежные, а десерт,в частности Семифреддо миндальный - это что-то сказочно вкусное.',
#   'aspects': [('6', '0', 'positive', 'FOOD#QUALITY', 'Салаты'),
#    ('27', '20', 'positive', 'FOOD#QUALITY', 'зеленью'),
#    ('33', '29', 'positive', 'FOOD#QUALITY', 'мясо'),
#    ('42', '36', 'positive', 'FOOD#QUALITY', 'курица'),
#    ('59', '53', 'positive', 'FOOD#QUALITY', 'десерт'),
#    ('93', '72', 'positive', 'FOOD#QUALITY', 'Семифреддо миндальный')]},
#  '10106:3': {'text': 'Официантки вежливые и улыбчивые.',
#   'aspects': [('10', '0', 'positive', 'SERVICE#GENERAL', 'Официантки')]},
#  '10106:4': {'text': 'Единственное,что немного не понравилось - долго ждали начала обслуживания (видимо,из-за большого количества народа) и с соседних столов никто не убирал посуду,когда ушли люди.',
#   'aspects': [('73', '61', 'negative', 'SERVICE#GENERAL', 'обслуживания')]},
#  '10106:5': {'text': 'Но это мелочи.', 'aspects': []},
#  '10106:6': {'text': 'Общее впечатление прекрасное.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10106:7': {'text': 'Советуем!',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10122:0': {'text': 'Отличный ресторан, была здесь уже не раз и вот решилась отпраздновать свой день рождения.',
#   'aspects': [('17', '9', 'positive', 'RESTAURANT#GENERAL', 'ресторан')]},
#  '10122:1': {'text': 'И я, и все гости остались очень довольны.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10122:2': {'text': 'Кухня на уровне, все свежее ,вкусное и аутентичное)',
#   'aspects': [('5', '0', 'positive', 'FOOD#QUALITY', 'Кухня')]},
#  '10122:3': {'text': 'Особенно хочется отметить спиртные напитки - вино просто великолепное, коктейли бесподобны.',
#   'aspects': [('42', '26', 'positive', 'DRINKS#QUALITY', 'спиртные напитки'),
#    ('49', '45', 'positive', 'DRINKS#QUALITY', 'вино'),
#    ('79', '71', 'positive', 'DRINKS#QUALITY', 'коктейли')]},
#  '10122:4': {'text': 'Порадовали музыканты - играли душевно, так что мы не упустили возможности потанцевать.',
#   'aspects': [('20', '11', 'positive', 'AMBIENCE#GENERAL', 'музыканты')]},
#  '10122:5': {'text': 'Счет за все это великолепие оказался совсем небольшим - особенно учитывая то, что сидели мы 6 часов и ни в чем себе не отказывали.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#PRICES', 'NULL')]},
#  '10122:6': {'text': 'Из небольших недочетов - сигары оказались староваты - слишком пересушены, забыли подать несколько закусок "в стол" (впрочем, это оказалось к лучшему - мы бы их уже не осилили), администратору, принимающему заказы на банкет, стоит быть немного приветливей и более заинтересованной в процессе - например, помогать в выборе блюд, что-то советовать, а не просто записывать со скучающим лицом.',
#   'aspects': [('31', '25', 'negative', 'RESTAURANT#MISCELLANEOUS', 'сигары'),
#    ('191', '177', 'negative', 'SERVICE#GENERAL', 'администратору')]},
#  '10122:7': {'text': 'В целом праздник удался, все было на уровне.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10122:8': {'text': 'Обязательно придем к вам еще!',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10135:0': {'text': 'Интерьер прекрасный!',
#   'aspects': [('8', '0', 'positive', 'AMBIENCE#GENERAL', 'Интерьер')]},
#  '10135:1': {'text': 'Для меня это просто идеальный интерьер небольшого ресторана.',
#   'aspects': [('38', '30', 'positive', 'AMBIENCE#GENERAL', 'интерьер')]},
#  '10135:2': {'text': 'Очень уютно, как-то тепло и по-домашнему, и в то же время очень-очень красиво и со вкусом!',
#   'aspects': [('0', '0', 'positive', 'AMBIENCE#GENERAL', 'NULL')]},
#  '10135:3': {'text': 'Оттуда не хочется уходить.',
#   'aspects': [('0', '0', 'positive', 'AMBIENCE#GENERAL', 'NULL')]},
#  '10135:4': {'text': 'Цены очень доступные для ресторана.',
#   'aspects': [('34', '25', 'positive', 'RESTAURANT#PRICES', 'ресторана')]},
#  '10135:5': {'text': 'Теперь о минусах.',
#   'aspects': [('0', '0', 'negative', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10135:6': {'text': 'Во-первых обслуживание странное.',
#   'aspects': [('22', '10', 'negative', 'SERVICE#GENERAL', 'обслуживание')]},
#  '10135:7': {'text': 'Возможно нам просто попался неприветливый официант, но и вид и манера говорить у него была отталкивающая.',
#   'aspects': [('50', '42', 'negative', 'SERVICE#GENERAL', 'официант')]},
#  '10135:8': {'text': 'Кроме того, я была просто поражена, что официанты то ли не говорят по-английски, или же говорят, но тщательно это скрывают.',
#   'aspects': [('49', '40', 'negative', 'SERVICE#GENERAL', 'официанты')]},
#  '10135:9': {'text': 'Официанты почему-то общались только со мной, а я вынуждена была переводить это спутнику-иностранцу, после чего он удивленно спросил меня - они не говорят по-английски?',
#   'aspects': [('9', '0', 'negative', 'SERVICE#GENERAL', 'Официанты')]},
#  '10135:10': {'text': 'Для ресторана в центре города я считаю это неприемлемо.',
#   'aspects': [('13', '4', 'negative', 'RESTAURANT#GENERAL', 'ресторана')]},
#  '10135:11': {'text': 'Но это еще не все - вместо одного супа мне принесли другой похожий без всякого предупреждения.',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL')]},
#  '10135:12': {'text': 'Я заметила это не сразу и кроме того у меня в тот вечер абсолютно не было желания конфликтовать, поэтому я не стала звать официанта и разбираться.',
#   'aspects': []},
#  '10135:13': {'text': 'Про кухню могу сказать, что фирменный салат Кларет мне не понравился совсем, к вину и десертам претензий нет, мясо я не брала, но моему другу оно понравилось.',
#   'aspects': [('50', '38', 'negative', 'FOOD#QUALITY', 'салат Кларет'),
#    ('83', '79', 'neutral', 'DRINKS#QUALITY', 'вину'),
#    ('94', '86', 'neutral', 'FOOD#QUALITY', 'десертам'),
#    ('114', '110', 'positive', 'FOOD#QUALITY', 'мясо')]},
#  '10135:14': {'text': 'В целом впечатления от ресторана очень хорошее, но оно могло бы быть лучше, если бы не странный сервис.',
#   'aspects': [('32', '23', 'positive', 'RESTAURANT#GENERAL', 'ресторана'),
#    ('103', '96', 'negative', 'SERVICE#GENERAL', 'сервис.')]},
#  '10139:0': {'text': 'Занесло нас сюда огромное желание поесть мясо, выпить качественного пива и посмотреть матч Зенит-Твенте.',
#   'aspects': []},
#  '10139:1': {'text': 'Теперь по порядку.', 'aspects': []},
#  '10139:2': {'text': 'Заходим-радушная встреча))',
#   'aspects': [('24', '17', 'positive', 'SERVICE#GENERAL', 'встреча')]},
#  '10139:3': {'text': 'Порадовало.', 'aspects': []},
#  '10139:4': {'text': 'Симпатичная девушка-блондинка Елена проводила нас и предложила присесть за единственный свободный столик.',
#   'aspects': [('29',
#     '12',
#     'positive',
#     'SERVICE#GENERAL',
#     'девушка-блондинка')]},
#  '10139:5': {'text': 'Не совсем комфортный, но не важно.', 'aspects': []},
#  '10139:6': {'text': 'Потому что как только появилась возможность посидеть с комфортом-нам сразу же предложили пересесть))',
#   'aspects': [('0', '0', 'positive', 'SERVICE#GENERAL', 'NULL')]},
#  '10139:7': {'text': 'Вручила меню и дала нам время подумать.', 'aspects': []},
#  '10139:8': {'text': 'Пока девушка не пришла, мы так ничего не надумали(',
#   'aspects': []},
#  '10139:9': {'text': 'Спасибо за стейк "Тауэр" в первую очередь повару, очень вкусно приготовлено, во вторую очередь девушке за совет.',
#   'aspects': [('24', '11', 'positive', 'FOOD#QUALITY', 'стейк "Тауэр"'),
#    ('48', '42', 'positive', 'FOOD#QUALITY', 'повару'),
#    ('102', '95', 'positive', 'SERVICE#GENERAL', 'девушке')]},
#  '10139:10': {'text': 'Салат цезарь с курицей так же нас очень порадовал, гренки были великолепные (таких гренок признаюсь честно не ел нигде).',
#   'aspects': [('22',
#     '0',
#     'positive',
#     'FOOD#QUALITY',
#     'Салат цезарь с курицей'),
#    ('57', '51', 'positive', 'FOOD#QUALITY', 'гренки'),
#    ('89', '83', 'positive', 'FOOD#QUALITY', 'гренок')]},
#  '10139:11': {'text': 'Пиво было очень вкусным, пробовали разное, а за три Вельвета моему другу подарили еще полотенце фирменное.)))',
#   'aspects': [('4', '0', 'positive', 'DRINKS#QUALITY', 'Пиво'),
#    ('0', '0', 'positive', 'SERVICE#GENERAL', 'NULL')]},
#  '10139:12': {'text': 'Приятные мелочи, но очень радуют.',
#   'aspects': [('0', '0', 'positive', 'SERVICE#GENERAL', 'NULL')]},
#  '10139:13': {'text': 'Интерьер спокойный ни к чему не обязывающий.',
#   'aspects': [('8', '0', 'neutral', 'AMBIENCE#GENERAL', 'Интерьер')]},
#  '10139:14': {'text': 'Мягкие диваны, удобные что сейчас очень важно(!)',
#   'aspects': [('13', '7', 'positive', 'AMBIENCE#GENERAL', 'диваны')]},
#  '10139:15': {'text': 'Хорошо сочетаются с размерами столов.',
#   'aspects': [('0', '0', 'positive', 'AMBIENCE#GENERAL', 'NULL')]},
#  '10139:16': {'text': 'Общая оценка 9 из 10.', 'aspects': []},
#  '10139:17': {'text': 'Почему 9?', 'aspects': []},
#  '10139:18': {'text': 'Потому что проблемы с вентиляцией.',
#   'aspects': [('33', '22', 'negative', 'AMBIENCE#GENERAL', 'вентиляцией')]},
#  '10139:19': {'text': 'Очень накурено.',
#   'aspects': [('0', '0', 'negative', 'AMBIENCE#GENERAL', 'NULL')]},
#  '10139:20': {'text': 'А так нам очень даже понравилось.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10139:21': {'text': 'Все остались всем довольны.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10139:22': {'text': 'Вернемся еще обязательно.))',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10139:23': {'text': 'Вам процветания и успехов)', 'aspects': []},
#  '10139:24': {'text': 'Персоналу спасибо)',
#   'aspects': [('9', '0', 'positive', 'SERVICE#GENERAL', 'Персоналу')]},
#  '10195:0': {'text': 'Вчера имела удовольствие позавтракать в этом милом ресторанчике.',
#   'aspects': [('63', '51', 'positive', 'RESTAURANT#GENERAL', 'ресторанчике')]},
#  '10195:1': {'text': 'По поводу кухни тут уже многие написали, что она как домашняя.',
#   'aspects': [('15', '10', 'positive', 'FOOD#QUALITY', 'кухни')]},
#  '10195:2': {'text': 'Не могу с этим не согласиться.', 'aspects': []},
#  '10195:3': {'text': 'Я редко где ела овсянку приготовленную почти так же как я готовлю ее дома.',
#   'aspects': [('23', '16', 'positive', 'FOOD#QUALITY', 'овсянку')]},
#  '10195:4': {'text': 'Порция была очень приличной!',
#   'aspects': [('6', '0', 'positive', 'FOOD#STYLE_OPTIONS', 'Порция')]},
#  '10195:5': {'text': 'Так же заказала себе на пробу "Наполеон".',
#   'aspects': []},
#  '10195:6': {'text': 'Тортик был вкусный, порция большая, но все же нигде не готовят так как готовила моя бабушка..., но все равно вкусно.',
#   'aspects': [('6', '0', 'positive', 'FOOD#QUALITY', 'Тортик'),
#    ('26', '20', 'positive', 'FOOD#STYLE_OPTIONS', 'порция')]},
#  '10195:7': {'text': 'Интерьер мне понравился, но восторга не вызвал.',
#   'aspects': [('8', '0', 'neutral', 'AMBIENCE#GENERAL', 'Интерьер')]},
#  '10195:8': {'text': 'Думаю для такого заведения очень даже ничего, большего и не нужно.',
#   'aspects': [('0', '0', 'positive', 'AMBIENCE#GENERAL', 'NULL')]},
#  '10195:9': {'text': 'Хотя диванчики можно было бы и блее уютными сделать, более "домашними", с подушками.',
#   'aspects': [('14', '5', 'neutral', 'AMBIENCE#GENERAL', 'диванчики')]},
#  '10195:10': {'text': 'И некоторым образом смутила стеклянная дверь в туалет, учитывая, что перед ней находится столик и могут сидеть посетители, как-то не комфортно.',
#   'aspects': [('53', '47', 'negative', 'RESTAURANT#MISCELLANEOUS', 'туалет')]},
#  '10195:11': {'text': 'Я ожидала, что все будет более по "квартирному", а оказалось более "кафешное".',
#   'aspects': []},
#  '10195:12': {'text': 'Обслуживание спокойное, больше сказать сложно, так как я была практически одна.',
#   'aspects': [('12', '0', 'neutral', 'SERVICE#GENERAL', 'Обслуживание')]},
#  '10195:13': {'text': 'Думаю, что зайду еще в это заведение на обед и ужин.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10287:0': {'text': 'Отличное место, очень вкусно готовят, огромные порции, мы одно горячее заказали на четверых(!) и то не смогли доесть..',
#   'aspects': [('0', '0', 'positive', 'FOOD#QUALITY', 'NULL'),
#    ('14', '9', 'positive', 'RESTAURANT#GENERAL', 'место'),
#    ('53', '47', 'positive', 'FOOD#STYLE_OPTIONS', 'порции'),
#    ('70', '63', 'positive', 'FOOD#STYLE_OPTIONS', 'горячее')]},
#  '10287:1': {'text': 'Интерьер ничего особенного, чисто и тихо, музыка в соседнем зале, но мы специально хотели без музыки.',
#   'aspects': [('8', '0', 'neutral', 'AMBIENCE#GENERAL', 'Интерьер')]},
#  '10287:2': {'text': 'Вежливая и услужливая официантка, алкоголь можно принести с собой, только надо купить еще что-то из алкоголя у них.',
#   'aspects': [('32', '22', 'positive', 'SERVICE#GENERAL', 'официантка')]},
#  '10287:3': {'text': 'Все очень понравилось, придем еще))',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '1040:0': {'text': 'заведение не из дешевых!',
#   'aspects': [('9', '0', 'negative', 'RESTAURANT#PRICES', 'заведение')]},
#  '1040:1': {'text': 'Большой мину с в том, что не продают алкоголь по отдельности, а только в коктейлях!',
#   'aspects': [('45', '37', 'negative', 'DRINKS#STYLE_OPTIONS', 'алкоголь'),
#    ('82', '73', 'negative', 'DRINKS#STYLE_OPTIONS', 'коктейлях')]},
#  '1040:2': {'text': 'По крайней мере так мне сказал бармен.', 'aspects': []},
#  '1040:3': {'text': 'Вино только в маленьких отдельных бутылочках, пива нет вообще!!!',
#   'aspects': [('4', '0', 'negative', 'DRINKS#STYLE_OPTIONS', 'Вино'),
#    ('50', '46', 'negative', 'DRINKS#STYLE_OPTIONS', 'пива')]},
#  '1040:4': {'text': 'Заказали несколько салатиков, так нам их готовили больше часа!!! хотя кроме нас в баре была только одна компания.',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL')]},
#  '1040:5': {'text': 'Не понимаю чем занимался повар на кухне.',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL')]},
#  '1040:6': {'text': 'Бармен в течении всего этого времени говорил, что наши салаты почти готовы.',
#   'aspects': [('6', '0', 'negative', 'SERVICE#GENERAL', 'Бармен')]},
#  '1040:7': {'text': 'В общем, не смотря на приятный интерьер больше сюда почему-то не хочется приходить :(',
#   'aspects': [('0', '0', 'negative', 'RESTAURANT#GENERAL', 'NULL'),
#    ('39', '31', 'positive', 'AMBIENCE#GENERAL', 'интерьер')]},
#  '10403:0': {'text': 'Отличное место!',
#   'aspects': [('14', '9', 'positive', 'RESTAURANT#GENERAL', 'место')]},
#  '10403:1': {'text': 'Так редко сочетается уютная обстановка, хорошая кухня и приличное обслуживание.',
#   'aspects': [('38', '28', 'positive', 'AMBIENCE#GENERAL', 'обстановка'),
#    ('53', '48', 'positive', 'FOOD#QUALITY', 'кухня'),
#    ('78', '66', 'positive', 'SERVICE#GENERAL', 'обслуживание')]},
#  '10403:2': {'text': 'И ценник очень демократичный.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#PRICES', 'NULL')]},
#  '10403:3': {'text': 'Посещали вдвоем с подругой.', 'aspects': []},
#  '10403:4': {'text': 'Обслуживание вполне приличное, встретили у входа, поводили по всему заведению, все показали, терпеливо дождались пока мы наконец решим куда нам сесть, хотя выбирали долго)',
#   'aspects': [('12', '0', 'positive', 'SERVICE#GENERAL', 'Обслуживание')]},
#  '10403:5': {'text': 'По счастью освободилась кравать)', 'aspects': []},
#  '10403:6': {'text': 'Обложились подушками, развалились в краватке, вобщем благодать.',
#   'aspects': [('44', '36', 'positive', 'AMBIENCE#GENERAL', 'краватке')]},
#  '10403:7': {'text': 'Еду принесли достаточно быстро: напитки почти сразу, салат минут через 15, горячее минут через 10 после салатов.',
#   'aspects': [('0', '0', 'positive', 'SERVICE#GENERAL', 'NULL')]},
#  '10403:8': {'text': 'Еда понравилась, особенно десерт - наполеон, очень вкусный).',
#   'aspects': [('3', '0', 'positive', 'FOOD#QUALITY', 'Еда'),
#    ('32', '26', 'positive', 'FOOD#QUALITY', 'десерт'),
#    ('43', '35', 'positive', 'FOOD#QUALITY', 'наполеон')]},
#  '10403:9': {'text': 'Вобщем, несмотря на предыдущий отзыв, собираюсь отметить там свой день рождения.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10403:10': {'text': 'Кстати я заказывала Космополитан - нормальный коктель и алкоголя там достаточно.',
#   'aspects': [('32', '20', 'neutral', 'DRINKS#QUALITY', 'Космополитан'),
#    ('53', '46', 'neutral', 'DRINKS#QUALITY', 'коктель')]},
#  '10442:0': {'text': 'Название ресторана обязывает попробовать это самое блюдо, разнообразие вариаций которого приятно удивляет.',
#   'aspects': [('56', '51', 'positive', 'FOOD#STYLE_OPTIONS', 'блюдо')]},
#  '10442:1': {'text': 'Мы выбрали Чебуреки с сыром и картофелем, сдобрив их сметанным соусом, было вкусно!',
#   'aspects': [('40',
#     '11',
#     'positive',
#     'FOOD#QUALITY',
#     'Чебуреки с сыром и картофелем'),
#    ('69', '53', 'positive', 'FOOD#QUALITY', 'сметанным соусом')]},
#  '10442:2': {'text': 'Очень сытное нежное блюдо, немного острое, совсем не жирное, рекомендую!',
#   'aspects': [('25', '20', 'positive', 'FOOD#QUALITY', 'блюдо')]},
#  '10442:3': {'text': 'Ещё был салат с форелью, которому бы я поставила 7 из 10, на мой вкус неудачное сочетание ингредиентов, овощи дали чрезмерное количество сока, а оформление блюда тертым яйцом выглядело как-то не солидно.',
#   'aspects': [('23', '8', 'neutral', 'FOOD#QUALITY', 'салат с форелью'),
#    ('161', '145', 'negative', 'FOOD#STYLE_OPTIONS', 'оформление блюда')]},
#  '10442:4': {'text': 'Шашлык из свинины был почти вкусным, если бы не попавшийся пересоленный кусочек (один из 5).',
#   'aspects': [('17', '0', 'conflict', 'FOOD#QUALITY', 'Шашлык из свинины'),
#    ('79', '59', 'negative', 'FOOD#QUALITY', 'пересоленный кусочек')]},
#  '10442:5': {'text': 'Жаль, что мы не едим баранину, блюда из этого мяса преобладают в меню.',
#   'aspects': []},
#  '10442:6': {'text': 'Обслуживание и скорость подачи нас просто поразили, чебуреки принесли минуты через 4, напитки ещё быстрее, шашлык был подан как раз в нужное время, единственное, чего пришлось ждать долго - сдачу (в последнее время во многих местах рассчитывают от 10 минут и дольше...)',
#   'aspects': [('12', '0', 'positive', 'SERVICE#GENERAL', 'Обслуживание'),
#    ('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL'),
#    ('30', '15', 'positive', 'SERVICE#GENERAL', 'скорость подачи')]},
#  '10442:7': {'text': 'Интерьер приятный, мы отдыхали на скамеечках друг напротив друга, как будто в уединенной беседке, было уютно и нас никто не потревожил.',
#   'aspects': [('8', '0', 'positive', 'AMBIENCE#GENERAL', 'Интерьер'),
#    ('44', '34', 'positive', 'AMBIENCE#GENERAL', 'скамеечках')]},
#  '10442:8': {'text': 'Когда уходили, заглянули во все залы, нам понравился камин, возле которого можно провести приятный романтический вечер.',
#   'aspects': [('58', '53', 'positive', 'AMBIENCE#GENERAL', 'камин')]},
#  '10442:9': {'text': 'Светлый зал тоже хорош, только нам показалось, что там наставлено слишком много столов.',
#   'aspects': [('11', '8', 'positive', 'AMBIENCE#GENERAL', 'зал')]},
#  '10442:10': {'text': 'Резюме: качественное, уютное и вкусное место, будем захаживать.',
#   'aspects': [('0', '0', 'positive', 'FOOD#QUALITY', 'NULL'),
#    ('44', '39', 'positive', 'RESTAURANT#GENERAL', 'место'),
#    ('44', '39', 'positive', 'AMBIENCE#GENERAL', 'место')]},
#  '10522:0': {'text': 'Решили пойти в Аппетит, раньше там не были, заказала столик. когда пришли,то немного разочаровались, так как столик был прям при входе, мы хотели сесть за другой,но нам мило сказали,что пусть кто-нибудь другой сядит, пока официант ушел мы быстренько за другой столик напротив сел,так как там нам показалось будет теплее.',
#   'aspects': [('115', '109', 'negative', 'AMBIENCE#GENERAL', 'столик')]},
#  '10522:1': {'text': 'А пошли мы в эти самые холодные деньки.', 'aspects': []},
#  '10522:2': {'text': 'И было холодно,сидели в куртках.',
#   'aspects': [('0', '0', 'negative', 'AMBIENCE#GENERAL', 'NULL')]},
#  '10522:3': {'text': 'Люди,которые приходили,иногда не следили за дверьми,приходилось просить,чтобы двери закрывали.',
#   'aspects': [('0', '0', 'negative', 'AMBIENCE#GENERAL', 'NULL')]},
#  '10522:4': {'text': 'Девушка из персонала потом нас пожалела, спросила не холодно ли нам,но все было очевидно.',
#   'aspects': [('7', '0', 'neutral', 'SERVICE#GENERAL', 'Девушка')]},
#  '10522:5': {'text': 'Еда нам понравилась,особенно роллы.',
#   'aspects': [('3', '0', 'positive', 'FOOD#QUALITY', 'Еда'),
#    ('34', '29', 'positive', 'FOOD#QUALITY', 'роллы')]},
#  '10522:6': {'text': 'Интерьер интересный.',
#   'aspects': [('8', '0', 'positive', 'AMBIENCE#GENERAL', 'Интерьер')]},
#  '10522:7': {'text': 'В остальных залах более уютно. так что в холод в этом зале,который при входелучше не заказывайть столик.)))',
#   'aspects': [('17', '12', 'positive', 'AMBIENCE#GENERAL', 'залах'),
#    ('58', '54', 'negative', 'AMBIENCE#GENERAL', 'зале')]},
#  '10546:0': {'text': 'Посетили заведение 23 февраля.', 'aspects': []},
#  '10546:1': {'text': 'Любезно встретили, проводили к гардеробу и за столик.',
#   'aspects': [('0', '0', 'positive', 'SERVICE#GENERAL', 'NULL')]},
#  '10546:2': {'text': 'На втором этаже большинство столов было занято или стоял резерв, но нашлось место и для нас троих.',
#   'aspects': []},
#  '10546:3': {'text': 'Меню не очень удобно сделано-отдельные папки гриль, японское меню и итальянское.',
#   'aspects': [('4', '0', 'negative', 'RESTAURANT#MISCELLANEOUS', 'Меню')]},
#  '10546:4': {'text': 'В итоге сидели с ними как обезьянки в лавке с открытками)))',
#   'aspects': []},
#  '10546:5': {'text': 'Всем мужчинам на 23 февраля подарок-рюмка водки-как то несолидно....',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL')]},
#  '10546:6': {'text': 'В основном были заказаны суши.', 'aspects': []},
#  '10546:7': {'text': 'Напитков ждали не очень долго-минут 10, а вот с остальными заказами все сложно...',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL')]},
#  '10546:8': {'text': 'сначала принесли салат для девушки, а мы сидели и облизывались.',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL')]},
#  '10546:9': {'text': 'Затем суп для друга, и затем все суши (минут через 30)Суши вкусные, салат с лососем-достаточно посредственный.',
#   'aspects': [('58', '54', 'positive', 'FOOD#QUALITY', 'Суши'),
#    ('83', '68', 'negative', 'FOOD#QUALITY', 'салат с лососем')]},
#  '10546:10': {'text': 'Суп ким-чи вкусный и порция большая.',
#   'aspects': [('10', '0', 'positive', 'FOOD#QUALITY', 'Суп ким-чи'),
#    ('27', '21', 'positive', 'FOOD#STYLE_OPTIONS', 'порция')]},
#  '10546:11': {'text': 'Впечатления- уютно, вкусно, большой выбор блюд на любой вкус( стейки, рыба гриль, ризотто, суши, пицца, паста, уха ...)',
#   'aspects': [('0', '0', 'positive', 'AMBIENCE#GENERAL', 'NULL'),
#    ('0', '0', 'positive', 'FOOD#QUALITY', 'NULL'),
#    ('46', '42', 'positive', 'FOOD#STYLE_OPTIONS', 'блюд')]},
#  '10546:12': {'text': 'Прошу прощения что подробно не разбираю каждое блюдо, потому как впечатления остались общие, и ничего особенного мы не заказывали.',
#   'aspects': []},
#  '10546:13': {'text': 'Со стола у нас убирали не часто, и разные официанты,но тем не менее все были достаточно любезны и улыбчивы.',
#   'aspects': [('51', '42', 'neutral', 'SERVICE#GENERAL', 'официанты')]},
#  '10632:0': {'text': 'Были с подругой летом 2010го, кафе симпатичное, сидели на террасе.',
#   'aspects': [('34', '30', 'positive', 'AMBIENCE#GENERAL', 'кафе')]},
#  '10632:1': {'text': 'Обслуживание поначалу расстроило: официант посадил нас за столик и ушел. меню на столике не оказалось, мы ожидали, что его нам сейчас принесут, ждали около 10 минут! но никого не было. после этого удалось поймать другого мальчика и попросить его принести, он был в шоке от того, что у нас даже меню нет до сих пор, принял заказ, еду и коктейли принес быстро, обслужил хорошо и внимательно, чем исправил первоначальное негативное впечатление.',
#   'aspects': [('0', '0', 'conflict', 'SERVICE#GENERAL', 'NULL'),
#    ('12', '0', 'negative', 'SERVICE#GENERAL', 'Обслуживание'),
#    ('42', '34', 'negative', 'SERVICE#GENERAL', 'официант')]},
#  '10632:2': {'text': 'Кухня - обычная на мой взгляд, ничего особенного, а вот цены явно завышены.',
#   'aspects': [('0', '0', 'negative', 'RESTAURANT#PRICES', 'NULL'),
#    ('5', '0', 'neutral', 'FOOD#QUALITY', 'Кухня')]},
#  '10632:3': {'text': 'Шарлотка действительно вкусная, "домашняя" :) ради десертов я бы пришла еще раз.',
#   'aspects': [('8', '0', 'positive', 'FOOD#QUALITY', 'Шарлотка'),
#    ('59', '51', 'positive', 'FOOD#QUALITY', 'десертов')]},
#  '10632:4': {'text': 'Ну и просто приятно посидеть-пообщаться.',
#   'aspects': []},
#  '10632:5': {'text': 'Что еще хотелось бы отметить - касается террасы - тесновато.',
#   'aspects': [('47', '40', 'negative', 'AMBIENCE#GENERAL', 'террасы')]},
#  '10632:6': {'text': 'Не очень приятно сидеть чуть ли не вплотную к другим столам и вынужденно слушать чужие разговоры.',
#   'aspects': [('0', '0', 'negative', 'AMBIENCE#GENERAL', 'NULL')]},
#  '10632:7': {'text': 'Очень много мужчин, которые сидят и не стесняясь обсматривают сверху донизу, как будто для них специально и пришли выставляться.',
#   'aspects': []},
#  '10632:8': {'text': 'Сложилось впечатление, что и мужчины, и дамы туда ходят именно искать знакомств для легкого времяпровождения.',
#   'aspects': []},
#  '10632:9': {'text': 'В остальном всё очень даже мило :)',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10731:0': {'text': 'Зашли поужинать вечером.', 'aspects': []},
#  '10731:1': {'text': 'Нам предложили vip-кабинет(см. фото-галерею ресторана).',
#   'aspects': []},
#  '10731:2': {'text': 'Нам все очень понравилось: интерьер, обслуживание. кухня.',
#   'aspects': [('35', '27', 'positive', 'AMBIENCE#GENERAL', 'интерьер'),
#    ('49', '37', 'positive', 'SERVICE#GENERAL', 'обслуживание'),
#    ('56', '51', 'positive', 'FOOD#QUALITY', 'кухня')]},
#  '10731:3': {'text': 'Настолько понравилось, что мы решили пригласить своих друзей отметить день рождения в этом ресторане.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10731:4': {'text': 'Администратор Виктория тут же составила меню, учла все наши пожелания, дала советы по проведению банкета.',
#   'aspects': [('13', '0', 'positive', 'SERVICE#GENERAL', 'Администратор')]},
#  '10731:5': {'text': 'Встреча друзей (нас было восемь человек) прошла великолепно -все остались очень довольны.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10731:6': {'text': 'И прекрасный отдельный зал(см. фото-галерею), и внимательный, но ненавязчивый персонал, и оригинальная кухня(мы взяли 8 разных горячих блюд и каждый утверждал, что у него самое вкусное) - все было просто "супер".',
#   'aspects': [('26', '23', 'positive', 'AMBIENCE#GENERAL', 'зал'),
#    ('86', '78', 'positive', 'SERVICE#GENERAL', 'персонал'),
#    ('108', '103', 'positive', 'FOOD#QUALITY', 'кухня'),
#    ('139', '127', 'positive', 'FOOD#QUALITY', 'горячих блюд')]},
#  '10731:7': {'text': 'Большое спасибо за прекрасный вечер, обязательно придем еще раз.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10731:8': {'text': 'P.S.Кстати: прекрасный сайт ресторана, меню!!! фото...',
#   'aspects': [('37',
#     '23',
#     'positive',
#     'RESTAURANT#MISCELLANEOUS',
#     'сайт ресторана'),
#    ('43', '39', 'positive', 'RESTAURANT#MISCELLANEOUS', 'меню')]},
#  '1077:0': {'text': 'Наш свадебный банкет состоялся 10 июля.', 'aspects': []},
#  '1077:1': {'text': 'Хотим выразить огромную благодарность персоналу и отдельно администратору Елене за прекрасное обслуживание.',
#   'aspects': [('47', '38', 'positive', 'SERVICE#GENERAL', 'персоналу'),
#    ('73', '59', 'positive', 'SERVICE#GENERAL', 'администратору'),
#    ('106', '94', 'positive', 'SERVICE#GENERAL', 'обслуживание')]},
#  '1077:2': {'text': 'Ресторан выбирали долго, ни разу не пожалели о своем выборе.',
#   'aspects': [('8', '0', 'positive', 'RESTAURANT#GENERAL', 'Ресторан')]},
#  '1077:3': {'text': 'Из плюсов назову замечательное расположение ресторана (если среди гостей есть приезжие из других городов, это особенно важно).',
#   'aspects': [('43', '31', 'positive', 'LOCATION#GENERAL', 'расположение')]},
#  '1077:4': {'text': 'Понравилась сама еда, повар - чудо! мы выбрали меню за 1500 на человека, заказали блюдо от шеф-повара и еще один салат, но и без наших дополнений угощения было бы достаточно.',
#   'aspects': [('20', '17', 'positive', 'FOOD#QUALITY', 'еда'),
#    ('27', '22', 'positive', 'FOOD#QUALITY', 'повар'),
#    ('154', '146', 'positive', 'FOOD#STYLE_OPTIONS', 'угощения')]},
#  '1077:5': {'text': 'В ресторане очень подходящая атмосфера для проведения свадебных мероприятий, настолько уютно и торжественно!',
#   'aspects': [('38', '29', 'positive', 'AMBIENCE#GENERAL', 'атмосфера')]},
#  '1077:6': {'text': 'У нас было 32 гостя, у всех очень хорошие впечатления.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '1077:7': {'text': 'Спасибо!', 'aspects': []},
#  '1077:8': {'text': 'Альфия и Иван.', 'aspects': []},
#  '10800:0': {'text': 'Часто посещаем Тан Жен на Большом проспекте В.О.',
#   'aspects': []},
#  '10800:1': {'text': 'впечатления только положительные. (Интерьер достаточно скромный, шумно, но)',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL'),
#    ('43', '35', 'neutral', 'AMBIENCE#GENERAL', 'Интерьер')]},
#  '10800:2': {'text': 'В выходные попасть достаточно трудно, поэтому лучше заказывать столик заранее.',
#   'aspects': []},
#  '10800:3': {'text': 'Несколько раз приходили в выходной без заказа, но администратор по-моему всегда способен найти свободный столик)))',
#   'aspects': [('63', '50', 'positive', 'SERVICE#GENERAL', 'администратор')]},
#  '10800:4': {'text': 'Очень нравится обслуживание: быстро, порции огромные, услужливые официанты.',
#   'aspects': [('27', '15', 'positive', 'SERVICE#GENERAL', 'обслуживание'),
#    ('43', '37', 'positive', 'FOOD#STYLE_OPTIONS', 'порции'),
#    ('74', '65', 'positive', 'SERVICE#GENERAL', 'официанты')]},
#  '10800:5': {'text': 'Заказывали банкетный зал.', 'aspects': []},
#  '10800:6': {'text': 'Порадовал индивидуальный подход к клиентам.',
#   'aspects': [('0', '0', 'positive', 'SERVICE#GENERAL', 'NULL')]},
#  '10800:7': {'text': 'Посещать лучше компанией: на четверых обычно заказываем 2 салата и 2 горячих.',
#   'aspects': []},
#  '10800:8': {'text': 'Любимые блюда: салат Тройка, салат из кальмаров, язык.',
#   'aspects': [('27', '15', 'positive', 'FOOD#QUALITY', 'салат Тройка'),
#    ('47', '29', 'positive', 'FOOD#QUALITY', 'салат из кальмаров'),
#    ('53', '49', 'positive', 'FOOD#QUALITY', 'язык')]},
#  '10800:9': {'text': 'Считаю, что стоит посетить это заведение только из-за фирменного блюда: баклажанов в соевом соусе.',
#   'aspects': [('70', '54', 'positive', 'FOOD#QUALITY', 'фирменного блюда'),
#    ('97', '72', 'positive', 'FOOD#QUALITY', 'баклажанов в соевом соусе')]},
#  '10800:10': {'text': 'А еще десерт очень вкусный: фрукты в горячей карамели!!!',
#   'aspects': [('12', '6', 'positive', 'FOOD#QUALITY', 'десерт'),
#    ('53', '28', 'positive', 'FOOD#QUALITY', 'фрукты в горячей карамели')]},
#  '10800:11': {'text': 'В общем, душевное заведение...',
#   'aspects': [('27', '18', 'positive', 'AMBIENCE#GENERAL', 'заведение')]},
#  '10816:0': {'text': 'Хотел поужинать с девушкой, но нам не повезло - именно в этот день у них отключили электричество.',
#   'aspects': []},
#  '10816:1': {'text': 'Обслуживающая нас девушка сказала что кухня не может предложить нам горячих блюд (а так же несколько холодных).',
#   'aspects': []},
#  '10816:2': {'text': 'Ничего горячего нам не удалось заказать, по этому оценку кухне ставить не буду, но и то что мы заказали не оставило ни положительных, ни отрицательных впечатлений.',
#   'aspects': [('0', '0', 'neutral', 'FOOD#QUALITY', 'NULL')]},
#  '10816:3': {'text': 'Заказали мы по салату цезарь, сырную тарелку, девушка взяла бокал вина "Бардо", я же взял лимонад так как был за рулём.',
#   'aspects': []},
#  '10816:4': {'text': 'Очень комично выглядело как официант принёсшая заказ наливала мне в винный бокал лимонад из бутылочки :)',
#   'aspects': []},
#  '10816:5': {'text': 'Интерьер приятный, понравился.',
#   'aspects': [('8', '0', 'positive', 'AMBIENCE#GENERAL', 'Интерьер')]},
#  '10816:6': {'text': 'Очень романтично сидеть на веранде и смотреть на канал...',
#   'aspects': [('34', '27', 'positive', 'AMBIENCE#GENERAL', 'веранде')]},
#  '10816:7': {'text': 'Наверное, потому как канала видно лишь всего ничего, зато как уже писали до меня, можно развлечься созерцанием студентов вечернего отделения финека.',
#   'aspects': []},
#  '10816:8': {'text': 'Сейчас зима и на веранде было довольно холодно так что девушка очень замерзла.',
#   'aspects': [('24', '17', 'negative', 'AMBIENCE#GENERAL', 'веранде')]},
#  '10816:9': {'text': 'На каждом стуле есть плед, но даже они не спасали.',
#   'aspects': []},
#  '10816:10': {'text': 'Несмотря на то, что наш заказ был не большой его подавали долго, если не сказать ОЧЕНЬ долго.',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL')]},
#  '10816:11': {'text': 'Такое чувство что они за это время вырастили новый виноград и уже из него сделали предложенное вино.',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL')]},
#  '10816:12': {'text': 'Ещё хочется отметить особенность меню - очень много персиков.',
#   'aspects': []},
#  '10816:13': {'text': 'Надеюсь заглянуть сюда вновь когда на улице будет тепло и когда в заведении будет свет.',
#   'aspects': []},
#  '10833:0': {'text': 'Посетили сегодня это кафе.', 'aspects': []},
#  '10833:1': {'text': 'Интерьер - ничего особенного, но уютно.',
#   'aspects': [('8', '0', 'neutral', 'AMBIENCE#GENERAL', 'Интерьер')]},
#  '10833:2': {'text': 'Играет тихая спокойная музыка.',
#   'aspects': [('29', '23', 'neutral', 'AMBIENCE#GENERAL', 'музыка')]},
#  '10833:3': {'text': 'Обслуживание хорошее.',
#   'aspects': [('12', '0', 'positive', 'SERVICE#GENERAL', 'Обслуживание')]},
#  '10833:4': {'text': 'Съела салат с лососем (по-моему, назывался Линда)- вкусный, но лосось пересолили.',
#   'aspects': [('21', '6', 'positive', 'FOOD#QUALITY', 'салат с лососем'),
#    ('69', '63', 'negative', 'FOOD#QUALITY', 'лосось')]},
#  '10833:5': {'text': 'И конечно же, начитавшись отзывов о наполеоне, решила его попробовать!',
#   'aspects': []},
#  '10833:6': {'text': 'Очень вкусный, крем нежирный, нежный.',
#   'aspects': [('19', '15', 'positive', 'FOOD#QUALITY', 'крем')]},
#  '10833:7': {'text': 'И самое главное, что не очень сладкий, как это бывает.',
#   'aspects': [('0', '0', 'positive', 'FOOD#QUALITY', 'NULL')]},
#  '10833:8': {'text': 'В меню очень много десертов (любителям сладкого найдется из чего выбрать)), надо будет еще что-нибудь попробовать.',
#   'aspects': [('27', '19', 'positive', 'FOOD#STYLE_OPTIONS', 'десертов'),
#    ('47', '39', 'positive', 'FOOD#STYLE_OPTIONS', 'сладкого')]},
#  '10833:9': {'text': 'В целом, неплохое место, а если учесть, что это кафе, то очень даже хорошее.',
#   'aspects': [('23', '18', 'positive', 'RESTAURANT#GENERAL', 'место')]},
#  '11796:0': {'text': 'Вчера заходили в Токио, шли из Миража, сначала зашли в Евразию... но хорошо, что там не оказалось мест!',
#   'aspects': []},
#  '11796:1': {'text': 'Помня из рестоклаба, что дальше находится Токио, пошли туда!',
#   'aspects': []},
#  '11796:2': {'text': 'Понравился большой зал, где много удобных мест на диванчиках, за которым смогли отлично поговорить, без шума и громкой музыки.',
#   'aspects': [('22', '19', 'positive', 'AMBIENCE#GENERAL', 'зал'),
#    ('60', '50', 'positive', 'AMBIENCE#GENERAL', 'диванчиках')]},
#  '11796:3': {'text': 'Показалось, что офицантки сами еще плутают по заведению, минут 5 пришлось ждать меню.',
#   'aspects': [('25', '16', 'neutral', 'SERVICE#GENERAL', 'офицантки')]},
#  '11796:4': {'text': 'Этого хватило , чтоб оглядеться)', 'aspects': []},
#  '11796:5': {'text': 'Достаточно хорошая обстановка.',
#   'aspects': [('29', '19', 'positive', 'AMBIENCE#GENERAL', 'обстановка')]},
#  '11796:6': {'text': 'Были неожиданно обрадованы акцией 2 по цене 1!!!',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#PRICES', 'NULL')]},
#  '11796:7': {'text': 'Но самое главное( по сравнению с Евразией(беспл.часы)) там все было очень вкусно!!!',
#   'aspects': [('0', '0', 'positive', 'FOOD#QUALITY', 'NULL')]},
#  '11796:8': {'text': 'Заказывали острый суп с морепродуктами, большие порции, достаточно острый, понравился!',
#   'aspects': [('38', '18', 'positive', 'FOOD#QUALITY', 'суп с морепродуктами'),
#    ('54', '48', 'positive', 'FOOD#STYLE_OPTIONS', 'порции')]},
#  '11796:9': {'text': 'Мидии под спайси соусом, очень хороши, напомнили мидии из 2 палочек.',
#   'aspects': [('23',
#     '0',
#     'positive',
#     'FOOD#QUALITY',
#     'Мидии под спайси соусом')]},
#  '11796:10': {'text': 'Куриное филе с пюре - очень красиво оформлено, филе нежное и достаточные порции.(если честно удивили, думал, раз такая акция все меньше намного)',
#   'aspects': [('19',
#     '0',
#     'positive',
#     'FOOD#STYLE_OPTIONS',
#     'Куриное филе с пюре'),
#    ('51', '47', 'positive', 'FOOD#QUALITY', 'филе'),
#    ('79', '73', 'positive', 'FOOD#STYLE_OPTIONS', 'порции')]},
#  '11796:11': {'text': 'Суши описывать не буду, ведь разные и на любителя!',
#   'aspects': []},
#  '11796:12': {'text': 'Понравились с креветкой, филадельфией и овощами.',
#   'aspects': [('47',
#     '12',
#     'positive',
#     'FOOD#QUALITY',
#     'с креветкой, филадельфией и овощами')]},
#  '11796:13': {'text': 'Кухня отличная, так держать!!!!',
#   'aspects': [('5', '0', 'positive', 'FOOD#QUALITY', 'Кухня')]},
#  '11796:14': {'text': 'Есть большое желание вернуться!',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '11796:15': {'text': 'Открывайте такой в Озерках или где-нибудь на Севере рядом)))',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '12819:0': {'text': 'Ужасное обслуживание!!!',
#   'aspects': [('20', '8', 'negative', 'SERVICE#GENERAL', 'обслуживание')]},
#  '12819:1': {'text': 'До сегодняшнего дня у меня было хорошее впечатление об этом баре, но вот официант, у которого мы пытались заказать столик, общался со мной просто отвратительно.',
#   'aspects': []},
#  '12819:2': {'text': 'На вопрос, есть ли у них некурящие места, нагло заявил (извиваясь при этом), что если нам нужны некурящие места, то вам в кафе рядом, а не к нам!',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL')]},
#  '12819:3': {'text': 'И удалился, хотя мы с ним общение еще не закончили!!!',
#   'aspects': []},
#  '12819:4': {'text': 'Больше никогда туда не пойду!',
#   'aspects': [('0', '0', 'negative', 'RESTAURANT#GENERAL', 'NULL')]},
#  '12819:5': {'text': 'Ужасное заведение!!!',
#   'aspects': [('17', '8', 'negative', 'RESTAURANT#GENERAL', 'заведение')]},
#  '15336:0': {'text': 'Прочитал все отзывы ниже и решил все же сходить и покушать туда с девушкой.',
#   'aspects': []},
#  '15336:1': {'text': 'Как и полагается, позвонил,заказал столик. попросил на первом этаже уютный.',
#   'aspects': []},
#  '15336:2': {'text': 'Пришли.', 'aspects': []},
#  '15336:3': {'text': 'Для нас зарезервировали самый лучший на мой взгляд столик.',
#   'aspects': []},
#  '15336:4': {'text': 'Интерьер классный.',
#   'aspects': [('8', '0', 'positive', 'AMBIENCE#GENERAL', 'Интерьер')]},
#  '15336:5': {'text': 'Сели.', 'aspects': []},
#  '15336:6': {'text': 'Сидим... еще 5 минут...', 'aspects': []},
#  '15336:7': {'text': 'Даже нет меню.',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL')]},
#  '15336:8': {'text': 'Выловил официанта.', 'aspects': []},
#  '15336:9': {'text': 'Меню принесли. а пепельницу нет.',
#   'aspects': [('27', '17', 'negative', 'SERVICE#GENERAL', 'пепельницу')]},
#  '15336:10': {'text': 'Минут через 10-15 подошли принимать заказ ( уже другой официант).',
#   'aspects': [('63', '55', 'negative', 'SERVICE#GENERAL', 'официант')]},
#  '15336:11': {'text': 'Приняли, минут через 15-20 принесли заказ.',
#   'aspects': []},
#  '15336:12': {'text': 'И...', 'aspects': []},
#  '15336:13': {'text': 'Пропали...',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL')]},
#  '15336:14': {'text': 'В заведении аншлага не было, но вот ощущение того, что о нас не помнят не покидало. пепельницу(которую все же пришлось просить) нам принесли и за весь вечер!!!!!',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL'),
#    ('94', '84', 'negative', 'SERVICE#GENERAL', 'пепельницу')]},
#  '15336:15': {'text': 'Ни разу не поменяли!!!!!!!',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL')]},
#  '15336:16': {'text': 'В течение всего вечера так и играли с официантом в игру "Поймай меня если сможешь".',
#   'aspects': [('48', '38', 'negative', 'SERVICE#GENERAL', 'официантом')]},
#  '15336:17': {'text': 'При чем, когда удалось подозвать другого официанта, она заказ принять отказалась, так как мы не ее столик. (правда позвала нашего официанта минуты через 3).',
#   'aspects': [('50', '41', 'negative', 'SERVICE#GENERAL', 'официанта')]},
#  '15336:18': {'text': 'Попросили счет. оплатили. а сдачи не несут.',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL')]},
#  '15336:19': {'text': 'Я конечно же понимаю, что чаевые и все такое, но их размер я хочу определять сам (сдача была 300 руб).',
#   'aspects': []},
#  '15336:20': {'text': 'Пришлось просить принести сдачу.',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL')]},
#  '15336:21': {'text': 'Итог.', 'aspects': []},
#  '15336:22': {'text': 'Интерьер 10 баллов.',
#   'aspects': [('8', '0', 'positive', 'AMBIENCE#GENERAL', 'Интерьер')]},
#  '15336:23': {'text': 'Кухня 7 баллов.',
#   'aspects': [('5', '0', 'neutral', 'FOOD#QUALITY', 'Кухня')]},
#  '15336:24': {'text': 'Сервис 1 ( а то и ноль.)',
#   'aspects': [('6', '0', 'negative', 'SERVICE#GENERAL', 'Сервис')]},
#  '15336:25': {'text': 'Из-за этого не уверен,что вернусь туда снова. наш счет на двоих составил 3700 руб. - альтернатива пена-бар.',
#   'aspects': [('0', '0', 'negative', 'RESTAURANT#GENERAL', 'NULL')]},
#  '15336:26': {'text': 'Рекомендация: Научите персонал работать хотя бы нормально!',
#   'aspects': [('30', '22', 'negative', 'SERVICE#GENERAL', 'персонал')]},
#  '1408:0': {'text': 'В прошедшее воскресенье заглянули в Метрополь незаметно и тихо отметить годовщину свадьбы.',
#   'aspects': []},
#  '1408:1': {'text': 'Первым впечатлением было удивление.', 'aspects': []},
#  '1408:2': {'text': 'Как правило перед посещением ресторанов впервые я стараюсь познакомиться с ними посредством сайтов, посмотреть меню, ну что бы понимать куда мы вообще идем и что ожидать, как от кухни, так и от ценовой политики.',
#   'aspects': []},
#  '1408:3': {'text': 'Так вот удивило меня как раз первое впечатление от ресторана - не смотря на довольно демократичные цены, интерьер сделан отлично, создается впечатление дороговизны, возможно даже роскоши...',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL'),
#    ('113', '105', 'positive', 'AMBIENCE#GENERAL', 'интерьер')]},
#  '1408:4': {'text': 'В общем не ожидал.', 'aspects': []},
#  '1408:5': {'text': 'Персонал оказался очень внимательным и вежливым, начиная от девушки хостесс внизу, заканчивая несколькими официантами.',
#   'aspects': [('8', '0', 'positive', 'SERVICE#GENERAL', 'Персонал'),
#    ('75', '60', 'positive', 'SERVICE#GENERAL', 'девушки хостесс'),
#    ('117', '106', 'positive', 'SERVICE#GENERAL', 'официантами')]},
#  '1408:6': {'text': 'Кухня понравилась.',
#   'aspects': [('5', '0', 'positive', 'FOOD#QUALITY', 'Кухня')]},
#  '1408:7': {'text': 'Оформление интересное, грамотное - блюда ХОЧЕТСЯ съесть)',
#   'aspects': [('10', '0', 'positive', 'FOOD#STYLE_OPTIONS', 'Оформление')]},
#  '1408:8': {'text': 'Вкусовые качества не отстают, например очень понравился подкопченный лосось с гофрами , красной икрой и кремом "шантий", рыба отменная (не знаю уж сами солят или нет), сочетание ингредиентов отличное.',
#   'aspects': [('119',
#     '56',
#     'positive',
#     'FOOD#QUALITY',
#     'подкопченный лосось с гофрами , красной икрой и кремом "шантий"'),
#    ('125', '121', 'positive', 'FOOD#QUALITY', 'рыба'),
#    ('190', '178', 'positive', 'FOOD#QUALITY', 'ингредиентов')]},
#  '1408:9': {'text': 'Пиво хорошее, не сказал бы, что лучшее в городе, но на уровне (мое личное субъективное мнение) с самым вкусным пивом, что я пробовал в Питере...',
#   'aspects': [('4', '0', 'positive', 'DRINKS#QUALITY', 'Пиво')]},
#  '1408:10': {'text': 'Оставили даже небольшой отзыв в волшебной книжке.',
#   'aspects': []},
#  '1408:11': {'text': 'В ближайшее время пойдем туда еще раз для более основательного знакомства с меню)',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '14130:0': {'text': 'Место очень даже хорошее.',
#   'aspects': [('5', '0', 'positive', 'RESTAURANT#GENERAL', 'Место')]},
#  '14130:1': {'text': 'Без особого пафоса.', 'aspects': []},
#  '14130:2': {'text': 'Уютное, более менее спокойное, располагает к отдыху.',
#   'aspects': [('51',
#     '0',
#     'neutral',
#     'AMBIENCE#GENERAL',
#     'Уютное, более менее спокойное, располагает к отдыху')]},
#  '14130:3': {'text': 'Прямо как на даче.', 'aspects': []},
#  '14130:4': {'text': 'По меню: наиотличнейший стейк с трюфельным маслом.',
#   'aspects': [('49',
#     '24',
#     'positive',
#     'FOOD#QUALITY',
#     'стейк с трюфельным маслом')]},
#  '14130:5': {'text': 'Салатики почти все ничего.',
#   'aspects': [('8', '0', 'neutral', 'FOOD#QUALITY', 'Салатики')]},
#  '14130:6': {'text': 'Хороший десерт с черникой.',
#   'aspects': [('14', '8', 'positive', 'FOOD#QUALITY', 'десерт')]},
#  '14130:7': {'text': 'Были на открытии, заприметили это местечко.',
#   'aspects': []},
#  '14130:8': {'text': 'Пару раз приходили, когда было очень мало народу.',
#   'aspects': []},
#  '14130:9': {'text': 'В такой обстановке можно и 10 поставить.',
#   'aspects': []},
#  '14130:10': {'text': 'А вот когда пришли вечером, да еще и выступала группа Иванушки, вот тут стало похуже.',
#   'aspects': [('0', '0', 'negative', 'RESTAURANT#GENERAL', 'NULL')]},
#  '14130:11': {'text': 'Зал был полный, но пару столиков пустовало, при этом официанты не справлялись, обслуживали долго.',
#   'aspects': [('62', '53', 'negative', 'SERVICE#GENERAL', 'официанты')]},
#  '14130:12': {'text': 'С коктейлями беда, маргарита клубничная, совсем и не клубничная, а из сиропа.',
#   'aspects': [('12', '2', 'negative', 'DRINKS#QUALITY', 'коктейлями'),
#    ('39', '19', 'negative', 'DRINKS#QUALITY', 'маргарита клубничная')]},
#  '14130:13': {'text': 'Зачем-то в счет включили то, чего мы не заказывали.',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL')]},
#  '14130:14': {'text': 'Но в принципе это не испортило нам настроения, т.к. все спасли Иванушки.',
#   'aspects': [('0', '0', 'neutral', 'RESTAURANT#GENERAL', 'NULL')]},
#  '14130:15': {'text': 'Итог: нам понравилось.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '14130:16': {'text': 'В сам "ресторан" еще обязательно вернусь.',
#   'aspects': [('15', '7', 'positive', 'RESTAURANT#GENERAL', 'ресторан')]},
#  '14130:17': {'text': 'Атмосфера такая, как будто приезжаешь к друзьям, благодаря теплому отношению, и еще наверно шеф-повару.',
#   'aspects': [('9', '0', 'positive', 'AMBIENCE#GENERAL', 'Атмосфера')]},
#  '14209:0': {'text': 'Искал, где отпраздновать свой день рождения!',
#   'aspects': []},
#  '14209:1': {'text': 'Выбор пал на Roll&Roll.', 'aspects': []},
#  '14209:2': {'text': 'Были здесь впервые.', 'aspects': []},
#  '14209:3': {'text': 'Отличная обстановка, мягкие, уютные диванчики, хорошее освещение (не напрягает)',
#   'aspects': [('19', '9', 'positive', 'AMBIENCE#GENERAL', 'обстановка'),
#    ('45', '36', 'positive', 'AMBIENCE#GENERAL', 'диванчики'),
#    ('64', '55', 'neutral', 'AMBIENCE#GENERAL', 'освещение')]},
#  '14209:4': {'text': 'Стол заказал утром в субботу на вечер.', 'aspects': []},
#  '14209:5': {'text': 'Официант посоветовал сделать предзаказ, рассказал меню, посоветовал блюда.',
#   'aspects': [('8', '0', 'positive', 'SERVICE#GENERAL', 'Официант')]},
#  '14209:6': {'text': 'Сервировка приятная.',
#   'aspects': [('10', '0', 'positive', 'FOOD#STYLE_OPTIONS', 'Сервировка')]},
#  '14209:7': {'text': 'Блюда были приготовлены вкусно.',
#   'aspects': [('5', '0', 'positive', 'FOOD#QUALITY', 'Блюда')]},
#  '14209:8': {'text': 'Горячее принесли вовремя.',
#   'aspects': [('24',
#     '0',
# ...
#   'aspects': [('60', '50', 'negative', 'SERVICE#GENERAL', 'официантка'),
#    ('201', '191', 'neutral', 'SERVICE#GENERAL', 'официантка')]},
#  '15855:10': {'text': 'Возникло ощущение, что маловато официантов на целый зал.',
#   'aspects': [('42', '32', 'negative', 'SERVICE#GENERAL', 'официантов')]},
#  '15855:11': {'text': 'Желаю Финнеганс процветания, хорошее место.',
#   'aspects': [('42', '37', 'positive', 'RESTAURANT#GENERAL', 'место')]},
#  '15856:0': {'text': 'Расскажу чудесную историю о том, как в ресторане "Тройка" дорожат клиентами.',
#   'aspects': [('57',
#     '39',
#     'positive',
#     'RESTAURANT#GENERAL',
#     'ресторане "Тройка"')]},
#  '15856:1': {'text': 'Моя подруга решила отметить в этом месте свой день рождения. так получилось, что день торжества совпал с кануном праздника Пасхи.',
#   'aspects': []},
#  '15856:2': {'text': 'Ресторан был пуст! (столик был заказан на 7 вечера)',
#   'aspects': []},
#  '15856:3': {'text': 'Но, открыт по случаю дня рождения :)', 'aspects': []},
#  '15856:4': {'text': 'К обслуживанию претензий не имею, всё идеально!',
#   'aspects': [('14', '2', 'positive', 'SERVICE#GENERAL', 'обслуживанию')]},
#  '15856:5': {'text': 'Мне как человеку, не употребляющем мясо и птицу, сложно сделать заказ.',
#   'aspects': []},
#  '15856:6': {'text': 'В тот день горячие блюда из рыбы не привлекли моё внимание.',
#   'aspects': []},
#  '15856:7': {'text': 'Заказала горячую закуску из овощей.', 'aspects': []},
#  '15856:8': {'text': 'Скажу честно, на вид мне не слишком понравилось (это лишь в силу способа приготовления, овощи после термообработки теряют яркость), главное, это было поразительно вкусно, учитывая, что к моменту подачи блюда я была уже не голодна.',
#   'aspects': [('207', '202', 'neutral', 'FOOD#STYLE_OPTIONS', 'блюда'),
#    ('207', '202', 'positive', 'FOOD#QUALITY', 'блюда')]},
#  '15856:9': {'text': 'Это был второй раз в моей жизни, когда я ела с таким аппетитом.',
#   'aspects': [('0', '0', 'positive', 'FOOD#QUALITY', 'NULL')]},
#  '15856:10': {'text': 'Виновницу торжества очень порадовало внимание со стороны ресторана и десерт от заведения)',
#   'aspects': [('0', '0', 'positive', 'SERVICE#GENERAL', 'NULL')]},
#  '15856:11': {'text': 'Не могу обойти выступление артистов.',
#   'aspects': [('35', '27', 'positive', 'AMBIENCE#GENERAL', 'артистов')]},
#  '15856:12': {'text': 'Красиво, профессионально (жаль не в моём вкусе такие шоу, в основном с большим интересом разглядывала декорации и костюмы).',
#   'aspects': [('0', '0', 'positive', 'AMBIENCE#GENERAL', 'NULL')]},
#  '15856:13': {'text': 'Уже решили периодически посещать это место.',
#   'aspects': [('42', '37', 'positive', 'RESTAURANT#GENERAL', 'место')]},
#  '15856:14': {'text': 'Спасибо ресторану "Тройка" за отличные впечатления!',
#   'aspects': [('26',
#     '8',
#     'positive',
#     'RESTAURANT#GENERAL',
#     'ресторану "Тройка"')]},
#  '15866:0': {'text': 'Выражаю от всей семьи коллективу ресторана благодарность за организацию работы по проведению юбилея моей мамы!',
#   'aspects': [('42',
#     '22',
#     'positive',
#     'SERVICE#GENERAL',
#     'коллективу ресторана')]},
#  '15866:1': {'text': 'Уже в самом начале из нашего общения стало понятно, что можно доверить работникам ресторана проведение столь важного для нас мероприятия.',
#   'aspects': [('91',
#     '71',
#     'positive',
#     'SERVICE#GENERAL',
#     'работникам ресторана')]},
#  '15866:2': {'text': 'Предложили разные варианты меню, варианты посадки гостей.',
#   'aspects': [('0', '0', 'positive', 'SERVICE#GENERAL', 'NULL'),
#    ('31', '18', 'positive', 'FOOD#STYLE_OPTIONS', 'варианты меню')]},
#  '15866:3': {'text': 'В день мероприятия дружелюбно встретили гостей и именинницу, было видно, что нас здесь очень ждут.',
#   'aspects': [('0', '0', 'positive', 'SERVICE#GENERAL', 'NULL')]},
#  '15866:4': {'text': 'По отзывам гостей, да и по нашему мнению - кухня ресторана восхитительна (за что спасибо шеф-повару)!',
#   'aspects': [('48', '43', 'positive', 'FOOD#QUALITY', 'кухня'),
#    ('99', '89', 'positive', 'FOOD#QUALITY', 'шеф-повару')]},
#  '15866:5': {'text': 'Красивая посуда, оформление, подача, ну и конечно, вкус - все на высоком уровне.',
#   'aspects': [('15', '9', 'positive', 'FOOD#STYLE_OPTIONS', 'посуда'),
#    ('27', '17', 'positive', 'FOOD#STYLE_OPTIONS', 'оформление'),
#    ('35', '29', 'positive', 'FOOD#STYLE_OPTIONS', 'подача'),
#    ('55', '51', 'positive', 'FOOD#QUALITY', 'вкус')]},
#  '15866:6': {'text': 'Работа официантов была незаметна, посуда и блюда менялись как-будто сами собой.',
#   'aspects': [('17',
#     '0',
#     'positive',
#     'SERVICE#GENERAL',
#     'Работа официантов')]},
#  '15866:7': {'text': 'Нельзя не отметить работу управляющего Александра.',
#   'aspects': [('38',
#     '19',
#     'positive',
#     'SERVICE#GENERAL',
#     'работу управляющего')]},
#  '15866:8': {'text': 'Благодаря ему, наш праздник стал именно праздником, а не заботой о гостях и еде.',
#   'aspects': [('0', '0', 'positive', 'SERVICE#GENERAL', 'NULL')]},
#  '15866:9': {'text': 'В такой ресторан хочется вернуться вновь.',
#   'aspects': [('16', '8', 'positive', 'RESTAURANT#GENERAL', 'ресторан')]},
#  '15866:10': {'text': 'Обязательно буду советовать друзьям и родственникам, хотя часть из них и сами все видели!',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '15866:11': {'text': 'Спасибо!',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '15914:0': {'text': 'Отличное место! 08.04.2010 отмечали свадьбу на втором этаже, с самой первой встречи администратор Анна расположила к себе, просмотрели еще несколько мест и не затягивая решили остановить свой выбор на этом релакс-кафе.',
#   'aspects': [('14', '9', 'positive', 'RESTAURANT#GENERAL', 'место'),
#    ('97', '84', 'positive', 'SERVICE#GENERAL', 'администратор')]},
#  '15914:1': {'text': 'Мены выбрали за 1550 (есть дороже) и ни сколько не пожалели, еды было много, все было очень вкусно и красиво разложено, расставлено, никто не ушел голодным!',
#   'aspects': [('64', '61', 'positive', 'FOOD#STYLE_OPTIONS', 'еды'),
#    ('64', '61', 'positive', 'FOOD#QUALITY', 'еды')]},
#  '15914:2': {'text': 'На все наши пожелания/требования администрация шла навстречу.',
#   'aspects': [('46', '33', 'positive', 'SERVICE#GENERAL', 'администрация')]},
#  '15914:3': {'text': 'Обслуживающий персонал был внимателен во время убирали со стола и всегда были наготове, согласовывали с нами время подачи горячей закуски и основного горячего блюда.',
#   'aspects': [('22',
#     '0',
#     'positive',
#     'SERVICE#GENERAL',
#     'Обслуживающий персонал')]},
#  '15914:4': {'text': 'Оставшееся спиртное и еду сложили и мы все забрали что-то в этот же день (родственники помогли) что-то на следующий день.',
#   'aspects': []},
#  '15914:5': {'text': 'Очень довольны этим местом!',
#   'aspects': [('26', '20', 'positive', 'RESTAURANT#GENERAL', 'местом')]},
#  '15914:6': {'text': 'Красивый интерьер, приятная музыка, отзывчивый персонал.',
#   'aspects': [('17', '9', 'positive', 'AMBIENCE#GENERAL', 'интерьер'),
#    ('34', '28', 'positive', 'AMBIENCE#GENERAL', 'музыка'),
#    ('55', '47', 'positive', 'SERVICE#GENERAL', 'персонал')]},
#  '15914:7': {'text': 'Мы с мужем с удовольствием придем туда поужинать в романтической обстановке))',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '15914:8': {'text': 'Спасибо Анне за организацию такого замечательного праздника',
#   'aspects': [('0', '0', 'positive', 'SERVICE#GENERAL', 'NULL')]},
#  '15966:0': {'text': '17 апреля 2010 года днём был семейный обед.',
#   'aspects': []},
#  '15966:1': {'text': 'Выбрали этот ресторан (скорее кафе).', 'aspects': []},
#  '15966:2': {'text': 'И не пожалели.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '15966:3': {'text': 'Поскольку особых требований к интерьеру мы не предъявляли, кроме отличного вида на залив, то и получили, что хотели.',
#   'aspects': [('88', '75', 'positive', 'LOCATION#GENERAL', 'вида на залив')]},
#  '15966:4': {'text': 'Ненавязчивая музыка, довольно приличные официанты (правда, приборы не раскладывают и вино не наливают).',
#   'aspects': [('19', '13', 'neutral', 'AMBIENCE#GENERAL', 'музыка'),
#    ('49', '40', 'neutral', 'SERVICE#GENERAL', 'официанты')]},
#  '15966:5': {'text': 'Но кухня очень понравилась.',
#   'aspects': [('8', '3', 'positive', 'FOOD#QUALITY', 'кухня')]},
#  '15966:6': {'text': 'Спасибо шеф-повару!',
#   'aspects': [('18', '8', 'positive', 'FOOD#QUALITY', 'шеф-повару')]},
#  '15966:7': {'text': 'Для четырех человек заказывали различные салаты и горячее.',
#   'aspects': []},
#  '15966:8': {'text': 'Порции большие, всё вкусно приготовлено, подается во-время.',
#   'aspects': [('6', '0', 'positive', 'FOOD#QUALITY', 'Порции'),
#    ('6', '0', 'positive', 'FOOD#STYLE_OPTIONS', 'Порции')]},
#  '15966:9': {'text': 'Рекомендую всем, кто после прогулки решил вкусно пообедать.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '15966:10': {'text': 'Цены очень демократичные.',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#PRICES', 'NULL')]},
#  '15974:0': {'text': '17 апреля посетил ваш ресторан...', 'aspects': []},
#  '15974:1': {'text': 'Ещё с улицы заметил ваш замечательный интерьер и решил у вас поужинать...',
#   'aspects': [('46', '38', 'positive', 'AMBIENCE#GENERAL', 'интерьер')]},
#  '15974:2': {'text': 'Первое что понравилось,это то как меня встретил ваш менеджер Илья, всё как я люблю,с улыбкой и юмором.',
#   'aspects': [('60', '52', 'positive', 'SERVICE#GENERAL', 'менеджер')]},
#  '15974:3': {'text': 'После меня посадили за столик и я был приятно удивлён что официант любезно взял мою верхнюю одежду и повесил в гардероб...(Давно такого не встречал).',
#   'aspects': [('66', '58', 'positive', 'SERVICE#GENERAL', 'официант')]},
#  '15974:4': {'text': 'Так как у вас был в первый раз , очень благодарен официанту Валентину за грамотное объяснение всех моих вопросов по поводу меню.',
#   'aspects': [('59', '50', 'positive', 'SERVICE#GENERAL', 'официанту')]},
#  '15974:5': {'text': 'И опять хочу отметить что ваш персонал очень позитивен.',
#   'aspects': [('38', '30', 'positive', 'SERVICE#GENERAL', 'персонал')]},
#  '15974:6': {'text': 'Валентин излучал позитив и очень поднял мне настроение после моего рабочего дня...(Позитив официантов особенно в вечернее время это сейчас большая редкость).',
#   'aspects': [('101', '91', 'positive', 'SERVICE#GENERAL', 'официантов')]},
#  '15974:7': {'text': 'Заказав блюда,было очень неожиданно получить комплимент от шеф-повара - Паштет из оленины...',
#   'aspects': [('69',
#     '45',
#     'positive',
#     'SERVICE#GENERAL',
#     'комплимент от шеф-повара')]},
#  '15974:8': {'text': 'Который скрасил моё ожидание заказанных мной блюд...',
#   'aspects': []},
#  '15974:9': {'text': 'Через пятнадцать минут я уже наслаждался вашими шедеврами.',
#   'aspects': [('0', '0', 'positive', 'FOOD#QUALITY', 'NULL')]},
#  '15974:10': {'text': 'Кухня у вас как говорится на уровне...',
#   'aspects': [('5', '0', 'positive', 'FOOD#QUALITY', 'Кухня')]},
#  '15974:11': {'text': 'Ушёл от вас сытым и довольным)',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '15974:12': {'text': 'Надеюсь ваш персонал всегда так же позитивен и доброжелателен...',
#   'aspects': [('20', '12', 'positive', 'SERVICE#GENERAL', 'персонал')]},
#  '15974:13': {'text': 'Ребята молодцы,надеюсь руководство ресторана как то это поощряет и мой отзыв не останется незамеченным...',
#   'aspects': [('0', '0', 'positive', 'SERVICE#GENERAL', 'NULL')]},
#  '15974:14': {'text': 'Спасибо!', 'aspects': []},
#  '15974:15': {'text': 'P.S. Обязательно вернусь к вам ещё...',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '15974:16': {'text': 'Только уже с друзьями.', 'aspects': []},
#  '15974:17': {'text': 'Кухня ваша очень понравилась,оценил её так как сам являюсь поваром...)',
#   'aspects': [('5', '0', 'positive', 'FOOD#QUALITY', 'Кухня')]},
#  '15974:18': {'text': 'Ещё раз спасибо!',
#   'aspects': [('0', '0', 'positive', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10837:0': {'text': 'В Диану мы заглянули 04.02.2011 г. (подыскивали место для семейного торжества).',
#   'aspects': []},
#  '10837:1': {'text': 'Как ни странно, кроме нас посетителей не было, несмотря на вечер пятницы.',
#   'aspects': []},
#  '10837:2': {'text': 'Девушка-официант встретила очень любезно и приветливо, мы с порога почувствовали себя как дома.',
#   'aspects': [('16', '0', 'positive', 'SERVICE#GENERAL', 'Девушка-официант')]},
#  '10837:3': {'text': 'Интерьер очень понравился - торжественный, изысканный, но не давит помпезностью.',
#   'aspects': [('8', '0', 'positive', 'AMBIENCE#GENERAL', 'Интерьер')]},
#  '10837:4': {'text': 'На стенах у бара - фотографии со знаменитыми гостями ресторана.',
#   'aspects': []},
#  '10837:5': {'text': 'Зал небольшой, интерьер в благородных красно-синих тонах, что создает ощущение камерности и уюта.',
#   'aspects': [('23', '15', 'positive', 'AMBIENCE#GENERAL', 'интерьер')]},
#  '10837:6': {'text': 'Особенно здорово смотрятся декоративные окна с ночным пейзажем!',
#   'aspects': [('44',
#     '27',
#     'positive',
#     'AMBIENCE#GENERAL',
#     'декоративные окна')]},
#  '10837:7': {'text': 'Меню продуманное и разнообразное, замечательные десерты, есть отличные предложения торжественных блюд для банкетов, на заказ сделают торт любой сложности.',
#   'aspects': [('4', '0', 'positive', 'FOOD#STYLE_OPTIONS', 'Меню'),
#    ('55', '48', 'positive', 'FOOD#QUALITY', 'десерты'),
#    ('101', '97', 'positive', 'FOOD#QUALITY', 'блюд'),
#    ('137', '133', 'positive', 'FOOD#STYLE_OPTIONS', 'торт')]},
#  '10837:8': {'text': 'Особенно порадовала винная карта.',
#   'aspects': [('32',
#     '20',
#     'positive',
#     'DRINKS#STYLE_OPTIONS',
#     'винная карта')]},
#  '10837:9': {'text': 'Вино, которое порекомендовал нам радушный хозяин заведения, было выше всяких похвал!',
#   'aspects': [('4', '0', 'positive', 'DRINKS#QUALITY', 'Вино'),
#    ('58', '42', 'positive', 'SERVICE#GENERAL', 'хозяин заведения')]},
#  '10837:10': {'text': 'Вообще, все, что нам предложили на ужин, было очень вкусно.',
#   'aspects': [('39', '35', 'positive', 'FOOD#QUALITY', 'ужин')]},
#  '10837:11': {'text': 'Из минусов - расстроил женский туалет (не работал замок на двери), и вообще вид холла несколько простоват по сравнению с остальным интерьером.',
#   'aspects': [('37', '31', 'negative', 'RESTAURANT#MISCELLANEOUS', 'туалет'),
#    ('85', '80', 'negative', 'AMBIENCE#GENERAL', 'холла')]},
#  '10837:12': {'text': 'В целом от посещения Дианы остались самые теплые воспоминания, непременно туда вернемся сами и смело можем рекомендовать этот уютный ресторан как для романтического ужина, так и для банкета человек на 30-35',
#   'aspects': [('26', '21', 'positive', 'RESTAURANT#GENERAL', 'Дианы'),
#    ('141', '133', 'positive', 'AMBIENCE#GENERAL', 'ресторан'),
#    ('141', '133', 'positive', 'RESTAURANT#GENERAL', 'ресторан')]},
#  '10855:0': {'text': 'Испорченный вечер...((',
#   'aspects': [('0', '0', 'negative', 'RESTAURANT#GENERAL', 'NULL')]},
#  '10855:1': {'text': 'Решили с мужем отметить день рождения и попутно день влюбленных (14 февраля).',
#   'aspects': []},
#  '10855:2': {'text': 'Забронировали столик за неделю.', 'aspects': []},
#  '10855:3': {'text': 'Пришли вовремя, про нас не вспомнили, долго рылись в каких-то записях, ура! нашли заметку про резерв стола.',
#   'aspects': [('0', '0', 'negative', 'SERVICE#GENERAL', 'NULL')]},
#  '10855:4': {'text': 'Сели.', 'aspects': []},
#  '10855:5': {'text': 'Музыка из динамиков сначала просто оглушала, потом ничего - привыкли.',
#   'aspects': [('6', '0', 'negative', 'AMBIENCE#GENERAL', 'Музыка')]},
#  '10855:6': {'text': 'Правда поговорить спокойно так и не удалось. (за соседними столами парочки так же громко говорили о личном, пытаясь перекричать динамики).',
#   'aspects': [('0', '0', 'negative', 'AMBIENCE#GENERAL', 'NULL')]},
#  '10855:7': {'text': 'Интерьер на троечку, ну собственно не за этим пришли.',
#   'aspects': [('8', '0', 'negative', 'AMBIENCE#GENERAL', 'Интерьер')]},
#  '10855:8': {'text': 'А зачем? - правильно, за мясом!', 'aspects': []},
#  '10855:9': {'text': 'Заказали рибай (590 р) и каре (ок. 600 р), попутно пару пива, чтоб скрасить ожидание.',
#   'aspects': []},
#  ...}

# %%
sem_test_ids = list(set([i.split(':')[0] for i in test_mark.keys()]))

# %%
How - - O O O

# %%
Steve - - B_AP NEUTRAL B_AP+NEUTRAL

# %%
elif token.start > int(aspect['from']) and token.stop <= int(aspect['to']):

# %%
'positive'.upper()
# Out:
# 'POSITIVE'

# %%
with open('../../data/test_sem_CoNLL.txt', 'w') as f:
    f.write('-DOCSTART-\n\n')
    for id_ in sem_test_ids:
        rev_sents = sorted([x for x in test_mark.keys() if x.startswith(id_)], 
                           key = lambda x: int(x.split(":")[-1]))
        for key in rev_sents:
            text = test_mark[key]['text']
            tokens = tokenize(text)
            for token in tokens:
                line = f'{token.text} - - O O O\n'
                for span in test_mark[key]['aspects']:
                    if span[2] not in ['neutral', 'conflict']:
                        if token.start == int(span[1]) and span[-1] != 'NULL':
                            line = f'{token.text} - - B_AP {span[2].upper()} B_AP+{span[2].upper()}\n'
                        elif token.start > int(span[1]) and token.stop <= int(span[0]):
                            line = f'{token.text} - - I_AP {span[2].upper()} I_AP+{span[2].upper()}\n'
                f.write(line)
        f.write('\n')

# %%
train
# Out:
# {'15758': {'text': 'Был в заведении со своей девушкой в пятницу. Очень неплохо. Ресторану еще много есть над чем поработать, конечно, но тем не менее, место довольно милое, обслуживание приятное и еда довольно вкусна. Заказывали салаты и горячее(стейк из лосося и блюдо под названием "сытая хавронья" из свинины). Принесли быстро. Крепкого алкоголя, кроме пива у них пока нет, видимо с лицензией проблемы, но медовуха оказалась очень даже приятной. Хотелось бы, конечно, большего разнообразия в меню, но так как они недавно открылись, думаю, со временем все у них наладится.',
#   'aspects': [[131, 136, 'positive'],
#    [153, 165, 'positive'],
#    [177, 180, 'positive'],
#    [389, 397, 'positive']]},
#  '2073': {'text': 'Три дня назад отмечали в этом "ресторане" день рождения. Сегодня решила почитать отзывы по этому заведению, так как вечер был просто испорчен. Складывается такое впечатление, что мы были где-то в другом месте. Да, неплохой интерьер, неплохая кухня... но все остальное просто ужас. Во-первых такого отвратительного обслуживания я не видела нигде. На весь ресторан работала одна официантка, что само по себе странно. Если бы она просто не справлялась с обилием заказов, то еще как то извинительно, но она не очень то и старалась. Например вино нам несли 20 мин., курить мы выходили на улицу, где для этого стоят кресла и столик, попросили ее принести пепельницу... она пообещала, но до конца нашего застолья так этого и не сделала. На закуску мы среди прочего заказывали оливки, так их нам принесли почти в конце вечера, про один заказ она вообще забыла, на что просто извинилась. Отдельная история - живая музыка. Хороший певец, с хорошим голосом... но для такого маленького помещения - это просто тихий ужас. Разговаривать было невозможно не только с другим концом стола, но и соседей справа-слева приходилось переспрашивать. Соглашусь, на вкус и цвет товарищей нет, но я в этот ресторан больше ни ногой и всех своих друзей обязательно предупрежу',
#   'aspects': [[97, 106, 'negative'],
#    [314, 326, 'negative'],
#    [377, 387, 'negative'],
#    [899, 911, 'negative'],
#    [974, 983, 'negative'],
#    [1179, 1187, 'negative']]},
#  '24713': {'text': 'Отмечали в банкетном зале свадьбу сына в июле 2013. Зал замечательный. Но... Мы выбрали среднее в ценовой категории меню. Когда пришли, меня удивило небольшое кол-во закусок. Мне казалось, что должно быть больше. Сырная тарелка поразила засохшим сыром. Фрукты были на последнем издыхании. Когда попробовала салаты- пришла в ужас. По качеству тянут на забегаловку, а не на банкетный зал. До заказа банкета я кое-что заказала в кафе на первом этаже. Еда понравилась. Но, такое впечатление, что на банкет готовит кто-то другой. Горячее тоже не понравилось. Торт у нас был свой. Свадьба, конечно, прошла весело, но качество еды ее не украсило. Когда молодые уехали, гости разошлись, я попросила упаковать нам оставшееся. Администратор при оформлении сказал, что все будет упаковано и собрано, включая алкоголь и соки. К моему удивлению, официанты мне сказали, что я могу сама все собрать со столов, они за отдельную плату дадут мне контейнеры. После ТРИДЦАТИ минут пререканий, мне удалось заставить их кое-что сложить. Оставшийся алкоголь, воду и соки собирали сами. В этом году женится второй сын. Когда он сказал, что этот зал уже занят на нужную дату- я обрадовалась.',
#   'aspects': [[52, 55, 'positive'],
#    [166, 173, 'negative'],
#    [213, 227, 'negative'],
#    [246, 251, 'negative'],
#    [253, 259, 'negative'],
#    [307, 313, 'negative'],
#    [448, 451, 'positive'],
#    [525, 532, 'negative'],
#    [620, 623, 'negative'],
#    [833, 842, 'negative'],
#    [502, 509, 'negative']]},
#  '16630': {'text': 'Уютная и тёплая домашняя обстановка! Милый и отзывчивый персонал, очень внимательное обслуживание. Еда, стоит ли говорить, что трудно удивить человека, привыкшего и знающего грузинскую кухню. Могу сказать одно, я была приятно удивлена! Спасибо персоналу, ему удается создать ощущение, что этот ресторан - особенное место где каждый чувствует себя долгожданным гостем!)))))))))))',
#   'aspects': [[25, 35, 'positive'],
#    [56, 64, 'positive'],
#    [85, 97, 'positive'],
#    [99, 102, 'positive'],
#    [244, 253, 'positive'],
#    [294, 302, 'positive'],
#    [315, 320, 'positive']]},
#  '27841': {'text': 'Первый раз зашла случайно, хотелось кофе попить...Сразу было очарована обслуживающим персоналом: встречают так, как будто ждали именно тебя и очень рады визиту. Кофе вкусное, тортики отменные. Потом несколько раз заходили с друзьями, посидеть, выпить пивка. Выбор пива небольшой, но это нормально все-таки это больше кондитерская...Хотя все нашли себе напиток по вкусу, есть и Тиммерманс и Невское. Очень понравились закусочки: и жаренные крылышки, и особенно кальмары. Их подают еще и с колечками лука. Правда без соуса, в меню мы соуса тоже не обнаружили, но приветливая девушка-официантка на наш вопрос о соусе, предложила 2 вида и сразу же принесла. Интерьер неплохой, жалко только, что диванчики и плазменная панель только в зале для некурящих. Обслуживание на 10, все вовремя, мило и с улыбкой. Отлично, что появилось такое приятное местечко в нашем районе.',
#   'aspects': [[71, 95, 'positive'],
#    [161, 165, 'positive'],
#    [175, 182, 'positive'],
#    [352, 359, 'positive'],
#    [377, 387, 'positive'],
#    [390, 397, 'positive'],
#    [417, 426, 'positive'],
#    [430, 447, 'positive'],
#    [460, 468, 'positive'],
#    [515, 520, 'negative'],
#    [573, 591, 'positive'],
#    [750, 762, 'positive'],
#    [839, 847, 'positive']]},
#  '12880': {'text': 'Не судите человека по одёжке... 9 мая...Пасмурный,но теплый Питерский вечер... В компании подруг решили прогуляться по центру,перекусить решили в Tefsi,так как были рядом и слышали много хорошего. Встретили нас на входе удивленно, так как выглядели мы,как тинейджеры),но как говорят у нас в компании "можем себе позволить"))). Не буду говорить об интерьере, так как наверно в предыдущих отзывах все уже написано,могу сказать одно-понравилось, кухня тоже нас порадовала- хачапури отличный, хинкали большие,но мясо чуть-чуть суховато,баклажаны запеченные отменные, люля неплох, но не хватало соуса, а официант не предложил дополнительно его заказать.Вот и все хорошее заканчивается, так как сервис в этом заведение на нуле, блюда одновременно не приносили, в итоге я ела,когда все остальные свои блюда уже съели,тарелки грязные со стола не убирали,но самое главное,когда принесли сдачу- чека не было,сразу все хорошие впечатления об этом ресторане испарились,естественно никто к нам больше не подошел,а когда мы уходили никто с нами не попрощался.Чаевые не оставили,так как считаю,что персонал этого заведения уже заработал себе на "чай".',
#   'aspects': [[347, 356, 'positive'],
#    [443, 448, 'positive'],
#    [470, 478, 'positive'],
#    [489, 496, 'positive'],
#    [508, 512, 'negative'],
#    [532, 541, 'positive'],
#    [590, 595, 'negative'],
#    [599, 607, 'negative'],
#    [689, 695, 'negative'],
#    [936, 945, 'negative'],
#    [1083, 1091, 'negative'],
#    [1098, 1107, 'negative']]},
#  '32040': {'text': 'Хороший ресторан с неплохим обслуживанием. Были в нем два раза. Оба раза остались довольны. Уютный интерьер в итальянском стиле, вежливые и внимательные девушки официанты, приятная музыка без бум-бумов. Кухня – не плохая, хотя, некоторые блюда, были приготовлены не по правилам. А что самое главное - не много людей. Оба раза, когда мы были в ресторане, параллельно с нами было занято лишь 2-3 столика. Ресторан хорошо подходит для романтического ужина. По цене: ужин на двоих обходится где-то 2000р',
#   'aspects': [[8, 16, 'positive'],
#    [99, 107, 'positive'],
#    [153, 170, 'positive'],
#    [181, 187, 'positive'],
#    [238, 243, 'negative'],
#    [403, 411, 'positive']]},
#  '19111': {'text': 'Был с друзьями в четвером в этом ресторане. Что могу сказать: 1. Персонал мне понравился, официантка была очень приятной, общительной и доброжелательной, по нашей просьбе без проблем сфотографировала нас, еду приносила быстро, лишнии тарелки тоже не задерживалаись на столе. В гардеробе дядечка тоже очень вежливый и все остальные кого видели из персонала произвели приятное впечатление. 2. Были в воскресенье в 15:30, народу никого не было, это немного удивило, потом подошли еще люди конечно. Зал большой, мебель приличная, большой телевизор на стене удобно смотреть с любого столика наверно. 3. Сначала хотели заказать чешские спиртные напитки, но их не оказалось к сожалению, немного расстроились, но не сильно. Заказали виски - виски нормальное, понравилось. Также заказали мясное ассорти, и капусту тушенную с мясом. Претензий к качеству блюд нету. Ничего суперского, но на уровне. В целом ресторан оставил приятное впечатление.',
#   'aspects': [[65, 73, 'positive'],
#    [90, 100, 'positive'],
#    [287, 294, 'positive'],
#    [346, 355, 'positive'],
#    [495, 498, 'positive'],
#    [534, 543, 'positive'],
#    [622, 646, 'negative'],
#    [733, 738, 'positive'],
#    [896, 904, 'positive']]},
#  '10847': {'text': 'Вчера, стало быть в понедельник, 14 февраля, отправился в это местечко, ранее мне неизвестное. Обстановка милая, уютная. Есть, конечно, как и в любом другом кафе столики, которые уютными не назовешь, но всем не угодишь и в целом мне обстановка понравилась. Сразу видно, что к интерьеру подходили как можно тщательнее, это радует. Администратор и официанты весьма вежливы. В кафе чувствуется от персонала, что люди хотят работать и это им нравится, а это самое главное!) Никаких задержек при подаче блюд/напитков не было. Единственное удивление образовалось, когда на десерт мне принесли ложку вместо десертной вилки, но это проблем не вызвало. Но вы попробовали бы этот десерт м.м.м. Десерт был очень вкусный, нам понравилось) Суши панированные в рыбных сухарях или как-то так вызвали очень много восхищения, т.к. это было действительно вкусно. По кухне можно сказать, что это кафе для тех, кто любит соотношение цены и качества. Есть все необходимое. В целом кафе оставляет очень приятные воспоминания. Всем очень рекомендую сходить и попробовать местную японскую кухню. На втором этаже на диванчиках весьма удобно разместиться компанией.',
#   'aspects': [[95, 105, 'positive'],
#    [233, 243, 'positive'],
#    [276, 285, 'positive'],
#    [330, 343, 'positive'],
#    [346, 355, 'positive'],
#    [394, 403, 'positive'],
#    [670, 676, 'positive'],
#    [684, 690, 'positive'],
#    [727, 761, 'positive'],
#    [848, 853, 'positive'],
#    [877, 881, 'positive'],
#    [960, 964, 'positive'],
#    [1056, 1070, 'positive'],
#    [1075, 1087, 'positive'],
#    [1091, 1101, 'positive']]},
#  '10354': {'text': 'Я не ходила в этот ресторан в детстве, не знаю, как всё было когда-то, но сейчас это вполне симпатичное и уютное заведение с хорошей кухней. Впервые посетили "Чебурек" c месяц назад - отмечали с друзьями прошедшую ранее свадьбу. Администрация любезно предоставила нам новый банкетный зал, где мы закрылись, включили свою музыку, курили кальян, веселились, и нам никто не мешал. Кухня всем друзьям понравилась, обслуживание тоже (девушки-официантки замечательные). Меня же больше всего порадовало, что администрация пошла нам навстречу и сделала хорошую скидку на банкет :) Уже через неделю моя подруга вернулась в "Чебурек" со своими родными, где они отметили юбилей отца. Мы также возвращаемся сюда снова и снова. Единственное, что расстраивает - это рост цен. За последний месяц цены менялись уже два раза. Растут они по чуть-чуть, но всё равно стоимость ужина на двоих с каждым посещением получалась у нас всё выше и выше :) Но без этого, конечно, никуда. Из кухни могу порекомендовать: чебуреки с сыром сулугуни и зеленью (волшебные!), сациви из баклажан, суп чанахи, конечно же, хинкали, ну и, наверное, бараньи ножки (не помню точное название блюда). Всё это не оставит равнодушным никого, очень вкусно и "аутентично"!))',
#   'aspects': [[113, 122, 'positive'],
#    [113, 122, 'positive'],
#    [133, 139, 'positive'],
#    [229, 242, 'positive'],
#    [378, 383, 'positive'],
#    [410, 422, 'positive'],
#    [429, 447, 'positive'],
#    [501, 514, 'positive'],
#    [614, 623, 'positive'],
#    [857, 861, 'negative'],
#    [990, 1025, 'positive'],
#    [1040, 1058, 'positive'],
#    [1060, 1070, 'positive'],
#    [1084, 1091, 'positive'],
#    [1109, 1122, 'positive']]},
#  '21059': {'text': 'Добрый день. Отмечали в этом ресторане 7 марта,был банкет на 20 человек. Так как открылись они недавно,отзывов нет никаких,было немного страшно идти в новое место,но так как живем рядом,решили рискнуть,и не пожалели!!!! Заранее все оплатили,нам помогли меню составить индивидуально под наши запросы и бюджет. К нашему приходу все уже было готово,столы накрыты,еда вынесена. Кухня просто обалденная,порции большие,все остались очень довольны!!Приятно удивила программа-живая музыка(девушка очень красиво пела),и грузинские танцевальный коллектив,потрясающе!!! Зал очень большой, светлый,кроме нас там было еще 2 банкета,но за счет большого пространства никто никому не мешал. Огромный плюс,что алкоголь можно с собой приносить,пробкового сбора нет. В общем все остались очень очень довольны,спасибо Вам большое за чудесный праздник,обязательно придем к Вам еще!!!!!!',
#   'aspects': [[374, 379, 'positive'],
#    [398, 404, 'positive'],
#    [458, 467, 'positive'],
#    [468, 480, 'positive'],
#    [511, 544, 'positive'],
#    [559, 562, 'positive'],
#    [726, 742, 'positive'],
#    [157, 162, 'negative']]},
#  '25960': {'text': 'Первые месяцы после открытия просто не могли нарадоваться такому классному местечку. И с друзьями весело посидеть и вдвоем с молодым человеком. Обслуживание было отличное и качество блюд на высоте. Бывали там раза 3 в неделю. Теперь как то все испортилось. Народу стало ужасно много всегда. Сервис упал резко. Последний раз нам даже не вытерли столик после прежних посетителей. Очень часто не бывает того что есть в меню (хотя раньше такого не было) да и качество еды испортилось на мой взгляд. А вот цены остались на прежнем уровне. Вобщем больше не радует это место.',
#   'aspects': [[75, 83, 'positive'],
#    [144, 156, 'positive'],
#    [182, 186, 'positive'],
#    [291, 297, 'negative'],
#    [416, 420, 'negative'],
#    [464, 467, 'positive'],
#    [562, 567, 'negative']]},
#  '2965': {'text': 'Посетили ресторан Ялта 11.05.12,по случаю Дня Рождения,заказали столик на 8 человек за день до торжества,при заказе нам показали ресторан,предложили несколько вариантов для размещения наших гостей,мы выбрали отдельно стоящие 2 столика окруженные диванами и креслами,рядом с панорамным окном,предоплату за заказ не оставляли,(что выгодно отличило этот ресторан от других,учитывая что наше событие было запланировано на вечер пятницы). Ресторан выгодно отличается спокойной атмосферой,приятной, НЕ громкой живой музыкой,что оставляет шанс для приятной беседы.Обслуживание не навязчивое,я бы сказала незаметное,очень приятные официанты,сразу принесли вазу для цветов,приняли заказ,все очень вежливо,с хорошим знанием меню и доброжелательностью. Кухня порадовала разнообразием,хорошим,информативным меню,по которому легко можно было выбрать блюдо на любой вкус,так как представлена японская,русская ,грузинская кухня.Порции большие,посуда хорошая,вкус отменный.Чек немного выше ,чем в других ресторанах,этого класса,но наши положительные эмоции стоили этого. Очень приятно провели время,очень рады что выбрали этот ресторан ,довольны остались уровнем сервиса и кухней.',
#   'aspects': [[351, 359, 'positive'],
#    [472, 482, 'positive'],
#    [504, 517, 'positive'],
#    [557, 569, 'positive'],
#    [623, 632, 'positive'],
#    [706, 718, 'positive'],
#    [742, 747, 'positive'],
#    [795, 799, 'positive'],
#    [913, 919, 'positive'],
#    [928, 934, 'positive'],
#    [1111, 1119, 'positive'],
#    [1147, 1154, 'positive'],
#    [1157, 1163, 'positive'],
#    [837, 842, 'positive'],
#    [434, 442, 'positive'],
#    [943, 947, 'positive']]},
#  '37036': {'text': 'Отмечали в этом ресторане день рождение в субботу вечером. Хочу выразить большую благодарность прежде всего руководству ресторана, обслуживающему персоналу и конечно же тем поварам, которые готовят посетителям заведения столь вкусные блюда. Понравилось абсолютно все. Конечно же впечатляет интерьер: уютно и красиво. Стол был шикарный. Хочу отметить, что для ресторана такого уровня цены не высокие. Хочется снова окунуться в незабываемую атмосферу, которая присуща данному заведению.',
#   'aspects': [[108, 129, 'positive'],
#    [131, 155, 'positive'],
#    [173, 180, 'positive'],
#    [226, 233, 'positive'],
#    [234, 239, 'positive'],
#    [290, 298, 'positive'],
#    [317, 321, 'positive'],
#    [439, 448, 'positive']]},
#  '10985': {'text': 'Решили недалеко от дома сходить в китайский ресторанчик, самым близким оказался Жен-Жен. На первый взгляд с улицы были видны китайские аттрибуты. Внутри на первом этаже танцпол, гудела европейская попса, нас попросили пройти на второй этаж. Была приятно удивлена "китайским интерьером" - диванчики как в бистро, скатерти на столах по типу а-ля столовая, европейские светильники/люстры, в общем в плане интерьера китайского никакого абсолютно! Заведение неуютное. Ну так как ехать в другое место уже не было сил, решили заказать все-такие еду. Меню не порадовало - отпечатанные листки, не особо понятен состав блюд и вес, о картинках даже речи не было. Ну ладно - с китайской кухней знакомы - заказали говядину, свинину, рис, пару закусок, порции оказались большими, еда - вкусной, принесли все горячее. Конечно посуда и сервировка стола могли бы быть и получше. По поводу сервиса - официантка не здоровалась, не успели сесть - пришла за заказом,правда блюда вынесли быстро, но счет пришлось ждать....при том, что кроме нас было занято всего 2 столика еще. в общем покушать было вкусно, но второй раз идти не хочется - люблю все же чтоб присутствоавал китайский антураж в подобных местах.',
#   'aspects': [[264, 284, 'negative'],
#    [288, 297, 'negative'],
#    [312, 330, 'negative'],
#    [402, 411, 'negative'],
#    [443, 452, 'negative'],
#    [543, 547, 'negative'],
#    [602, 613, 'negative'],
#    [701, 709, 'positive'],
#    [711, 718, 'positive'],
#    [720, 723, 'positive'],
#    [730, 737, 'positive'],
#    [739, 745, 'positive'],
#    [766, 769, 'positive'],
#    [811, 817, 'negative'],
#    [820, 830, 'negative'],
#    [882, 892, 'negative']]},
#  '11267': {'text': 'Давно не была в таком ужасном месте. Обслуживание просто ни в какие рамки не лезет, офицантки просто не обращают на тебя никакого внимания, а если уж все-таки удастся кого-нибудь поймать, то на тебя смотрят с таким выражением лица.. "ах, вам еще и принести что-то надо...". По-поводу самой еды - ни одно блюдо восхищения не вызвало. В силу обстоятельств, была в этом ресторанчике не один раз, но как-то с каждым разом убеждаюсь в совем первом впечатлении. Однажды при заказе супа из меню официантка сказала, что следует заказать другой, так как этот скис (!!!). Интерьер - очень темный, не каждому тоже будет по вкусу. В общем, не советую ходить в это место. На той же улице есть довольно много заведений лучшего качества.',
#   'aspects': [[30, 35, 'negative'],
#    [37, 49, 'negative'],
#    [84, 93, 'negative'],
#    [367, 379, 'negative'],
#    [475, 479, 'negative'],
#    [562, 570, 'negative'],
#    [652, 657, 'negative']]},
#  '27569': {'text': 'В первый раз попали в Арагви ещё в феврале. Компания была большая, столик забронировали заранее. Всё очень понравилось - и кухня, и обслуживание, и обстановка. этот ресторан сразу стал любимым, поэтому время от времени туда заглядываем. Последний раз была с подругой 16 апреля. На всякий случай заранее заказали столик. Несмотря на будний день, все столики были заняты, поэтому бронь оказалась очень уместна. Готовят в Арагви очень вкусно, ждать еду приходится недолго. Заказывали зелень с овощами, так там принесли этогго добра целую корзинку.)) шашлык на любителя- кому-то нравится из телятины, кому-то из свинины. Очень вкусные чебуреки! десертов немного, но тоже очень вкусные. Пробовали лёгкий десерт и печёную грушу. жаль,что нет грузинских вин... но их нигде нет. Музыка в ресторане негромкая, обстановка располагает к общению. Так что если нужно спокойное, приятное место, где можно вкусно и недорого поесть, Арагви - самый лучший вариант!приходите, не пожалеете!',
#   'aspects': [[123, 128, 'positive'],
#    [132, 144, 'positive'],
#    [148, 158, 'positive'],
#    [165, 173, 'positive'],
#    [446, 449, 'positive'],
#    [481, 497, 'positive'],
#    [631, 639, 'positive'],
#    [641, 649, 'positive'],
#    [736, 750, 'negative'],
#    [771, 777, 'positive'],
#    [801, 811, 'positive'],
#    [917, 923, 'positive'],
#    [917, 923, 'positive']]},
#  '16378': {'text': 'Сегодня были компанией из 4х человек, были уже далеко не в первый раз, но только сегодня вот собрался оставить отзыв. По порядку: Кухня - Суп-Харчо, шашлыки (перепробовали практически все из представленных) 5+ оценка, лепешки, весьма неплохое вино (на мой вкус), ну и конечно чай с чабрецом :), вот зачем сюда стоит и нужно ходить, согласитесь, что в таком месте какой-нибудь салат Греческий брать совершенно бесполезно, он и не должен быть хорошим тут :) Интерьер - В целом достаточно тематично, исключая уже упомянутую кем-то колонку в зале и может быть недостаток света в главном зале, мне, как и многим, кто здесь писал больше нравится светлый зал, он намного уютнее, единственное - стоит обратить внимание на чистоту скатертей, не всегда идеально. Обслуживание - Приятные, вежливые молодые люди, не слишком часто, но и не редко подходят, работают не бездушно, с улыбкой и вообще органично смотрятся, никаких нареканий. Вообще приятное место для посиделок, как деловых, так и частных, любителям "понтов и собачек" точно не сюда, заведение все-таки не дотягивает до того уровня, чтобы привлекать таких персонажей, но и слава богу. При всем написанном цена очень адекватная, по крайней мере на ту часть меню, которая нас интересует. Спасибо за внимание.',
#   'aspects': [[130, 135, 'positive'],
#    [138, 147, 'positive'],
#    [149, 156, 'positive'],
#    [218, 225, 'positive'],
#    [243, 247, 'positive'],
#    [276, 290, 'positive'],
#    [528, 535, 'negative'],
#    [567, 587, 'negative'],
#    [640, 651, 'positive'],
#    [714, 731, 'negative'],
#    [753, 765, 'positive'],
#    [787, 799, 'positive'],
#    [940, 945, 'positive'],
#    [1205, 1209, 'positive'],
#    [575, 587, 'negative'],
#    [376, 391, 'negative'],
#    [1154, 1158, 'positive']]},
#  '34307': {'text': 'Недавно пришли компанией, давно не были в этом заведении и лучше бы не приходили!!!! Была пятница, людей в зале под завязку, сели за единственный свободный стол, так столы стоят настолько близко, что выйти из- за него невозможно((( но это не самое страшное...... Очень долго несут заказ либо вобще про тебя забывают, все время приходят и переспрашивают( ну если у тебя плохая память- возьми бумагу и записывай) . Мы брали горячее, салатики, пиво и закуски к пиву, которые так и не дождались, хотя по прошествии часа 1 раз даже напомнили, чего мы делать не должны в принципе. Но вот в счет их ВКЛЮЧИТЬ они не забыли!!!! Салаты раньше были вкуснее. Еду приносят черти как, во- первых без приборов, все время нужно напоминать, во вторых, по времени ужасно,1 из нас уже час как поел, а второму еще даже готовить видимо не начали.Официанта то не дождешься, то еще доесть не успел, уже тарелку забирают. В зале стоит галдеж, музыку вобще не слышно. В это заведение мы раньше ходили с удовольствием, что случилось- непонятно. Больше ни ногой!!!! Цены пивного ресторана, а обслуживание дешевой привокзальной пивнушки(((((((',
#   'aspects': [[47, 56, 'negative'],
#    [107, 111, 'negative'],
#    [166, 171, 'negative'],
#    [825, 834, 'negative'],
#    [900, 904, 'negative'],
#    [919, 925, 'negative'],
#    [949, 958, 'negative'],
#    [1065, 1077, 'negative']]},
#  '12814': {'text': 'Сегодня побывал в данном заведении. Кухня была нормальная, я бы даже сказал, что вкусно было все приготовлено. Но есть одно НО... При том что ресторан был практически пуст заказ, я ждал больше сорока минут плюс ко всему, про один десерт официантка совсем забыла и несла его еще минут 20. И что больше всего удивили и не понравилось, то что в меню в составе десерта было написаны одни ингридиенты, а реальном блюде часть инегридиентов я так и не нашел! Так что если кто собиреться там пообедать или поужинать, то учтите, что заказ вы можете ждать Очень долго!',
#   'aspects': [[36, 41, 'positive'],
#    [237, 247, 'negative'],
#    [408, 413, 'negative']]},
#  '35904': {'text': '27.04.2013 Посетила ваш ресторан Евразия,с семьей в г.Ломоносове!Все понравилось!Сервис на высочайшем уровне, большой выбор по меню и напиткам )приятный интерьер, тихо, спокойно!Официантка Марина,была вежлива,приветлива очень быстро приняла заказ)очень порадовала кухня, быстро готовят, невероятно все было вкусно. Ребята работают в команде,все время администратор помогал официантам.Спасибо вам огромное ) Удачи вам и процветания!!!',
#   'aspects': [[81, 87, 'positive'],
#    [127, 131, 'positive'],
#    [134, 142, 'positive'],
#    [153, 161, 'positive'],
#    [178, 188, 'positive'],
#    [264, 269, 'positive'],
#    [315, 321, 'positive'],
#    [351, 364, 'positive']]},
#  '36725': {'text': 'Посетили зтот ресторан 8 марта втроем по купонам. Обстановка приятная, столы большие, обслуживание порадовало, персонал внимательный. Очень понравился официант Шахид, отвечал на все вопросы относительно блюд, заказ не пришлось долго ждать. Еда понравилась, порции большие, красиво оформлены, все вкусно. Все столики были заняты, но никто не мешал спокойно поговорить, музыка играла не громко. Очень вкусные десерты: тирамису, черничный пирог и черный лес. По ценам с купонами получилось вполне приемлемо. С бутылочкой вина, салатами, горячим и десертами получилось меньше 1000 рублей на человека.',
#   'aspects': [[50, 60, 'positive'],
#    [71, 76, 'positive'],
#    [86, 98, 'positive'],
#    [111, 119, 'positive'],
#    [151, 159, 'positive'],
#    [240, 243, 'positive'],
#    [257, 263, 'positive'],
#    [407, 414, 'positive'],
#    [416, 424, 'positive'],
#    [426, 441, 'positive'],
#    [444, 454, 'positive']]},
#  '28258': {'text': 'Заехали с мужем поужинать в пятницу ( 17.01.14.) в 23:00. Первым нас встретил парковщик, помог припарковаться и даже открыл двери и вежливо нас поприветствовал. Интерьер ресторана мне нравится, я люблю такой дизайн. Все просто и со вкусом, много интересных мелочей. Нас обслуживала приятная девушка. К сожалению не запомнили ее имя. Она была внимательна и ненавязчива и помогла мне с выбором пасты, подробно рассказав состав и способ приготовления блюда. Меню ресторана большое в виде журнала, есть все что угодно....вареники, суши, вок, пасты и т.д. Дизайн меню интересный, дизайнеры молодцы! Я ела крем суп из белых грибов (примерно 350 р.) и пенне с уткой ( 450 р.). Суп был вкусный, но паста была просто божественна. Много соуса, мягкое мясо утки. Пастой я была очень довольна))) Муж ел салат с говядиной и карпаччо ( цены я не помню). Нам все очень понравилось. От визита мы получили положительные эмоции...поболтали и вкусно поели! Будем приезжать еще в этот ресторан. Спасибо поварам и персоналу за хорошие эмоции!',
#   'aspects': [[78, 87, 'positive'],
#    [161, 169, 'positive'],
#    [208, 214, 'positive'],
#    [291, 298, 'positive'],
#    [455, 459, 'positive'],
#    [551, 562, 'positive'],
#    [670, 673, 'positive'],
#    [690, 695, 'positive'],
#    [727, 732, 'positive'],
#    [741, 750, 'positive'],
#    [752, 758, 'positive'],
#    [965, 973, 'positive'],
#    [983, 990, 'positive'],
#    [993, 1002, 'positive'],
#    [791, 808, 'positive'],
#    [89, 94, 'positive'],
#    [931, 936, 'positive'],
#    [270, 281, 'positive'],
#    [370, 377, 'positive'],
#    [69, 77, 'positive']]},
#  '19467': {'text': 'На днях я таки посетила Террасу, в которой не была уже пару месяцев. Соскучилась!) Зашли небольшой женской компанией, часов в 9. Народ в это время собрался крайне гламурный, всё вокруг пестрило брендами и драгоценностями. Мне нравится стильный гламур (не знаю, употребляется ли такое выражение), а не... розовый. Это я к тому, что за соседним столиком сидели две дамочки с ног до головы в розовом. Очень забавные, повеселили.) Часов в 11 (сидели мы довольно долго) к нам подсели трое молодых людей, чтобы познакомиться. Знакомиться мы не стали, но и настроение они нам, к счастью, не испортили. Официантка попалась хорошая: внимательная, без оценивающих взглядов, и ждать часами её не приходилось. Сервис в Террасе не плохой, но раз на раз не приходится. В этот раз повезло. Кухня, как всегда, на уровне. Меню интересное и разнообразное. Салаты и паста просто потрясающие. Алкоголь, действительно, вкусный.) Цены приемлемые. В целом Терраса не разочаровывает и продолжает оставаться одним из любимых мест.',
#   'aspects': [[595, 605, 'positive'],
#    [775, 780, 'positive'],
#    [805, 809, 'positive'],
#    [838, 844, 'positive'],
#    [847, 852, 'positive'],
#    [873, 881, 'positive'],
#    [933, 940, 'positive']]},
#  '34761': {'text': 'Хочется поделиться со всеми пользователями сайта отзывом о ресторане Duplex. Данный ресторан мы выбрали для празднования свадебного праздничного ужина в кругу друзей и близких. Предварительно посетив данный ресторан, нам удалось оценить качество блюд и наглядно посмотреть интерьер внутри. Так как торжество планировалось на 25 человек, места для наших гостей было вполне достаточно и для танцев в том числе. Менеджер Алексей, который принимал наш заказ и подписывал договор, провёл всё мероприятие сам, чем очень нас порадовал. В меню мы выбирали разнообразные блюда и все они были очень вкусными. Стол был богатым и ярким. Украшать зал отдельно не пришлось, интерьер очень уютный и располагающий для торжественного мероприятия. Все остались очень довольны, едой, сервисом и доброжелательной атмосферой в ресторане. Спасибо большое Алексею, за наш праздник! Если бы мне пришлось второй раз выбирать ресторан, я не усомнившись сделала выбор в пользу Duplex!',
#   'aspects': [[337, 359, 'positive'],
#    [409, 417, 'positive'],
#    [562, 567, 'positive'],
#    [599, 603, 'positive'],
#    [660, 668, 'positive'],
#    [759, 763, 'positive'],
#    [765, 773, 'positive'],
#    [793, 803, 'positive'],
#    [950, 956, 'positive']]},
#  '36359': {'text': 'Н Начну из далека)) года 1,5-2 назад заходила в "дали" и осталась с неоднозначными впечатлениями (то ли понравилось,то ли нет).Кухня никакая,какой-то странный персонал в непонятной форме,обслуживание тоже ни о чем.Единственное что зацепило - дизайн кафе,уж очень красивый. Буквально на днях решила рискнуть и зайти отдохнуть. Кафе можно было узнать только по оставленному дизайну,все остальное поменялось. Заказала себе салат,так мне даже было жалко его съесть,настолько было красиво украшен))я уже не говорю,что было очень вкусно). Очень понравилось ненавязчивое и качественное обслуживание. Спасибо Вам большое за уютную атмосферу,от Вас даже не хотелось уходить,все настолько было тепло и радушно!)',
#   'aspects': [[242, 248, 'positive'],
#    [420, 425, 'positive'],
#    [420, 425, 'positive'],
#    [579, 591, 'positive'],
#    [623, 632, 'positive']]},
#  '36948': {'text': 'Была в этом ресторане уже четыре раза с декабря прошлого года. Прекрасное вино, вкусная еда с красивой подачей, спокойная атмосфера и замечательное обслуживание. Что касается оценок (от 1 - 10): - 7 ставлю за кухню потому, что хотелось бы больше разнообразия в меню по основным блюдам. - 5 за интерьер - не очень уютно на этих стульях, сумочку никуда не поставить, оптимальные места у окна (относительно комфортно) - 10 за сервис - всегда внимательный и в то же время незаметный персонал, что и должно соответствовать ресторанному обслуживанию.',
#   'aspects': [[74, 78, 'positive'],
#    [88, 91, 'positive'],
#    [103, 110, 'positive'],
#    [122, 131, 'positive'],
#    [148, 160, 'positive'],
#    [269, 284, 'negative'],
#    [293, 301, 'negative'],
#    [327, 334, 'negative'],
#    [377, 389, 'positive'],
#    [423, 429, 'positive'],
#    [479, 487, 'positive'],
#    [261, 265, 'positive']]},
#  '28745': {'text': 'На день рождения моей девушки, мы решили сходить в ресторан. Я выбрал "Мидзуки" основываясь на отзывах с этого сайта, и не ошибся - очень уютное место, вкусная еда (заказывали роллы и рис с курицей), музыка ненавязчивая и тихая. Сервис - хороший, - официантки, заметив что на них смотришь, - не делают вид, что не заметили, а подходят:) Ждать заказа пришлось не больше, чем ожидаешь от ресторана - тарелки появились ровно в тот момент, когда мне в первый раз пришло в голову, что пора бы уже всё-таки принести)) В общем, вечер провели замечательно, теперь буду водить туда друзей.',
#   'aspects': [[71, 78, 'positive'],
#    [145, 150, 'positive'],
#    [160, 163, 'positive'],
#    [176, 181, 'positive'],
#    [184, 197, 'positive'],
#    [229, 235, 'positive'],
#    [249, 259, 'positive']]},
#  '29395': {'text': 'Ресторан очень хороший!!! С ним у меня связано очень трепеиное и важное событие...в этом ресторане мне мой будущий муж сделал предложение (кстати, свадьба через неделю и мы будем отмечать ее только там). Кухня замечательная, обслуживание на 10.Не пришлось ждать меню, как это обычно бывает в некоторых ресторанах. Мы сели, заказали грузинские блюда, шампанское, через минут 5 нам принесли самое вкусное шампанское, которое я пила в жизни. .... Заказ тоже не пришлось ждать очень долго, минут 20, нормально. Мы кушали, кушали, и никак не могли насладиться едой, она была такой вкусной, необычной, т.к. я была первый раз в грузинском ресторане. Там спокойно, музыка такая спокойная и восточная...))) Правда не помню живая ли она была, вроде, нет. Мы были там днем, а вечером там я это точно знаю, что намечалась какая-то программа. Мне очень понравилось!!!! Если Вы ищите ресторан для какого-либо важного события, можете смело идти в "ТБИЛИСО"!!! Если не понравитсяЯ, можете меня исбить...:-))))',
#   'aspects': [[0, 8, 'positive'],
#    [204, 209, 'positive'],
#    [225, 237, 'positive'],
#    [403, 413, 'positive'],
#    [555, 559, 'positive'],
#    [657, 663, 'positive'],
#    [932, 941, 'positive']]},
#  '16714': {'text': 'Были в пятницу (19.03.10), заказывали столик для родительского праздника на воскресенье, заодно и попробовали немного кухню сами. Взяли шашлык по азейрбаджански (из баранины), хачипури Имеритенское, салат Байрам и овощи на гриле. Хачипури немного подкачало, показалось что маловато сыра, хотя наверное на любителя. Салат сочный и вкусный, баранина и овощи очень достойные. Сервис оставляет приятное впечатление. Официант ненавязчивы, но учтивый...очень хорошее сочетание. Интерьер к сожалению не оценил...на уровне, но не более, хотя может быть для приятного обеда более и не надо. Родители остались очень довольны. Особенно хочется выразить признательность администратору, работавшему в эти дни (к сожалению не запомнил имя девушки). Очень хотелось, чтобы родителям понравилось, и сервис оказался выше всяких похвал.',
#   'aspects': [[315, 320, 'positive'],
#    [339, 347, 'positive'],
#    [350, 355, 'positive'],
#    [373, 379, 'positive'],
#    [412, 420, 'positive'],
#    [559, 564, 'positive'],
#    [658, 672, 'positive'],
#    [782, 788, 'positive']]},
#  '3385': {'text': 'Не могу не рассказать, как прошел банкет на мою свадьбу. Итак, когда мы приехали закуски уже были готовы, все было вкусно и как должно быть. Официантка, все делала четко. Бокалы были полны, тарелки пустые во время убирались. Второе мы заказывали по меню. После заказа прошло около полу часа, а может и больше, когда к о мне подошла официантка и сказала, что на кухне нет света, и надо делать другой заказ на горячее (на углях). После бракосочетания и прогулки по городу, как понимаете гости всегда голодные. Да, закуски, как-то смягчили желание поесть, но не на столько, чтобы ждать еще час. Делать было нечего, все опять сели за стол и стали выбирать себе другие блюда, через 20 минут был сделан еще один заказ. И через 30 минут стало совсем смешно, когда ко мне подошла администратор и сказала, что горячего на углях не будет. Будет выполнен первоначальный заказ. В тот день мне ни чем нельзя было испортить настроение. Через 15 минут, на столах появился наш заказ. Тогда уже было все равно, главное накормить гостей, ну и себя) Торт. заказанный заранее (наполеон) не оправдал моих ожиданий, ну что ж на вкус и цвет товарища нет. Что касается интерьера, то он очень подходит для торжеств, удалось поработать с фотографом в интерьерах зала VIP. Рекомендую, но. видимо, ВСЮ кухню надо заказывать заранее. а лучше еще и попробовать!',
#   'aspects': [[81, 88, 'positive'],
#    [141, 151, 'positive'],
#    [332, 342, 'negative'],
#    [1057, 1065, 'negative'],
#    [1145, 1154, 'positive']]},
#  '35620': {'text': 'Об этом заведение достаточно расхожее мнение, решила проверить сама, так как живу по близости. Зашла днем пообедать, встретили достаточно радушно, спросили в первые я в заведение или уже была, это говорит о том, что персонал заботлив к своим гостям и помнит всех постоянных) Мне помогли с выбором столика и рассказали о всех акциях и предложениях. Особенно порадовала 50% скидка на японское меню) Обслуживание быстрое и внимательное, еда понравилась, ассортимент бара большой но я пила только чай, так как пришла пообедать и о качестве напитков сказать ничего не могу. При расчете официант красочно рассказал о программе в выходные дни, о вечеринках и артистах, просто не смогла ему отказать и обещала обязательно придти! Вообще мое впечатление достаточно положительное об этом заведение и я планирую его посещать теперь часто.',
#   'aspects': [[216, 224, 'positive'],
#    [382, 395, 'positive'],
#    [397, 409, 'positive'],
#    [434, 437, 'positive'],
#    [451, 467, 'positive'],
#    [581, 589, 'positive'],
#    [778, 787, 'positive'],
#    [279, 286, 'positive'],
#    [117, 126, 'positive']]},
#  '31004': {'text': 'Были с мужем, хотели отметить дату знакомства, НО! Долго (минут 15-20)ждали в гардеробе, пока нас пригласят внутрь, хотя было уже достаточно поздно и когда мы вошли оказалось, что зал был полупустой. Ладно... Не нервничаем... Доброжелательные такие, праздник всё-таки... Интерьер интересный. Заказываем блюда, названий не помню (я - что-то из курицы, муж захотел попробовать конину). Горячее готовилось минут 10... быстро - не спорю, но КАК за 10 минут можно приготовить конину? Было полное ощущение и от вида и от вкуса, что блюда стояли уже пару суток и были просто разогреты в микроволновке. Никакой соли, никаких специй, совершенно пресная еда (хотя, не спорю, кто-то любит и так, но официанты могли бы предупредить и поставить на стол побольше специй)! Сервировано просто никак. Доесть не смогли. Настроение импортилось. Самым съедобным оказался салат из зелени и овощей, согласитесь, сложно испортить. Цены в общем, средние,но при такой кухне совершенно неоправданные. Мы и за доплату больше туда не пойдём.',
#   'aspects': [[271, 279, 'positive'],
#    [384, 391, 'negative'],
#    [526, 531, 'negative'],
#    [603, 607, 'negative'],
#    [617, 623, 'negative'],
#    [644, 647, 'negative'],
#    [688, 697, 'negative'],
#    [943, 948, 'negative'],
#    [943, 948, 'negative']]},
#  '34889': {'text': 'Гуляли в центре с сестрой, измывали от жары в эти прекрасные редкие теплые деньки... Нагуляли аппетит, решили зайти в ресторанчик пообедать. Давно собиралась посетить ресторан Кухню, а тут и недалеко оказались. Уже на пороге почувствовав легкую прохладу кондиционера и услышав приятную музыку, поняли, что сделали правильный выбор! Девушки администраторы вежливые и приятные, уютная атмосфера, ненавящево стильный интерьер, удобные столики, чисто и со вкусом. Меню. Разнообразие блюд, официанты компетентные, назовут ингредиенты, посоветуют что- то в соответствии с вашими предпочтениями в еде. Пообедали замечательно, быстро, сытно и что самое главное- очень вкусно! Потрясающие десерты, я как настоящий ценитель сладкого, ставлю самую высокую оценку. На самом деле можно много расхваливать, но, наверное, каждому стоит самому оценить. Могу смело рекомендовать это место тем, кто хотел бы ты посидеть в приятной атомосфере и получить удовольствие от хороших и качественно приготовленных блюд! Найти минусы всегда можно в любом месте, в какое мы бы не пришли, все зависит и от нашего настроения. Хотя в некоторых местах нашего города они сами себя находят, эти минусы... Здесь объективно - отличное место.',
#   'aspects': [[254, 266, 'positive'],
#    [286, 292, 'positive'],
#    [332, 354, 'positive'],
#    [383, 392, 'positive'],
#    [414, 422, 'positive'],
#    [432, 439, 'positive'],
#    [479, 483, 'positive'],
#    [485, 494, 'positive'],
#    [680, 687, 'positive'],
#    [866, 871, 'positive'],
#    [913, 923, 'positive'],
#    [988, 992, 'positive'],
#    [1199, 1204, 'positive']]},
#  '14190': {'text': 'Добрый день! Мы с молодым человеком любим открывать новые места..разные рестораны..особенно итальянские. Были во многих уже. Нашла по рейтингу ресторан, пришли, все гости сидели на террасе (лето все таки), а мы сели внутри (поближе к конждиционеру)). Интерьер очень уютный. Сидели прямо напротив кухни (где пиццу готовят) около окна. Есть отзывы, что пахнет кухней..но я не особо заметила..да и легкий аромат пиццы думаю только аппетита прибавит) Начиталась отзывов, что хорошая пицца - взяли именно ее, и остались очень довольны!! Во всех итальянских ресторанах беру тирамису, хлебную козинку и ...захожу в туалет. Таким образом я ставлю оценку заведению. Хлеб должен быть свежий, тираму таять во рту, а на туалетах не должны экономить!! Все понравилось, десерт волшебный! Мило посидели, в окно видела Спас на крови...романтик) Официантка вежливая очень. Напитки принесла быстро...да и еду совсем не пришлось ждать! в общем большое спасибо за атмосферу и угощения. Обязательно придем еще!',
#   'aspects': [[251, 259, 'positive'],
#    [479, 484, 'positive'],
#    [756, 762, 'positive'],
#    [791, 795, 'positive'],
#    [829, 839, 'positive'],
#    [944, 953, 'positive'],
#    [956, 964, 'positive']]},
#  '36166': {'text': 'Здравствуйте! Регулярно с друзьями посещаем данный ресторан! Если хочется провести выходные в какой-нибудь компании душевно, весело, вкусно, то ресторан очень хорошо для этого подходит! Прекрасная Маргарита, вкусная еда и отличная музыка!!! Живу в другом районе, но с радостью приезжаю именно сюда, да простят меня остальные мексиканские рестораны, за мексиканкой едой, атмосферой и отлично провести вечер! Радует также, что кухня по выходным работает долго в отличие от многих других заведений! В общем, место ни разу не подводило, рекомендую!',
#   'aspects': [[51, 59, 'positive'],
#    [144, 152, 'positive'],
#    [197, 206, 'positive'],
#    [216, 219, 'positive'],
#    [231, 237, 'positive'],
#    [352, 368, 'positive'],
#    [370, 380, 'positive'],
#    [505, 510, 'positive']]},
#  '12591': {'text': 'Я недавно переехала в Пушкин.Абсолютно не было времени ,чтобы прогуляться даже по парку,я уже не говорю про какие-либо рестораны.Недавно мне повезло и я выкроила время,чтобы пойти в Екатериненский парк.Погода выдалась ужасная ,решила скрыться в каком-нибудь уютном кафе.Подошла к первому человеку,идущему на встречу и поинтересовалась ,где есть хорошее место,чтобы выпить кофе.Мужчина ,не сомневаясь ответил,что на улице Московской есть чудесное кафе "White-Rabbit". Придя туда ,меня удивила очень уютная атмосфера,приветливый персонал и конечно же интерьер,отдаю должное хозяевам и дизайнеру!В тот день я пила американо(пожалуй самый вкусный)и ела филадельфию,осталась довольна,продукты свежие,кофе ароматный! Через неделю сходила с подругой,заказали 2 стейка (стриплойн) и бутылку красного вина.Такие стейки редко встретишь в СПб,очень вкусные!Всё очень понравилось!Кстати обслуживание очень приятное,их не видно,но тарелки исчезают сразу же.! Думаю пойти на вечер итальянского вина Novello. Спасибо за такое чудесное место в Пушкине!Удачи!',
#   'aspects': [[446, 465, 'positive'],
#    [505, 514, 'positive'],
#    [527, 535, 'positive'],
#    [549, 557, 'positive'],
#    [583, 592, 'positive'],
#    [611, 620, 'positive'],
#    [649, 660, 'positive'],
#    [679, 687, 'positive'],
#    [695, 699, 'positive'],
#    [803, 809, 'positive'],
#    [875, 887, 'positive'],
#    [1020, 1025, 'positive']]},
#  '33591': {'text': 'Отличное кафе!!!! Отмечала в нем свой день рождения с друзьями. Все было замечательно - вкусная и обильная еда, большие блюда, обстановка, вежливая администратор Александра. Небольшое уютное кафе. Очень низкие цены (и это с учетом того, что место находится на Невском проспекте). Я уже не первый раз сюда хожу и всегда очень довольна. Очень вкусные хачапури с сыром, вкусный лосось (кусок очень большой и сытный). И много другой вкусной еды. У меня все друзья решили сюда прийти еще не раз. Если говорить о минусах: Минус, пожалуй, один: Внизу не очень красивый антураж. ПО крайней мере, мне не очень нравится. Но, наверное, это на любителя. На верхнем этаже все супер!!!! НО зато внизу можно попеть караоке! Есть ооочень вкусный кальян. В общем, порекомендую это место всем тем, кто хочет вкусно, сытно и не очень дорого отметить какой-нибудь праздник или просто посидеть вдвоем в уютной обстановке. Очень-очень довольна!!!!',
#   'aspects': [[9, 13, 'positive'],
#    [107, 110, 'positive'],
#    [120, 125, 'positive'],
#    [127, 137, 'positive'],
#    [148, 161, 'positive'],
#    [191, 195, 'positive'],
#    [349, 365, 'positive'],
#    [375, 381, 'positive'],
#    [383, 388, 'positive'],
#    [437, 440, 'positive'],
#    [562, 569, 'negative'],
#    [645, 658, 'positive'],
#    [700, 707, 'positive'],
#    [730, 736, 'positive'],
#    [764, 769, 'positive'],
#    [889, 899, 'positive']]},
#  '20086': {'text': 'Неделю назад зашли посмотреть на новое заведение. Столик заказали, но можно было и не заказывать, свободные столы были. В ресторане 2 зала и комната для караоке (ее увидеть не удалось, работает не каждый день). Интерьер в нашем зале нам понравился - уютно, красивая мебель. Меню не очень большое, цены среднегородские. Отсутствие некоторых заказанных салатов нам объяснили большим спросом:-) Несколько удивило огромное количество обслуживающего персонала в пересчете на кв.м. и посетителя, наш стол обслуживало двое, хотя нас было за столом всего 5 чел. По залам постоянно ходит персонал, у входа стоит несколько "встречающих". Видимо администрация кризис пока не чувствует... По качеству салатов претензий не было, а вот десерты не впечатлили, нам показалось, что готовятся они не в ресторане. Наверное надо будет зайти еще, чтобы увидеть динамику развития...',
#   'aspects': [[211, 219, 'positive'],
#    [266, 272, 'positive'],
#    [722, 729, 'negative']]},
#  '11058': {'text': 'Случайный отзыв.Случайный, потому что были единственный раз. Зашли не большой компанией 5 февраля, вечером. Встречают, провожают всем составом.Улыбаются, предлагают попробовать все, что есть в меню. Ты уже съел один десерт, ну и что, возьми еще один. Доброжелательны до предела. Рассказывают по составу блюд, советуют, одним словом : приятны в общении. Приносят,уносят, сервируют, не придерешься, и это почти при полной заполненности зала. Из небольших недостатков стоит отметить , долго ждали блюда, но обслуживающая нас официантка, сгладила все углы. Как итог вечер удался, спасибо Поленте.',
#   'aspects': [[584, 591, 'positive']]},
#  '20021': {'text': 'Нет, на аватаре не фото бармена)) итак, попросили поподробнее.. Постараюсь) с улицы его почти не видно, и вывеска не очень располагает зайти внутрь... так бы не зашла, честно. Но друзья позвали. и я не пожалела! внутри очень здорово!мест мало, даже не знаю, плюс это или минус.буквально 5-6 столиков, ну и барная стойка) очень уютно) самый классный- столик в конце зала, в уголке, с диваном и подушками) интерьер мне понравился. в светлых тонах, висят картины, занавесочки из то ли бисера, то ли ещё чего) Меню. барная карта хорошая. есть из чего выбрать. правда цены на кальян мне завышенными показались.. Выбор еды небольшой. заказывала тарелку фруктов и салат ( честно, не помню название). всё как на картинке-красииво)). но опять же, вот и минус маленького помещения. еду ждать минут 15, не меньше. и так как бармен один-то и напитки тоже приносят по мере приготовления каждому.. а вот и плюс бара) Сервис! точнее отношение бармена к посетителям. каждого встретит, проводит) здорово) вообщем! место отличное! посидеть с друзьями вечером самое то! да и просто придти,хоть одной/одному, тоже нормально! садишься за барную стойку и ведёшь душевные разговоры с приветливым барменом)',
#   'aspects': [[106, 113, 'negative'],
#    [291, 299, 'positive'],
#    [306, 319, 'positive'],
#    [350, 356, 'positive'],
#    [383, 390, 'positive'],
# ...
#   'aspects': [[94, 103, 'positive'],
#    [137, 146, 'positive'],
#    [166, 174, 'positive'],
#    [179, 186, 'positive'],
#    [359, 368, 'positive'],
#    [381, 398, 'positive'],
#    [399, 417, 'positive'],
#    [418, 425, 'positive'],
#    [426, 442, 'positive'],
#    [443, 457, 'positive'],
#    [501, 507, 'positive'],
#    [541, 548, 'positive'],
#    [558, 564, 'positive'],
#    [570, 575, 'positive'],
#    [706, 716, 'positive']]},
#  '36926': {'text': 'Добрый день! Первый раз пишу отзыв о ресторане, настолько меня впечатлило данное место. Прекрасная кухня, уютный интерьер, доброжелательные официанты, очень дружественная атмосфера! Невозможно уйти оттуда с плохим настроением и голодным, порции очень большие!)) Особенно порадовал ценник...качественная еда за небольшие деньги. Ходили с молодым человеком, заказали омлет по-баварски 260р., салат с теплой куриной печенью 260р., пиво 0,5л. 220р. и бокал белого вина 250р., все вместе обошлось нам всего лишь в 990р. Вообщем впечатление прекрасное, будем заходить еще!!!)))))',
#   'aspects': [[81, 86, 'positive'],
#    [99, 104, 'positive'],
#    [113, 121, 'positive'],
#    [140, 149, 'positive'],
#    [171, 180, 'positive'],
#    [238, 244, 'positive'],
#    [303, 306, 'positive'],
#    [303, 306, 'positive'],
#    [365, 382, 'positive'],
#    [390, 420, 'positive'],
#    [428, 432, 'positive'],
#    [453, 464, 'positive']]},
#  '10625': {'text': 'Субботним вечером зашли компанией в кафе Dolce Italy, попить кофе с пирожными. Было без пятнадцати девять, а кафе, как оказалось, закрывается ровно в девять вечера. Нам любезно предложили разместиться в ресторане, а пирожные пообещали принести туда. Так и произошло наше знакомство с рестораном Italy. Народу было много, полный зал. Для нас смогли найти только столик для курящих, но это сильно не помешало, так как вентиляция справляется. То что мы заказывали, нам понравилось. Интерьер спокойный, сделано со вкусом, но без особых изысков. На мой взгляд, больше подходит для компании, чем для того, чтобы прийти вдвоём. Что касается сервиса, то официантка в начале про нас забыла, пришлось окримнуть, чтоб сделать заказа. Но в остальном всё вежливо и предупредительно. К салату цезарь нужен был соус без анчоусов. Вначале повар сказал, что они могут предложить лишь майонез, что соус готовится утром одинаковый для всех. Минут через десять прибежал снова и обещал сделать всё в лучшем виде.. В общем, зайдём в это место снова. Обязательно попробуем больше итальянских блюд. Давно уже хотим с женой найти для себя хороший итальянский ресторан. Вдруг Italy окажется именно им? :)',
#   'aspects': [[416, 426, 'positive'],
#    [634, 641, 'negative'],
#    [646, 656, 'negative'],
#    [823, 828, 'negative'],
#    [867, 874, 'negative'],
#    [880, 884, 'negative'],
#    [1015, 1020, 'positive']]},
#  '19677': {'text': 'Хочу оставить свой отзыв об этом замечательном кафе. Отмечали мамин юбилей, все было просто замечательно! Недовольных не осталось, всем очень понравилась кухня! Большие порции, интересные салаты и горячее, все было очень сытно и вкусно за сравнительно небольшую цену! Очень приятное ненавязчивое обслуживание! Отдельное спасибо администратору Сергею! Остались только хорошие воспоминания! И какой восхитительный был торт! Всем рекомендую посетить это замечательное кафе! Отлично подходит для проведения небольших банкетов! Уютно и по-домашнему!',
#   'aspects': [[47, 51, 'positive'],
#    [154, 159, 'positive'],
#    [169, 175, 'positive'],
#    [188, 194, 'positive'],
#    [188, 194, 'positive'],
#    [197, 204, 'positive'],
#    [197, 204, 'positive'],
#    [296, 308, 'positive'],
#    [328, 342, 'positive'],
#    [416, 420, 'positive'],
#    [465, 469, 'positive']]},
#  '3552': {'text': 'Недавно праздновала день рождение на 40 человек, это было просто незабываемо. Очень вкусная пицца и салаты на закуску, большой выбор горячих блюд на любой вкус, все гости были удивлены качеством приготовления и очень вкусными блюдами. Заказали большой торт тирамису на десерт, собственного приготовления- это было очень вкусно, но места в животе уже не оставалось, поэтому раздавали гостям в домой. Тихая, приятная музыка. Очень внимательные официанты и администраторы. Спасибо вам огромное за праздник и очень душевную обстановку:))',
#   'aspects': [[92, 97, 'positive'],
#    [100, 117, 'positive'],
#    [133, 145, 'positive'],
#    [226, 233, 'positive'],
#    [252, 265, 'positive'],
#    [415, 421, 'positive'],
#    [442, 451, 'positive'],
#    [454, 468, 'positive']]},
#  '22527': {'text': 'Сегодня отмечали день рождения небольшой компанией из шести человек. Нас разместили в VIP зале. Понравилось оформление стола, подсвечник с горящими свечами создал уютную атмосферу семейного торжества. Обслуживание прекрасное: тарелки убирали сразу, новые блюда приносили быстро, так что ничего не надо было ждать. Кухня тоже приятно удивила, особенно размер порций. Все было свежим и отменно вкусным. Единственное "но"- это отсутствие живой музыки, с ней наш вечер был бы еще приятнее.иЗа сравнительно небольшие деньги отлично отдохнули и поели. Следующий раз не буду думать, куда пойти отмечать какое-нибудь торжество.',
#   'aspects': [[108, 124, 'positive'],
#    [126, 155, 'positive'],
#    [170, 179, 'positive'],
#    [201, 213, 'positive'],
#    [314, 319, 'positive'],
#    [358, 364, 'positive']]},
#  '2345': {'text': 'Вчера впервые побывали у вас на Комендантском 2. Очень уютная атмосфера. Обслуживание и внимание персонала выше всяких похвал! (отдельное спасибо официанту Евгению, обслуживающего наш столик). Долгое время мы были завсегдатаями другого итальянского ресторана, теперь наши сердца (и желудки))) принадлежат Капоне!!! Было немного рискованно для нас прийти к вам вчера впервые, т.к. планировался ужин в честь моего Д.Р. Но мы остались в полном восторге, и уже сегодня с утра, созваниваясь с друзьями всем настоятельно рекомендовала к вам прийти!!! Уже довольно давно отношусь к своему дню рождения более чем спокойно, ограничиваясь тихим семейным ужином. НО вчера ... впервые за много лет вернулось настроение праздника, как из детства! За что огромное вам спасибо!!! Отдельно хочется отметить качество живой музыки! Были приятно удивлены! И конечно наши комплименты повару!!! И вкус и оформление блюд достойны самой высокой оценки!!! Обязательно будем заходить к вам по всем поводам, и без оных, и конечно будем рекомендовать ваш ресторан всем своим друзьям! Еще раз огромное спасибо за великолепный вечер!!!',
#   'aspects': [[62, 71, 'positive'],
#    [73, 85, 'positive'],
#    [97, 106, 'positive'],
#    [146, 155, 'positive'],
#    [305, 311, 'positive'],
#    [800, 812, 'positive'],
#    [864, 870, 'positive'],
#    [894, 898, 'positive'],
#    [894, 898, 'positive'],
#    [1028, 1036, 'positive']]},
#  '8996': {'text': 'Были с друзьями в пабе Метрополь, всё очень понравилось. При входе открывает дверь швейцар, далее стойка с хостес, все очень вежливые, просторная гардеробная, красивая лестница. Интерьер на очень достойном уровне, чувствуется что заведение держит свою марку. В пабе большие деревянные столы, удобные стулья, есть телевизоры, в тот день крутили какой-то концерт. Ненавязчивый и услужливый официант, даже не записывал наш заказ, всё запоминал, видимо знает своё дело :) Сразу скажу про цены, это не забегаловка, поэтому на хороший ужин с пивом, одному человеку нужно как минимум иметь при себе 1500 руб. Но если вы действительно хотите провести приятный вечер в приличном месте, то оно того стоит. Порции не маленькие, а пиво вкусное, блюда готовили не очень долго, мы не успели утомиться в ожидании. В общем, впечатления от паба позитивные, спасибо персоналу ресторанного комплекса за то, что стараетесь сделать клиентов довольными!!! Отдельное спасибо за красоту, за интерьеры!',
#   'aspects': [[18, 32, 'positive'],
#    [83, 90, 'positive'],
#    [146, 157, 'positive'],
#    [168, 176, 'positive'],
#    [178, 186, 'positive'],
#    [230, 239, 'positive'],
#    [285, 290, 'positive'],
#    [300, 306, 'positive'],
#    [313, 323, 'positive'],
#    [388, 396, 'positive'],
#    [670, 675, 'positive'],
#    [696, 702, 'positive'],
#    [719, 723, 'positive'],
#    [823, 827, 'positive'],
#    [848, 857, 'positive'],
#    [955, 962, 'positive'],
#    [967, 976, 'positive']]},
#  '9878': {'text': 'Пришли в данное заведение 4 июня 2014 года покушать шашлык... Заказали из говядины и свинины. Сидели ждали заказ минут 30, потом к нам подошел человек "на кочерге" и сказал, что он очень извиняется и что шашлык скоро принесут...через минут 10 нам принесли холодное мясо ( причем что мы взяли 2 разных)...Когда мы сказали, что шашлык холодный перед нами снова извинился все тот же мужчина и предложил его подогреть... на вкус он был просто отстой (мой муж половину просто не съел, хотя обычно есть все, что не приколочено)... Это единственное заведение, в котором мы не оставили на чай за последние 5 лет! Никому не посоветую еду из данного заведения. Хотя счет нам принесли за минуту.',
#   'aspects': [[143, 150, 'negative'],
#    [265, 269, 'negative'],
#    [326, 332, 'negative'],
#    [380, 387, 'negative'],
#    [420, 424, 'negative'],
#    [542, 551, 'negative'],
#    [640, 649, 'negative']]},
#  '33825': {'text': '06.09.2013 были на ужине в ресторане Пури. Выбирали по местоположению и ориентировались на отзывы посетителей. Заказали столик по телефону. Встретила нас прекрасная девушка администратор, проводила до столика. Место оказалось просто замечательным. Интересный интерьер, все красочное и при этом очень домашняя обстановка. Обслужили нас по высшему разряду. Очень грамотный официант Андрей, за что ему отдельное спасибо. Уделял нам достаточного много времени и при этом не был навязчивым. Порекомендовал отличный чай, от которого мы были в восторге. Меню очень разнообразное. Принесли заказ быстро. Все вкусно. Буду рекомендовать сходить друзьям и знакомым. Появилось желание посетить и другие заведения сети Гинза.',
#   'aspects': [[165, 186, 'positive'],
#    [210, 215, 'positive'],
#    [259, 267, 'positive'],
#    [309, 319, 'positive'],
#    [371, 379, 'positive'],
#    [510, 513, 'positive'],
#    [547, 551, 'positive'],
#    [321, 330, 'positive'],
#    [573, 587, 'positive'],
#    [111, 126, 'positive']]},
#  '15655': {'text': 'Сегодня посетили этот ресторан с девушкой. Очень понравилось. Интерьер отличный, все из дерева и очень красиво! Официанты внимательны и ненавязчивы! Играет приятная музыка! Что касается кухни: Остался в восторге от теплого салата с говядиной, и конечно стейк из говядины! Еще не могу не отметить крем-суп из лосося! Ребята просто молодцы - очень очень вкусно! И порции "достойные". В общем были приятно удивлены таким замечательным местом, обязательно придем еще, и не один раз!',
#   'aspects': [[62, 70, 'positive'],
#    [112, 121, 'positive'],
#    [165, 171, 'positive'],
#    [215, 241, 'positive'],
#    [253, 270, 'positive'],
#    [296, 314, 'positive'],
#    [362, 368, 'positive'],
#    [432, 438, 'positive']]},
#  '17475': {'text': 'Была вчера в этом ресторане!Поехала туда не целеноправленно,так что ничего конкретного об этом месте не знала)Начнем со входа!Есть гардероб и приятный гардеробщик,далее открывается вид в зал-хорошая мебель и приятный интерьер ,печально что нет некурящей зоны!Встретили нормально (никакой улыбки на лице администратора при этом не было) ,проводили к столу.Официант не ориентируется в меню,не видит столы,из рук все валится,грязные тарелки стояли по 10 минут на столе и это при неполном зале!!!?Да уж) Кухня:кушали японскую кухню,вкусная еда и немаленькие порции,подача обычная.А еще салат цезарь-тоже вкусно!Услышала что скидку постоянным гостям по фамилии,без карточки,не делают- не знаю хорошо ли это?!Проводили всем персоналом,уже с улыбкой и доброжелательным видом!',
#   'aspects': [[131, 139, 'positive'],
#    [151, 162, 'positive'],
#    [199, 205, 'positive'],
#    [217, 225, 'positive'],
#    [244, 258, 'negative'],
#    [355, 363, 'negative'],
#    [513, 527, 'positive'],
#    [536, 539, 'positive'],
#    [554, 560, 'positive'],
#    [582, 594, 'positive'],
#    [718, 728, 'positive'],
#    [181, 190, 'positive'],
#    [500, 505, 'positive'],
#    [259, 268, 'positive'],
#    [337, 354, 'positive']]},
#  '22015': {'text': 'Впечатление заведение оставило не самые лучшие!!а жаль.....новое место в центре города!!Во-первых гостей никто не встречает и не провожает к столу,не говоря уже о том,что зал для курящих или не курящих предложен вообще не был!!Подруга заказала бизнес-ланч,а меню я так и не увидела,так как его просто не принесли!!!Заказ был принят ужасно,вслед уходящему официанту мы договаривали свой заказ!!!я заказала чай,но даже его принесли без жасмина!!)))хлеб не был предложен,в принципе вообще ничего предложено не было!!!с таким обслуживанием у заведения вряд ли появятся постоянные гости!!дальше..хуже...счёт нам вынесли,когда мы еще кушали,и даже не просили его,видно в этом заведении не любят ,когда гости задерживаются,сложилось впечатление,что нам определённо пора!!!=))) Интерьер милый,есть диванчики,правда не очень мягкие!!',
#   'aspects': [[12, 21, 'negative'],
#    [355, 364, 'negative'],
#    [790, 799, 'negative']]},
#  '18518': {'text': 'Мы были в этом ресторане 2 раза. Обслуживанием очень довольны, скатерти меняют после каждого посетителя, все очень чисто. Официанты очень подготовленные, могут рассказать, что из чего готовиться, как подаётся. Порции достаточно большие. Всё вкусно! Единственный минус - в праздники и выходные у них очень много посетителей, хотя это говорит о том, что ресторан хороший...И поэтому готовят очень долго! Закуски и салаты приносят быстро, а горячее нужно ждать. За ожидание нам принесли комплимент - мороженое для ребенка. Кстати, мороженое они готовят сами! Очень вкусно!',
#   'aspects': [[33, 46, 'positive'],
#    [122, 131, 'positive'],
#    [210, 216, 'positive'],
#    [352, 360, 'positive'],
#    [484, 494, 'positive'],
#    [528, 537, 'positive']]},
#  '10231': {'text': 'Я несколько раз была в этом заведении,о кухне могу сказать только самое хорошее.Потрясающая паста с лососем,очень вкусные супчики,отличные десерты.Последний раз была с друзьями,все остались довольны и обслуживанием и едой.Интерьер не плохой, несколько залов на разный вкус и компанию.Вообщем стоящее место для обеда и посиделок с друзьями.',
#   'aspects': [[40, 45, 'positive'],
#    [92, 107, 'positive'],
#    [122, 129, 'positive'],
#    [139, 146, 'positive'],
#    [201, 214, 'positive'],
#    [217, 221, 'positive'],
#    [300, 305, 'positive']]},
#  '11793': {'text': 'Являемся постоянными посетителями данного заведения более года. Главное, что хотелось бы отметить - постоянно высокое качество кухни. Это одно из немногих мест, где хочется попробовать все и сразу. Обязательно рекомендуем попробовать суши и роллы. Она обалденны, готовят их быстро, всегда свежие и очень вкусные! Удивительная особенность для сети ресторанов то, что и в других ресторанах (Комендантский, Петроградская) уровень сервиса и кухни остается на том же уровне. Особенно это хорошо видно, если Вы являетесь постоянным посетителем Палок или Евразии =)) Единственное, что хочется отметить из негативного - в зале для некурящих бывает холодно, когда открывается входная дверь, но это мелочи. Если Вы идете туда в первый раз - обязательно попробуйте мороженое в кляре - лучшее в городе. А вот горячее раз на раз не приходится. Бывает приносят и холодным.. Обслуживание хорошее, но иногда приносят все сразу: и суши и суп и десерт. Надеюсь, качество обслуживания и кухни будет столь же высоким, все-таки любимый ресторан!',
#   'aspects': [[42, 51, 'positive'],
#    [118, 132, 'positive'],
#    [155, 159, 'positive'],
#    [234, 238, 'positive'],
#    [241, 246, 'positive'],
#    [342, 357, 'positive'],
#    [427, 434, 'positive'],
#    [437, 442, 'positive'],
#    [614, 632, 'negative'],
#    [754, 771, 'positive'],
#    [953, 965, 'positive'],
#    [968, 973, 'positive'],
#    [1015, 1023, 'positive']]}}

# %%
train.keys()
# Out:
# dict_keys(['15758', '2073', '24713', '16630', '27841', '12880', '32040', '19111', '10847', '10354', '21059', '25960', '2965', '37036', '10985', '11267', '27569', '16378', '34307', '12814', '35904', '36725', '28258', '19467', '34761', '36359', '36948', '28745', '29395', '16714', '3385', '35620', '31004', '34889', '14190', '36166', '12591', '33591', '20086', '11058', '20021', '12203', '13835', '19503', '20862', '36781', '33912', '32995', '12863', '33952', '36321', '32771', '36085', '15363', '225', '35790', '37070', '33816', '27629', '33665', '31071', '16322', '32721', '33405', '12678', '2364', '1200', '13225', '2089', '27169', '27925', '343', '10239', '31140', '32859', '10942', '20784', '21716', '19439', '11355', '36049', '11027', '33693', '27620', '33720', '15567', '18756', '20861', '16676', '1368', '29298', '33621', '20417', '25753', '354', '18220', '24132', '32856', '32442', '28710', '34282', '16647', '32513', '12943', '20397', '12270', '1308', '18430', '23858', '18003', '30201', '3152', '33538', '36407', '33976', '34334', '35325', '35863', '22970', '11388', '2168', '35635', '1563', '1269', '30808', '13186', '14539', '26152', '2495', '32926', '33897', '12131', '27816', '25861', '32206', '35501', '11825', '29321', '9837', '33252', '10778', '26887', '33598', '10099', '31963', '16137', '3231', '34575', '19265', '35085', '3976', '24214', '13252', '18780', '2006', '24217', '22386', '2606', '11155', '13748', '13623', '14865', '19746', '29383', '11770', '3236', '33082', '3480', '36589', '1105', '32692', '1289', '1434', '12467', '23878', '29350', '34045', '33798', '3452', '28112', '9721', '12341', '1511', '16761', '26022', '3705', '11532', '27375', '34710', '11116', '2747', '15423', '36', '36402', '34607', '28585', '19027', '36017', '24275', '16274', '32744', '13100', '36483', '17009', '34402', '34196', '280', '21574', '19383', '10798', '13790', '33524', '10825', '18148', '21856', '26330', '34956', '34232', '2013', '1749', '35613', '11421', '14177', '13912', '26284', '32367', '32584', '27539', '19817', '28612', '1751', '31778', '18253', '24916', '23369', '11102', '17999', '18372', '16568', '28275', '35486', '2616', '9230', '33043', '24501', '16955', '36079', '18983', '6668', '9955', '15159', '22975', '33838', '21399', '1515', '2107', '35867', '2692', '36126', '1052', '2468', '14031', '16151', '24578', '1032', '32840', '36512', '9870', '33520', '17398', '1878', '13823', '3202', '30744', '34228', '2203', '12118', '30368', '10663', '14568', '10645', '36381', '30148', '33622', '36205', '1666', '36274', '17572', '1427', '25709', '3647', '15335', '36576', '36926', '10625', '19677', '3552', '22527', '2345', '8996', '9878', '33825', '15655', '17475', '22015', '18518', '10231', '11793'])

# %%
with open('../../data/train_sem_CoNLL.txt', 'w') as f:
    f.write('-DOCSTART-\n\n')
    for id_ in train.keys():
        text = train[id_]['text']
        tokens = tokenize(text)
        for token in tokens:
            line = f'{token.text} - - O O O\n'
            for span in train[id_]['aspects']:
                if token.start == int(span[0]):
                    line = f'{token.text} - - B_AP {span[2].upper()} B_AP+{span[2].upper()}\n'
                elif token.start > int(span[0]) and token.stop <= int(span[1]):
                    line = f'{token.text} - - I_AP {span[2].upper()} I_AP+{span[2].upper()}\n'
            f.write(line)
        f.write('\n')

# %%
with open('../../data/train_sem_CoNLL.txt', 'r') as f:
    train_txt = f.read().split('\n')[2:]

# %%
with open('../../data/test_sem_CoNLL.txt', 'r') as f:
    test_txt = f.read().split('\n')[2:]

# %%
train_txt = [t for t in train_txt if t]

# %%
test_txt = [t for t in test_txt if t]

# %%
pos = 0
neg = 0
ovall = 0
for t in test_txt:
    if t.split()[3] == 'B_AP' or t.split()[3] == 'O':
        ovall+=1
        if t.split()[4] == 'POSITIVE':
            pos += 1
        if t.split()[4] == 'NEGATIVE':
            neg += 1

# %%
pos/ovall
# Out:
# 0.05059321695362122

# %%
pos/ovall
# Out:
# 0.039997724169321805

# %%
neg/ovall
# Out:
# 0.009906922861822395

# %%
neg/ovall
# Out:
# 0.011663632225762404

# %%
for i in range(10):
    print(test_mark[f'13284:{i}'])
# Out:
# {'text': 'Встречались в этом пабе с подругой.', 'aspects': []}
# {'text': 'Дело было в четверг, днем.', 'aspects': []}
# {'text': 'Посетителей сначала было немного, но чем ближе время шло к вечеру, тем больше бар заполнялся.', 'aspects': []}
# {'text': 'При этом в зале не было накурено, видать хорошая и продуманная система вентиляции.', 'aspects': [('81', '71', 'positive', 'AMBIENCE#GENERAL', 'вентиляции')]}
# {'text': 'Приятная, достаточно уютная атмосфера в стиле паба.', 'aspects': [('37', '28', 'positive', 'AMBIENCE#GENERAL', 'атмосфера')]}
# {'text': 'Очень неплохое меню, но всё весьма сытное, вкусное.', 'aspects': [('19', '15', 'positive', 'FOOD#QUALITY', 'меню')]}
# {'text': 'И большие порции, что не может не понравиться мужчинам.', 'aspects': [('16', '10', 'positive', 'FOOD#STYLE_OPTIONS', 'порции')]}
# {'text': 'Моя подруга здесь бывала гораздо чаще меня, говорит, что перепробовала почти всё, и ей нравится.', 'aspects': [('0', '0', 'positive', 'FOOD#QUALITY', 'NULL')]}
# {'text': 'Девушка-офоициант расторопно нас обслуживала, на мой шутливый коммент про что-нибудь легкое и низкокаллорийное отреагировала очень быстро и предложила несколько вариантов блюд, хотя я совсем не собиралась соблюдать строгую диету или какие-то ограничения в еде.', 'aspects': [('17', '0', 'positive', 'SERVICE#GENERAL', 'Девушка-офоициант')]}
# {'text': 'И вообще на все вопросы отвечала сразу и исчерпывающе, что очень приятно.', 'aspects': [('0', '0', 'positive', 'SERVICE#GENERAL', 'NULL')]}

# %%
sem_test_ids
# Out:
# ['13284',
#  '11771',
#  '10868',
#  '12582',
#  '10855',
#  '10122',
#  '13451',
#  '10837',
#  '10442',
#  '13102',
#  '15966',
#  '1542',
#  '12765',
#  '11154',
#  '10139',
#  '12439',
#  '15492',
#  '10522',
#  '15100',
#  '13693',
#  '15665',
#  '13558',
#  '1580',
#  '12094',
#  '11073',
#  '14415',
#  '14130',
#  '12533',
#  '15336',
#  '1040',
#  '11817',
#  '14551',
#  '15797',
#  '15824',
#  '10731',
#  '10632',
#  '12913',
#  '12611',
#  '12777',
#  '10937',
#  '15847',
#  '1166',
#  '11533',
#  '10953',
#  '13483',
#  '12579',
#  '12004',
#  '15697',
#  '15914',
#  '151',
#  '13133',
#  '15974',
#  '15524',
#  '12510',
#  '1156',
#  '10106',
#  '10903',
#  '1077',
#  '1206',
#  '10915',
#  '15140',
#  '10403',
#  '14407',
#  '12990',
#  '10135',
#  '11283',
#  '10287',
#  '12149',
#  '11108',
#  '13156',
#  '14545',
#  '15145',
#  '13541',
#  '12952',
#  '1180',
#  '12696',
#  '1512',
#  '15687',
#  '14757',
#  '15855',
#  '15856',
#  '10546',
#  '1300',
#  '15866',
#  '10833',
#  '12819',
#  '1306',
#  '11657',
#  '12435',
#  '14209',
#  '12360',
#  '10195',
#  '11885',
#  '10922',
#  '11796',
#  '10800',
#  '11393',
#  '15141',
#  '10816',
#  '13864',
#  '15348',
#  '1336',
#  '1408']
